# %%
import requests
import time
import re
import pandas as pd
from bs4 import BeautifulSoup
from konlpy.tag import Kkma
from konlpy.tag import Okt

# %%
# 참고 사이트 https://yeo0.github.io/data/2018/09/24/5.-%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9D%B4-%ED%95%84%EC%9A%94%ED%95%9C-%EC%82%AC%EC%9D%B4%ED%8A%B8%EC%97%90%EC%84%9C%EC%9D%98-%ED%81%AC%EB%A1%A4%EB%A7%81/
# 참고 사이트 2 https://hashcode.co.kr/questions/9084/%EC%9E%A1%ED%94%8C%EB%9E%98%EB%8B%9B-%EB%A1%9C%EA%B7%B8%EC%9D%B8-%ED%9B%84-%EC%8A%A4%ED%81%AC%EB%A0%88%EC%9D%B4%ED%95%91-%EB%AC%B8%EC%9D%98%EB%93%9C%EB%A6%BD%EB%8B%88%EB%8B%A4-%E3%85%9C%E3%85%9C

# 로그인 할 url
url = "https://www.jobplanet.co.kr/users/sign_in?_nav=gb"
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'
headers = {'Content-type': 'application/json', 'Accept': 'text/plain', 'User-Agent':user_agent}
login_data = {'user':{'email':'hsmy31@hanyang.ac.kr', 'password':'rhkwpgksmswnd!', 'remember_me':'true'}}
session = requests.session()

# 로그인 실행
login_response = session.post(url, json = login_data, headers = headers)

# %%
def ind_reviews(code):
    url = "https://www.jobplanet.co.kr/reviews?&industry_id=" + str(code)
    response =  session.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    num = soup.find('span', class_='num') # 리뷰 개수 확인
    num = int(num.get_text().strip())
    import math, random
    pages = math.ceil(num / 10)
    page = random.sample(range(1, pages),30)
    reviews = {}
    for i in page: # 페이지를 랜덤으로 하여 300개의 리뷰 추출
        time.sleep(1)
        url = "https://www.jobplanet.co.kr/reviews?&industry_id=" + str(code) + "&page="+ str(i)
        response =  session.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        label = soup.find_all('h2', class_="us_label") # 한 줄 리뷰 추출
        # 추출한 리뷰에서 태그를 제외한 텍스트만 추출하여 labels 리스트에 저장
        labels = [label.get_text().strip() for label in label[:]]
        star = soup.find_all('div', class_="star_score") # 별점이 포함된 div 추출
        # 추출한 div에서 별점을 나타내는 width 속성의 숫자로 된 부분을 stars 리스트에 저장
        stars = re.findall('[0-9]+[.]+[0-9]', str(star))
        # reviews 딕셔너리에 '리뷰: 별점' 형식으로 추가
        for j in range(len(labels)):
            reviews[labels[j][5:-1]] = stars[j].replace('.0','')
    return reviews

# %%
# 각 산업군의 기업 리뷰 스크래핑
reviews1 = dict(ind_reviews(1001))
reviews2 = dict(ind_reviews(900))

# %%
#특수문자 제거
def sub(dic):
    dic = [re.sub(r"[^가-힣A-Za-z0-9]", " ", str(content)) for content in dic]
    return dic

# %%
#리뷰별 키워드 추출 후 중첩 리스트 생성  
def append(text):
    temp=[]
    for i in text:
        temp.append(okt.nouns(i))
    return temp

# %%
#산업군 별 키워드 추출 후 리스트 생성
def extend(text):
    temp=[]
    for i in text:
        temp.extend(okt.nouns(i))
    return temp

# %%
reviews_1 = sub(reviews1)
reviews_1
# Out:
# ['위치 좋고 타이틀 좋고 일도 나름 잘 배울 수 있음 ',
#  '칼퇴보장과 비교적 자유로운 점심시간이 좋았습니다  다만 공무원 사회이다보니 보수적인 분위기가 있습니다',
#  '편하게 일할수있음 구내 식당도 맛있음 1층카페도 좋음',
#  '팀바이팀이지만 비교적 무난하게 다닐 수 있는 곳',
#  '복지과 사원들이 친절하고 먹을걸 많이 준다',
#  '별 욕심 없이 길게 다니기 좋은 곳  단 민원업무를 맡는다면 다름',
#  '계약직으로 근무하여 무기계약직을 노리기에 아주 좋음 물론 공무원 시험합격되면 베스트임',
#  '많은것을 보고 배웠음  한단계 성장하는 계기',
#  '석박사 졸업하고  라인 잘 타서 편하게 살고 싶은 사람에게 추천  특히 업무가 힘들지 않아서 여성 석사 졸업자에게 추천 ',
#  '새로운 실험기구를 다루고 전반적인 분석 실험 업무에 대해 배울 수 있는 곳 ',
#  '공공기관 계약직이라 눈치도 보이지만 대체적으로 나쁘지는 않음 ',
#  '민원인에게 과도한 친절을 베풀지 않아도 되는 곳이며  자기 할 일만 잘 하면 되는 곳임 ',
#  '앞으로 더  좋아질 공기업 입니다 일은 조금 힘들다하나 저는 힘든지모르고다녔습니다',
#  '다양한 무상원조 사업을 기획부터 운영 및 관리까지 경험해볼 수 있는 곳',
#  '큰 목표없이 편하게 지내고 싶으신분들에게 추천합니다',
#  '국가기관에서 일한다는 자부심  편리한 출퇴근 환경',
#  '보수적인 분위기를 가지고 있으나 업무강도 낮은 편이며 복지 및 급여 상당히 좋은 편',
#  '딱 그냥 전형적인 공무원 집단인듯 공공기관 거쳐가기 딱 좋은 계약직임',
#  '기독교인이 아니어도 일할 수 있지만  YWCA에서 운영하고 있어 정규직 간사 되려면 기독교인이어야 함 ',
#  '출퇴근이 편하다  회사근처에 음식점  커피먹을곳이 매무매우적다',
#  '보람차게 일할 수 있는 곳  지식을 얻고자 오는 분들께 서비스를 제공할 수 있다는게 보람찼음 ',
#  '그냥 저냥 공무윈입니다 다른 자치구에 비해 그닥 복지가 좋은 쪽은 아닌듯',
#  '생각보다 보수적인 것 같지않아요 사람들도 좋은 것같아요',
#  '일과 삶의 균형이 그 어느 곳보다 뛰어난 직장',
#  '많이 알려진 공무원 장단점을 그대로 가지고 있는 평이한 집단',
#  '당신이 국회 공무원 시험을 통과할 수만 있다면  그걸 위해 들인 노력을 30년 넘게 보상받을 수 있는 직장 ',
#  '승진 빨리하려고 모인 집단자기만 생각함 겉으로는 착한척',
#  '공공기관으로써 나라의 환경적 문제를 직접적으로 확인하고 경험할수있는 좋은 곳이었다 ',
#  '나름 좋고 입지도 나쁘지 않음   공무원이 일하는 곳이라 평균이상은 함',
#  '행정부 최상위 기관으로 대통령을 직접보좌하며 폭넓은 시야와 다양한 경험을 가질 수 있음',
#  '적당히 발전가능성이 있고 적당히 꼰대문화참을만은 하다',
#  '좋은 직원분들과 함께 강도 심하지 않은 업무를 진행할 수 있는 좋은 도서관',
#  '안정적으로 일할수 있는곳  민원 강도가 생각보다 쎄  스트레스는 있음',
#  '공무원이고 사람들에게 직접 도움 드릴수 있는 직업이다 ',
#  '민주주의 국가로서 선거가 역동성있게  살아숨쉬고 있다는 것을 느낄 수 있었다 ',
#  '공공기관의 안정감  근무여건이 각박하지 않은데서 오는 평온함',
#  '러시아를 좋아한다면 근무하기 좋은 곳  칼퇴근 가능  야근수당 나옴   다만  진급이 없고 연봉 인상이 낮다는 점이 있고 ',
#  '일하기 편해요  사람들도 좋고 근처에 금정세무서가 커서 그런지 사람도 그렇게 많지 않아요 ',
#  '근무환경이 우수하고 직원들간에 소통이 잘 이루어지며 안정성이 우수한 직장같음',
#  '여수에서 평생 살 생각이라면 추천  타 지역 사람이면 글쎄     ',
#  '조금 특별하면서 보수적인 직장을  경험 해보고 싶으면 경험으로 좋은 경험',
#  '최악 중 최악  예산 인원 반토막 나서 내년이면 없어질 기관이라고 확신',
#  '워라벨 인정합니다  기업한줄평은 일단 들어와서 느껴보는 것이 어떨까요 ',
#  '점차 성장하는 지방공기업 중 하나로 계속된 좋은 평가를 받는중',
#  '대표를위한 대표에의한 대표의 회사  법인기업이지만 대표 회사다 산자부 반성해라 진짜',
#  '꽤 괜찮은 기업입니다  사내정치만 제외하면 일도없고 급여만 개선된다면 참 좋은곳',
#  '프랑스인들이 임원진이고 대표이지만 회사는 외국회사가 아닌 한국회사처럼 운영이 되며 연봉을 보고 가는곳이 아니라 본인의 만족 혹은 다른곳으로 점프업을 하기 위해 거치는 회사',
#  '1명이 해야하는 일이 너무 많은곳 대신 여러업무를 하면서 다양한 경험가능',
#  '과로가 일상이며  군대식 폐쇄적 문화가 강한  현대와 동떨어진 세계  선배 공무원으로서 더이상의 인생 피해자가 발생하지 않길 바람  반드시 응시하려는 곳을 면밀히 파악하고 지원할 것 ',
#  '터치가 별로없으며 자기일만 잘하면됨 복지좋음 사내분위기 케바케이나 본인은 좋았음',
#  '공공기관은 시험봐서 들어가는걸로   최소 공무직으로 들어가는걸 추천',
#  '적당히 편하게 다니기 좋음  발전가능성은 모르겠음',
#  '업무 체계가 제대로 안잡혀있는 느낌입니다  위에서 말하는 건 무조건 해야합니다 ',
#  '지역에서 오래된 공공도서관이기 때문에 업무를 익히기 좋음   경험해보기 좋음  ',
#  '오래된 기업인 만큼 가장 보수적인 회사  사업을 키워 회사의 발전에 도움이 되어야하지만 책임질까봐 두려워 걱정이 많은 회사',
#  '춘천내에서는 큰 회사 중 하나라고 생각되는곳임 ',
#  '능력만큼 인정받는 곳  인턴이라 경험할 수 있는 기간이 짧아 아쉬웠음',
#  '생각보다 좋지 않았지만 사람들은 좋았음',
#  '군대라는 속박이 힘든 사람에겐 부적절하다',
#  '청년인턴으로 일했었는데 좋은사람도 있고 안좋은 사람도 있습니다 ',
#  '공정거래관련 전문성을 가지고 일 할 수있으며 수평적이고 대체적으로 유연한 분위기 속에서 일 할 수 있습니다',
#  '알바로 일했었는데 사람들 담배 진짜 많이폈습니다     많이 힘들어보였단 뜻',
#  '다양한 업무를 배울 수 있으며  같은 직종 회사 이직시 유니크한 이력이 될 수 있습니다 ',
#  '혼자만의 시간을 잘 관리할 수 있다면 업무와 삶의 균형을 잘 맞춰 경험을 쌓을 수 있는 곳',
#  '워라밸을 하면서 업무강도는 중간  일하면서 자기계발 가능  복지 수준 나쁘지 않음',
#  '분위기가좋고 시키는일이 거의없음  모두잘대해주셔서적응하기좋은기업',
#  '정직원으로 일을 한건 아니지만 부서 분위기도 좋고 직원분들이 친절하셨습니다  구내식당 밥도 맛있고 전반적으로 다 만족스러웠습니다',
#  '출동도 많고 행정업무도 많아서 일 배우기는 좋은 곳직원도 많아서 업무분장은 잘되어 있음공무원이라 그런지 사기업에 비해 성과에 대한 압박은 상대적으로 적음',
#  '순환근무제를 하는 것이 장단점이지만 업무를 다양하게 경험해볼 수 있다는 점  그리고 중소기업들의 산업과 현장에 대한 이해를 높일 수 있다는 점이 좋습니다  중소기업사장들을 고객으로 하는것이 일반고객을 상대하는 것이랑 비교하면 훨씬 낳습니다  ceo들은 그나마 젠틀 할 수 있다 ',
#  '행정인턴으로 단기 근무를 하는데도 배울점이 많았다 ',
#  '여기가 회사인지 자기성찰 하러 오는 곳인지 모르겠는 곳',
#  '업무  복지 등은 매우 만족하나 급여가 너무너무 짜다  경력이 쌓여도 급여가 거의 올라가지 않는  기업 ',
#  '지도자라 그런지 출퇴근 관련해서는 자유로웠음 Ex  매일은 아니지만 현장출근 현장퇴근 지도일정에 맞춰 ',
#  '공공기관이라는 장점은 있으나 민원응대는 어려운 편임',
#  '전형적인 공무원 집단이라고 생각합니다',
#  '공공기관인데도 개방적인 사고와 자유로운 분위기가 보장되는 곳',
#  '불안정한 시스템과 적은 예산으로 인한 고질적인 문제들이 있으나  데스크업무와 현장업무를 두루 익히기 적합하며 여성직원들이 일하기 편한 분위기입니다 ',
#  '공무원으로서 정년과 연금이 보장되는 안정적이며 육아휴직 등 제도가 잘되어있음',
#  '별 한개 주기도 아까운 회사이니 필히 참고해 주시길30자 이상 적을것도 없음',
#  '일하는 방식이 답답했고 소모적임 하는사람만 고생하는 구조',
#  '그냥 그렇다 좋은점을 모르겠다 뭐하는 회사인지 모르겠다',
#  ' 사무보조 공무직   분장 상관 없이 모든 일을 다 해야하지만 그만큼 다양한 업무를 배울 수 있음',
#  '만족합니다  다만 서울시에 비해서 부족한 복지가 눈에 띕니다  복지포인트 등  ',
#  '나이많고 연차높은 사람들은 일을 편하게하지만 젊은 사람들은 업무가 과다함',
#  '종사자가 자기 커리어 쌓고 연구활동하고 좋은것 같다 ',
#  '뭘 해도 결국 공무원 집단  능력 있는 교사들도 많고  월급만 기다리며 대충 하는 교사들도 많음  혁신이 이루어지기 힘듬 ',
#  '근무환경은 쾌적하고 편함  But 월급 및 근무조건은 열악함 ',
#  '무난하게 다니기 좋다 크게 좋지도 크게 나쁘지도 않다',
#  '도시와 농촌이 적절하게 섞여있는 경찰서가 많이 있음 ',
#  '관 이상급 능력차이가 크고 계약직과 정규직의 차별이 심함  공공기관의 프로세스 경험할 수 있음 ',
#  '무난하게 일할 수 있는 공단인데 부서와 소속기구빨을 꽤 타는 거 같음 낮은 연봉상승률은 단점',
#  '좋은 근무 환경  대우를 받으면서 아르바이트를 할 수 있는곳',
#  '사회 복지 분야에 관심이 있는 경우 일하기 좋은 곳다문화 가족을 위한 프로그램을 운영할 수 있음',
#  '여의도 최저임금   진짜 여의도에서 내 임금이 젤 짰다 ',
#  'MICE산업이 어떻게 운영되는지 알 수 있는 곳  다양한 전시 기획을 전문으로 하는 곳 ',
#  '외국계처럼 보이지만 뼛 속까지 한국계 기업  크게 발전하기 어렵다고 생각한다',
#  '첫 직장으로도 괜찮고 경력직으로 입사하기에도 뭐 하나 빠지지 않는 곳',
#  '좋아요 야근 강요 없고 휴학 후 다니기 좋았어요',
#  '좋은 사람들과 함께 일한 좋은 기억을 가지고 나갔다 ',
#  '생각없이 기대하는것 없으면 다니기 좋은회사',
#  '전국의 문화재를 보존관리하는 업무를 할수있는곳  청단위 중에서 기획  정책업무가 과다하지 않음  본청이 대전이고 전국 소속기관 외곽 으로 옮겨다닐수 있다는 단점이 있음  지방근무를 해야함에도 불구하고 본격적이고 전문적으로 문화재업무를 할수있는 학예직에게 추천',
#  '업무 난이도가 낮고 많은 시간을 확보할 수 있습니다 ',
#  '보이기식 인재채용으로 처우개선이 필요함  일자리 양성을 했다고는 하지만 실제론 주먹구구식 채용으로 이직률 높음',
#  '학교밖청소년 지원의 특수성 있으나 직원의 업무환경  복지에 한계가 있음 ',
#  '금전적인 부분이 중요하지 않다면 안정적으로 자유롭게 일할 수 있는 곳',
#  '안정된 직장을 원한다면 추천드립니다  워라밸을 챙길수 있다고 장담은 못하겠음 ',
#  '수많은 민원과 왜 해야하는지 의문인 업무들이 있음  지방조직이 많고 본부는 세종에',
#  '부서마다 다르겠지만 고요한 느낌    인턴이라 권한이 없어 이렇게 느낀걸수도 ',
#  '울산광역시  군  구에서 필요한 내용에 대한 연구와 사업을 수행하는 연구원',
#  '설계와 감리를 모두 맡아서 진행할 수 있는 회사',
#  '구청 특성상 과바과가 아주 큼  저는 만족합니다',
#  '신입이 일 배우기에는 좋은 곳  경력자에게는 업무와 책임은 많이 주어지고 그에 따른 보상은 없음  대체로 업무 분위기는 좋은 편  팀별 차이 있음 ',
#  '스스로 해결해야 하는 일이 많음  할 일을 찾아서 해야하지만 권한이 많지 않음',
#  '외부평가 우수한 기초지자체 지방공기업으로 워라밸을 보장하는 다양한 복쩨도가 있음',
#  '인턴으로 일하기 좋은 곳  큰 급여보다는 편한 직장',
#  '국내 창업지원프로그램의 리더격이긴 하나  중진공 정규직원을 제외한 코칭  전문위원  행정직원은 2년 계약 파견직 근무형태이며  재계약이 안됩니다   사내문화는 대부분 입교한 CEO들과의 원활함을 강조하기 때문에 조용하고  화목한 편입니다  복지라고 할 것은 15일 연차 휴가 중 8일유급휴가  야근수당 없고  출장수당은 주지만 출장이 거의 없습니다 ',
#  '난 있고싶지 않은 곳  남들은 모르겠음 ',
#  '워라밸 지키기에 최고의 직장  여자들이 다니기에 좋은 직장 ',
#  '서로 존중해줍니다   파트 강사였는데도 적응을 잘 도와줍니다  수평적인 문화입니다 ',
#  '지금은 없어진 기관이다  서울에 있다가 용인으로 옮겨짐 ',
#  '정체성이 사라지는 고구마 10개 먹은 기관  인사와 평가체계가 엉망인 기관',
#  '일하고자하는 사람이 별로 없고 인사이동이 잦기 때문에 어떤 한 분야를 제대로 전문적으로 아는 사람이 없습니다몇몇 팀장은 결재봇에 불과합니다',
#  '좋은편이다만 아쉬운게잇다 극락과 지옥을 왓다갓다',
#  '좋은사람은 한없이 좋고 나쁜사람은 한없이 나쁜 곳  재단 내 정규직과 비정규직의 양극화  다양한 사람들이 한데 어우러진 동종업계 대기업 취급  선진적인 부분이 분명 존재함 ',
#  '좋은 사람이 많지만  직원 개별 전문성이 발현되기 어려움 ',
#  '환경부 소속기관  기후변화 정책 관련 연구 진행',
#  '국내유일의 친환경농산물 전문공기업 국내최초 친환경 특구양평에 있고 농가를 위해 힘쓰는 자랑스런 국내유일의 친환경 공기업  공기좋은 곳에서 사회에 기여하면서 일하고 싶은 사람은 강추  대신 내성과 인내력은 필수 ',
#  '대전시 산하 공공기관이라 대전시 말에 무조건 맞춰야하는 게 힘듦  대전시가 의사결정을 잘하는것도 아니고 책임을 넘기느라 일을 대충함 ',
#  '위치가 좋음  연봉 나쁘지않음  부바부  이상한곳은 너무 이상함 좋은부서는 좋음',
#  '공공기관이라서 복지혜택 사기업보다 좋음 안정적인 직장',
#  '안정적인 직장이나 그만큼 폐쇄적인 조직',
#  '최소한의 사회적 관계에서 본인 업무를 할 수 있는 공무원',
#  '부대에서 근무할 때는 편한 줄 모름  하지만 사회에 나오면 이 곳보다 편한 곳이 없음  야근  회식 강요 없고 칼퇴근 가능  개인주의라 업무만 잘 하면 그 외의 것으로 상사 눈치도 별로 안봐도 됨 ',
#  '이상적인 워라밸을 생각하시는 분들이 오신다면 만족하실 만한 회사 입니다 ',
#  '극지 방문이라는 평생 해보기 힘든 경험을 할 기회가 있음 ',
#  '노동자의 권리 향상을 위해 힘쓰는 곳',
#  '관광업계 종사자라면 한국 관광의 주요 사업에 대해 파악할 수 있고  공기업의 특성상 공무원에 준하는 업무 안정성을 확보할 수 있음 ',
#  '제주도에서는 그나마 가장 먹고 살기에 적합한 직업이라고 생각이 된다  안정된 급여  복지 등 다양한 혜택이 있다 ',
#  '공공기관으로서 계약직이 일하기에도 나쁘지 않은 곳이었음',
#  '오래 계실 분들은 출퇴근시간 보장되고 괜찮으실 듯합니다 ',
#  '체계가 아직 안잡혀있고 불필요한 페이퍼 작업 및 보고가 너무나 많음',
#  '장점이 퇴색할 가능성도 크지 않지만  단점이 개선될 가능성도 크지 않은 회사',
#  '복지를 잘챙겨주고 사내분위기는 전체적으로돟으나  부서별로 정규직과 계약직을 약간 차별하는 곳도 있음',
#  '여성인력개발센터의 고질적인 낮은 연봉수준만 개선된다면 정말 괜찮은 센터 ',
#  '인턴이어서 사업에 직접 참가할수는 없었지만  다양한 경험을 해볼 수 있는 기회가 많았음 ',
#  '비전 그런거 다 떠나고 마음편히 다니고 싶다 하면 추천  연구자로서의 발전과 경력을 쌓기위해 들어오고 싶다면 비추천 ',
#  '대도시 이점 때문에 대구 공무원 시험치시는분 대구에 달성군이 있다는걸 잊지마세요',
#  '계약직에 따른 갑질은 적지만 투명인간 취급당하기 일수이며 권한이 없는 일을 수행해야 할 상황이 생김',
#  '공공기관답게 안정적으로 다닐 수 있는 곳이고  강남 한복판에서 근무할 수 있는 곳',
#  '체계는 없지만 근무환경은 나쁘지 않음',
#  '계약직 말고 정규직좀 뽑아주세요 경력쌓기는 나쁘지 않은거같음',
#  '일단 깔끔  프로젝트 시작될땐 일이 많지만 할만함  철밥통임 해양에 관한 견문이 넓어질 수 있을듯싶다 ',
#  '전형적인 행정처리 위주의 업무 문화  창의력 도전정신 같은 MZ 세대가 원하는 역량을 배우기는 힘듦',
#  '나쁘지 않지만 대학 교직원들이 흔히 겪는 업무 떠넘기기는 언제나 존재한다 ',
#  '국내 최초의 유엔 사무국 산하 기구  UN과 같은 국제 기구에서 일하고 싶은 사람에게 이력과 네트워크 제공',
#  '민원만 없으면 참 좋은 회사입니다 중부청은 모두   ',
#  '보수성 짙은 충청남도 소재 지방자치단체',
#  '점점 발전하고 성장하고 있는 기관  기대가 되는 곳입니다 ',
#  '서울에 있는게 장점  언덕은 정말 노답           ',
#  '연고지 근무의 장점을 가진 지방공기업 하지만 실상을 들여다보면 문제점이 많은곳',
#  '전시쪽은 과학에 관심이 있거나 전공분야일시 업무를 수행하는데 유리하다고 생각  일반적인 공공기관과 비슷함',
#  '자기 할일만 잘하면 눈치안보고 생활 할 수 있는 회사 ',
#  '산림쪽으로는 가장 갈만한 공공기관이라고 생각함',
#  '대구가 연고지인 사람들은 평생 대구에서 살 수 있다는 게 장점인 직렬  ',
#  '공기업이라 그런지 사기업 대비 비교적 여유있게 일했던 것 같음',
#  '엄청난 고용안정적인 직업  워라밸 보장은 부서별로 다름 ',
#  '하는 일도 어렵지 않고 연봉은 낮지만 수당으로 어느정도 채울 수 있음 워라밸 좋음',
#  '업무강도 높지않고 진상 민원만 없으면 괜찮은 곳',
#  '마음 먹으면 워라벨 가능하긴 합니다  육아휴직 눈치 안 보고 쓸 수 있습니다 ',
#  '학예사 자격증 발급을 위해 경력인증기관에서 경력을 채울수 있는 곳',
#  '기업은 괜찮은데 가습기는 극악 부서간 편차 너무 큽니다',
#  '한번찍히면 평생 따라다니는 회사 연구원 인사이동이 연구원 안에서만 거의해서폐쇄적 구조',
#  '공무원으로 사명감을 가지고 보람을 느끼며 일할 수 있는 곳  하지만 일은 많음 ',
#  '계속 다니기에 좋은 기관인 것 같다  자부심을 가지고 일하는 사람들이 대부분이다 ',
#  '나쁘진 않은곳 도서관이 지금은 문화재단으로 가서 어떤지 모르겠으나 아직 사서 처우는 아쉽다',
#  '경영지원 직무이기는 하나 청소년관련 공공영역의 서비스  청소년 활동 및 상담에 대한 이해가 필요합니다 ',
#  '안정정이며 가정과 일의 밸런스를 찾을 수 있는 곳  하지만 급여와 복지혜택은 낮음',
#  '계약직으로 들어 간 것이라 수목원 업무에 대해서 알아갈 수 있어서 좋은 경험이었습니다 ',
#  '젊은 연구원들이 함께 연구하는 연구실 분위기',
#  '전북권에서는 나름 전망있고 괜찮은 기업',
#  '대구 내에서 나름 중심지에 일한다는 프라이드를 가질 수 있는 곳 ',
#  '크게 몸이 힘든 일 없이 무난하게 버틸 수 있는 곳',
#  '문화에 관련된 다양한 프로그램을 기획하는 곳',
#  '영국에서 한국 문화를 홍보하는 일  많이 배울 수 있다 ',
#  '다양한 사무행정 업무를 경험할 수 있는 곳',
#  ' 계약직  신의 직장  단  선거철 제외',
#  '지방자치단체와 함께 대민업무 최전선에서 구직자를 위한 모든 서비스를 제공하는 공공기관',
#  '7 8 9급만 죽어라 일하는 공무원 조직 침체된 분위기 노후화된 건물',
#  '서울이라는 대도시 안에  그것도 숲속안에서 근무 환경이 조성되어 있다는 아주 좋은 근무조건을 가지고있다 ',
#  '기록의 수집  관리 및 제공기관으로 안정적이고 사람들도 좋은편이지만 부서별 업무강도가 다르고 협력에 소극적 ',
#  '좋은 사람들과 좋은 환경 지금은 어떨지 모르겠지만 이때가 가장 좋았던 것 같다 ',
#  '워라밸을 중시한다면 최고의 직장입니다 ',
#  '기회만 있다면 다시 일하고 싶은곳  사람들이 정말 좋았다  소방행정에 관심이 있다면 매우 도움이 될 것 ',
#  '정말 좋은 사람들이랑 같이 일 할 수 있는 곳  평생교육사로써 본인의 역량을 마음껏 발휘 할 수 있는 곳 ',
#  '공무원집단에서 계약직으로 일하는게 이방인 느낌이 나기도 하지만 구성원들이 대부분 매너있다 ',
#  '사서로서 일하기 좋은 곳이라고 생각합니다  친절하신 분들이 많고 업무도 체계적으로 구성되어 진행되고 있었어요 ',
#  '급여가 생가보다 쌤  체계가 생각보다 없음  커리어보단 돈',
#  '선거철 아르바이트로 하기에 좋은 일자리',
#  '타 관공서와 비교했을 때 업무가 독립적인면이있어 1년마다 자리가 바뀌는 업무상 어려움과 업무량의 업다운에도 불구하고 내일만 잘하면되는면이있음 모든 법원이 다 마찬가지임',
#  '여유롭고 느긋한 분위기급여는 아쉽지만 워라벨 보장 가능',
#  '정규직들의 뒷담화가 심각함 능력없는 나이많은 직원들 구조조정 필요함 노는 직원들이 은근히 있음',
#  '당신 뒤에 든든한 누군가가 있다면  사돈에 팔촌까지 찾아라 ',
#  '장애인복지계의 삼성 LG급의 인지도 보유',
#  '길고 오래  보면 최고인 직장  이만한 공기업은 없다  하지만 공기업중 최하위   ',
#  '그냥그냥 다닐만한 회사 수원에 살면 다니기 좋음',
#  '낮은 급여  워라밸 붕괴  서울에 있음',
#  '다신 일하고 싶지 않았던 곳 정말 많은 생각을 하게 만들어줍니다 다들 오세요',
#  '일 못해도 라인만 잘타면 승진할 수 있는 곳 ',
#  '사내 정치를 견딜 수 있다면 일 하는둥 마는둥 편히 다닐 수 있는 곳 ',
#  '인권단체인데 인권보장이 잘 안됨  직원들은 열심히 일하고 이사급들은 직원들을 소모품취급함',
#  '사내정치질이 아주중요한 곳 휩쓸리면 끝',
#  '계약직과 정규직이 너무 확연한 곳  성골과 진골로 나뉘는 완벽한 계급이 있는 조직',
#  '상당히 만족스러운 기업  미래의 발전 가능성이 큰 공공기관이다 ',
#  '부서에 따라 분위기가 다르지만 의료부분쪽은 정이 없는 편 ',
#  '상사에 따라 바뀌는 곳 총영사  부총영사  담당 영사가 누구냐에 따라 나의 근무환경과 직무 등등이 바뀜 3년마다 신입사원이 되는 곳이다 ',
#  '편하게 일하는 곳도 있고 반면에 서류작업이 넘치는 곳도 있다 행정에 이렇게 많은 인력이 있어야 되나라는 생각이 들었다',
#  '국가공공기관인만큼 개인에 의해 경영이 좌우되지 않음',
#  '온실가스와 관련하여 다양한 통계  감축목표 등을 실무적으로 배울 수 있는 유일한 기관',
#  '일보다는 사람 스트레스가 큰 곳  비싼 아르헨티나 물가',
#  '봉사단으로서 해외봉사를 가기 좋은 기업',
#  '뚜렷한 목표의식이 있다면 좋은 경험과 경력이 될 수 있는 곳 ',
#  '월급 중요하지 않고 오로지 정년 보장만 중요하다면 공무원 추천함',
#  '일단 파벌싸움이심하다 진짜심각하다 매우심각하다  그러나 직원복지는 작살난다',
#  '주먹구구식에다 인수인계 개판임  워라밸 보장도 안됨',
#  '지방 공공기관이지만 수직적이지 않음  신입도 일하기 편함  워라벨 좋음 ',
#  '서민금융생활법에 따라 9월 특별 법인화가 확정된 채무조정기구  채무 감면 및 소액금융등이 주 업무',
#  '기술뿐만이 아니라 정책적인 부분까지 모두 도맡아 할 수 있는 곳',
#  '  고시 비고시 출신 가림  행정직이 일하기 좋음 그 외 직렬은 X  업무량 많음  조직이 커서 여러 업무 배우기 좋음',
#  '재외공관 대표부에서 계약직으로 근무  태극마크라는 자부심으로 일하는 조직',
#  '여성 경력단절 및 육아 고려하면 최고의 직장  하지만 경제적 여건은 포기해야  갈수록 장점 보단 단점이 커지고 있는 직종  뼛속까지 감정노동자 ',
#  '원주 지방환경청에 공무직으로 근무하였습니다  공무원 사회를 경험할 수 있는 재미있는 시간이 였습니다 ',
#  '급여대비 업구 강도가 낮고 정년이 보장됩니다  근무지가 안동제한이라 안동에서 일하시고싶은 분들에겐 최상입니다 ',
#  '다양한 사람을 만날 수 있는 장점이 있지만 근무지가 좋지 않다 ',
#  '도서 보유 권수가 많고 신간 도서도 많이 들어와 이용자가 많지만  업무량이 엄청 많지 않으며  업무 난이도가 비교적 낮음 ',
#  '일하기 편했다 칼퇴도 가능하고 맡은 업무 외에 더 주는 것도 없었음',
#  '사회복지가치관이 명확한곳 관장님의 열정과 개인의 성장을 지원하는 곳 이용자와 직원 간 존중의 문화가 높음',
#  '분위기 나쁘지않고 공무원으로 오시면 철밥통입니다 ',
#  '안정적으로 꾸준히 오래 다닐 수 있는 회사  그러나 조금 고여있는 회사',
#  '워라밸의 끝판왕을 경험할 수 있으나 미국문화에 익숙하지 않으면 위로 올라가기 어려운 곳 ',
#  '일은 많고 열심히 안하는 직원도 있지만 친절하고 배울만했습니다  하지만 민원인이 많을 때는 밉기도 했네요',
#  '자유롭고 유한 분위기의 공조직   그렇기에 공무원이 아닌자는 소외감을 느낌',
#  '광주 헬게이트 구청 투톱  시 전입시험이 다가오면 다들 탈출을 꿈꾼다 ',
#  '청사 이전 후 환경이 더욱 좋아짐야근 강요 없고 사내 분위기도 나쁘지 않음',
#  '공무원이라는 장점  활발하고 생기넘치는 에너지 하지만 폐쇄적인 조직성으로 지도사로 한번 근무하면 대다수가 한 근무지에서 근무  적응못하면 타지역까지 동종업계에서 소문 다남',
#  '젊꼰이들 집합소 인성글러먹은 팀원들  거기서 버티는 말없는 자들  단순 반복 행정업무인데 심사평가기관의 특성상 갑질심하다가 민원들어오면 을',
#  '일에 대한 의욕이 있던 사람도 사라지게 함열심히 일하는 데에 보람이 없음',
#  '경영평가만 잘받으면 된다는 생각으로 낮은자는 더 낮아지고 높은자는 더 챙기는 말뿐인 공기업 9급이하는 식물인간취급',
#  '그냥저냥 살순 있음  다만 돈 벌고 싶고 그럼 안됨 사람이 꼰대가 좀 있음',
#  '안가는게 좋을듯 싶지만서도 가도 쏘우쏘우한곳 하  ',
#  '서로 책임회피에 한명한테 일 다 몰고 놀 궁리만 하는 직원이 대다수인 회사',
#  '자부심을 느끼면서 일할 수 있는 곳  중앙 부처중 상위권이라 생각됨',
#  '여러 분야의 일을 수행할 수 있으며 본인의 최대치를 끌어올릴 수 있음',
#  '한국인 일본인으로 이루어진 기관으로  일본 문화 및 한일 교류에 관련된 다양한 일을 하는 곳',
#  '부산 스포원파크 저물어가는 태양  기성세대 고객 가 줄어들며 매출도 줄고 이에 따라 직원들 인원 감축이 많았음',
#  '단순 행정직이긴했으나 시간이 여유있어서 다른 공부를 할 수 있었습니다 ',
#  '몇몇 좋은 박사님들이 많았지만 제일 윗선이 본인의 욕심만 채움 공무원이다보니 똑같이 회식비 내는거에 질림 130받는 애들한테 뜯어야 속이 시원했던건지 인턴때 기회 박살 내면 어쩌라는건지',
#  '일은 많지만 공무원의 안정성이 있는 곳 ',
#  '좋은 복지와 직원을 위한 경영  다만 수직적인 의사결정과정이 비효율적이라 느껴짐',
#  '인턴기간동안 전시에 관련된 많은 것을 배울 수 있었습니다 ',
#  '일을 많이 하고 제때 끝내지 못하면 야근을 합니다  일 많이하는 만큼 돈은 많이 줍니다   근데 꼰대문화가 심해서 멘탈이 강한사람은 지원하세요',
#  '용산구 관내 주차장 문화센터 체육시설 어린이집 장난감도서관 등 공공시설 위탁운영 기업으로 서비스기반의 구민 편의제공 기업임 ',
#  '구청 관련 행사대행사로 보면 되십니다 ',
#  '일하는 사람만 일하는 곳  중간만 가야 워라밸 지킬 수 있음 ',
#  '다른 지방공기업과 같이 연고지 및 정년보장 이외에는 아쉬움이 많은회사',
#  '공기업으로  안정적인 근무환경을 추구하는 분에게 만족할만한 회사  대신 연봉상승률도 수평을 이룸    ',
#  '많은 경험과 노하우를 배울 수 있지만 일의 효율성을 배우기는 어렵고 편하게 일하는 방법을 찾으려 할것이다 ',
#  '해수부 산하 기관으로서 국내외 해양조사를 책임짐 바다의 정보를 실시간으로 제공하여 국민에게 편의를 제공',
#  '안정적이고 여유로운 군인  군무원 생활을 할수 있는 곳',
#  '여러가지 역차별을 경험할 수 있습니다 ',
#  '워라밸이 있는 삶이면 최고의 직장이라 생각됩니다 ',
#  '서울 변두리에 위치한 노원구   지방보다 합리성을 기대했으나  고인물 인사 때문에 신규직원들 사기 의욕 저하시키는 곳 ',
#  '스타트업 및 창업 초보자에게 많은 혜택을 주려 노력함  아이템만 좋다면 지속적인 투자받을 수 있음 ',
#  '일이 많고 바쁘지만 개인이 노력한다면 많은 성장을 할 수 있다 ',
#  '산림분야 계시는 분들이 오면 딱입니다  다만 시골인것  감수',
#  '수평적 구조라서 일하기에 부담이 많이 되지 않음',
#  '빛 좋은 개살구  화려한 껍데기  다양한 미술관에서 서비스직 경험했지만 최악의 근무지  관람객과 스탭  전시 자체에 대한 기본적인 예의와 배려가 없음 ',
#  '부산에서는 이만한 회사 찾기가 힘들다  초봉은 작지만 장기적으로 보면 부산에서 연봉이 높다  점점더 경쟁률이 높아질것이다',
#  '보수적인걸 넘어 꼰대적인 곳    꼭 이렇게 팍팍하게 일해야합니까',
#  '객관적으로 봤을 때 장점과 단점이 명확한 기업임다만  일반직보다 업무직 무기직 처우가 더 좋음맘같아선 2점주고싶은데 일이 편하고 수도권근무라 4점줌',
#  '공무원 조직 중 자유로운 편이지 않을까  업무가 특수성 있음 ',
#  '공공기관 계약직으로 근무 했었는데 공공기관이다 보니 꿀직장이었던거 같습니다 ',
#  '워라벨과 복지가 좋아 평생직장으로 생각하며 안정적으로 다닐 수 있는 회사',
#  '복지도 좋고 출퇴근 위치도 좋았다 사람들도 나름 좋은편',
#  '재택으로 기계학습 데이터 구축 계약직했슴다전체적으로 친절하셨고 아주 좋았습니다',
#  '환경부 산하 공공기관  큰 욕심 없이 다니면 나쁘지 않다 ',
#  '계약직은 짐짝 취급당함 단물 빼먹고 버리기 잘함 자유로운 휴가사용 가능',
#  '대체로 여유로운 분위기 그러나 사람마다 업무 강도 차이가 커보얐음',
#  '넓은 캠퍼스에서 일할 수 있고 대학교 시설을 자유롭게 이용할 수 있음  대신  다른 지자체에 비해 체계가 없는 편이라고 함 ',
#  '워라벨이 잘지켜지고  기업문화가 상당히 수평적이라고  할 수 있다 ',
#  '워라밸이 좋음  칼퇴 보장 계약직에 한해서는',
#  '편하고 좋은 사람들이 많았다  구내식당 가격도 저렴했다 ',
#  '일반 사기업에 비해 워라밸이 어느정도 보장되는 곳',
#  '로컬의 한계가 명확할수 밖에 없는 조직인것 같습니다 ',
#  '청년인턴으로 잠시일해보았는데 공무원기관에서 하는 일을 직접적으로 와닿게 배울 수 있어서 좋은 경험이었다 ',
#  '적은 급여나 시스템 등의 단점이 시설 인프라나 상하구조에서의 수평적 관계면에서 일할만 하고 괜찮다',
#  '기간제로일하며 열심히했으나 남자가일하긴별로인듯합니다 여자가 너무 많아 힘든일은 남자기간제가많이하는듯',
#  '조직이 작아서 시스템화  되어있진 않으나  나름 다른 부분은 충족',
#  '확실히 관공서라서 맘편히 다닐수 있고 교통편이 편리해요',
#  '나라에 봉사를 하는 것을 꿈꾸던 사람에게 안정성을 줄 수 있는 곳',
#  ' 나도 안짤리지만 쟤도 안짤린다    표본을 보여줌']

# %%
okt=Okt()
okt.nouns(reviews_1[0])
# Out:
# ['위치', '타이틀', '일도', '나름', '수']

# %%
#KKMA를 사용할 경우 성능이 좋지 않음. okt랑 비교해봤을 때 okt를 사용하는 편이 좋다고 판단.
kkma=Kkma()
kkma.nouns(reviews_1[0])
# Out:
# ['위치', '타이틀', '일도', '나름', '수', '있음']

# %%
goverment= extend(reviews_1)
goverment
# Out:
# ['위치',
#  '타이틀',
#  '일도',
#  '나름',
#  '수',
#  '칼',
#  '퇴보',
#  '비교',
#  '점심시간',
#  '다만',
#  '공무원',
#  '사회',
#  '보수',
#  '분위기',
#  '일',
#  '구내',
#  '식당',
#  '층',
#  '카페',
#  '팀',
#  '바이',
#  '팀',
#  '비교',
#  '무난',
#  '수',
#  '곳',
#  '복지',
#  '사원',
#  '별',
#  '욕심',
#  '곳',
#  '단',
#  '민원',
#  '업무',
#  '계약',
#  '직',
#  '근무',
#  '무기계약직',
#  '아주',
#  '공무원',
#  '시험',
#  '합격',
#  '베스트',
#  '임',
#  '보고',
#  '단계',
#  '계기',
#  '박사',
#  '졸업',
#  '라인',
#  '살',
#  '사람',
#  '추천',
#  '업무',
#  '여성',
#  '석사',
#  '졸업',
#  '추천',
#  '실험',
#  '기구',
#  '전반',
#  '분석',
#  '실험',
#  '업무',
#  '대해',
#  '수',
#  '곳',
#  '공공기관',
#  '계약',
#  '직',
#  '눈치',
#  '보이',
#  '체적',
#  '민원',
#  '과도',
#  '친절',
#  '곳',
#  '자기',
#  '일만',
#  '곳임',
#  '앞',
#  '더',
#  '공기업',
#  '일',
#  '조금',
#  '저',
#  '힘',
#  '무상',
#  '원조',
#  '사업',
#  '기획',
#  '운영',
#  '및',
#  '관리',
#  '경험',
#  '수',
#  '곳',
#  '목표',
#  '신분',
#  '추천',
#  '국가',
#  '기관',
#  '자부심',
#  '출퇴근',
#  '환경',
#  '보수',
#  '분위기',
#  '가지',
#  '업무',
#  '강도',
#  '편이',
#  '복지',
#  '및',
#  '급여',
#  '편',
#  '그냥',
#  '전형',
#  '공무원',
#  '집단',
#  '듯',
#  '공공기관',
#  '계약',
#  '직임',
#  '기독교인',
#  '일',
#  '수',
#  '운영',
#  '정규직',
#  '간사',
#  '기독교인',
#  '함',
#  '출퇴근',
#  '회사',
#  '근처',
#  '음식점',
#  '커피',
#  '곳',
#  '무',
#  '매우',
#  '보람',
#  '일',
#  '수',
#  '곳',
#  '지식',
#  '분',
#  '서비스',
#  '제공',
#  '수',
#  '보람',
#  '그냥',
#  '저',
#  '공무',
#  '윈',
#  '다른',
#  '자치구',
#  '그닥',
#  '복지',
#  '쪽',
#  '생각',
#  '보수',
#  '것',
#  '사람',
#  '것',
#  '일과',
#  '삶',
#  '균형',
#  '그',
#  '곳',
#  '직장',
#  '공무원',
#  '장단점',
#  '그대로',
#  '가지',
#  '집단',
#  '당신',
#  '국회',
#  '공무원',
#  '시험',
#  '통과',
#  '수만',
#  '위해',
#  '노력',
#  '보상',
#  '수',
#  '직장',
#  '승진',
#  '집단',
#  '기만',
#  '생각',
#  '함',
#  '겉',
#  '척',
#  '공공기관',
#  '나라',
#  '환경',
#  '문제',
#  '직접',
#  '확인',
#  '경험',
#  '곳',
#  '나름',
#  '입지',
#  '공무원',
#  '일',
#  '곳',
#  '평균',
#  '이상은',
#  '함',
#  '행정부',
#  '최',
#  '상위',
#  '기관',
#  '대통령',
#  '직접',
#  '보좌',
#  '시야',
#  '경험',
#  '수',
#  '발전',
#  '가능성',
#  '꼰',
#  '문화',
#  '직원',
#  '강도',
#  '업무',
#  '진행',
#  '수',
#  '도서관',
#  '안정',
#  '일',
#  '곳',
#  '민원',
#  '강도',
#  '생각',
#  '스트레스',
#  '공무원',
#  '사람',
#  '직접',
#  '도움',
#  '직업',
#  '민주주의',
#  '국가',
#  '로서',
#  '선거',
#  '역',
#  '동성',
#  '살',
#  '것',
#  '수',
#  '공공기관',
#  '안정감',
#  '근무',
#  '여건',
#  '러시아',
#  '근무',
#  '곳',
#  '칼',
#  '퇴근',
#  '가능',
#  '야근',
#  '수당',
#  '다만',
#  '진급',
#  '연봉',
#  '인상',
#  '점',
#  '일',
#  '사람',
#  '근처',
#  '금정세무서',
#  '커서',
#  '사람',
#  '근무',
#  '환경',
#  '직원',
#  '간',
#  '소통',
#  '안정',
#  '직장',
#  '여수',
#  '평생',
#  '살',
#  '생각',
#  '라면',
#  '추천',
#  '타',
#  '지역',
#  '사람',
#  '이면',
#  '글쎄',
#  '조금',
#  '보수',
#  '직장',
#  '경험',
#  '경험',
#  '경험',
#  '최악',
#  '중',
#  '최악',
#  '예산',
#  '인원',
#  '반토막',
#  '내년',
#  '이면',
#  '기관',
#  '확신',
#  '워',
#  '라벨',
#  '인정',
#  '기업',
#  '줄평',
#  '일단',
#  '것',
#  '요',
#  '점차',
#  '지방',
#  '공기업',
#  '중',
#  '하나로',
#  '계속',
#  '평가',
#  '중',
#  '대표',
#  '위',
#  '대표',
#  '대표',
#  '회사',
#  '법인',
#  '기업',
#  '대표',
#  '회사',
#  '산자부',
#  '반성',
#  '진짜',
#  '꽤',
#  '기업',
#  '사내정치',
#  '제외',
#  '일도',
#  '급여',
#  '개선',
#  '곳',
#  '프랑스인',
#  '임원진',
#  '대표',
#  '회사',
#  '외국',
#  '회사',
#  '한국',
#  '회사',
#  '운영',
#  '연봉',
#  '보고',
#  '곳',
#  '본인',
#  '만족',
#  '곳',
#  '점프',
#  '업',
#  '위해',
#  '회사',
#  '명',
#  '곳',
#  '대신',
#  '업무',
#  '경험',
#  '가능',
#  '과로',
#  '일상',
#  '군대',
#  '폐쇄적',
#  '문화',
#  '현대',
#  '세계',
#  '선배',
#  '공무원',
#  '더',
#  '이상',
#  '인생',
#  '피해자',
#  '발생',
#  '바람',
#  '반드시',
#  '응시',
#  '곳',
#  '파악',
#  '지원',
#  '것',
#  '터치',
#  '별로',
#  '자기',
#  '일만',
#  '복지',
#  '사내',
#  '분위기',
#  '케바케',
#  '본인',
#  '공공기관',
#  '시험',
#  '는걸',
#  '최소',
#  '무직',
#  '추천',
#  '발전',
#  '가능성',
#  '업무',
#  '체계',
#  '제대로',
#  '느낌',
#  '위',
#  '말',
#  '건',
#  '무조건',
#  '지역',
#  '도서관',
#  '이기',
#  '때문',
#  '업무',
#  '경험',
#  '기업인',
#  '만큼',
#  '가장',
#  '보수',
#  '회사',
#  '사업',
#  '회사',
#  '발전',
#  '도움',
#  '걱정',
#  '회사',
#  '춘천',
#  '내',
#  '회사',
#  '중',
#  '하나',
#  '생각',
#  '곳임',
#  '능력',
#  '곳',
#  '인턴',
#  '경험',
#  '수',
#  '기간',
#  '생각',
#  '사람',
#  '군대',
#  '속박',
#  '사람',
#  '청년',
#  '인턴',
#  '일',
#  '사람',
#  '사람',
#  '공정',
#  '거래',
#  '관련',
#  '전문성',
#  '가지',
#  '일',
#  '수',
#  '수평',
#  '체적',
#  '분위기',
#  '속',
#  '일',
#  '수',
#  '알바로',
#  '일',
#  '사람',
#  '담배',
#  '진짜',
#  '뜻',
#  '업무',
#  '수',
#  '직종',
#  '회사',
#  '직시',
#  '유니크',
#  '이력',
#  '수',
#  '혼자',
#  '시간',
#  '관리',
#  '수',
#  '업무',
#  '삶',
#  '균형',
#  '경험',
#  '수',
#  '곳',
#  '워',
#  '밸',
#  '업무',
#  '강도',
#  '중간',
#  '일',
#  '자기계발',
#  '가능',
#  '복지',
#  '수준',
#  '분위기',
#  '일이',
#  '거의',
#  '모두',
#  '기업',
#  '정직',
#  '일',
#  '건',
#  '부서',
#  '분위기',
#  '직원',
#  '구내식당',
#  '밥',
#  '전반',
#  '출동',
#  '행정',
#  '업무',
#  '일',
#  '곳',
#  '직원',
#  '업무',
#  '분장',
#  '공무원',
#  '기업',
#  '성과',
#  '대한',
#  '압박',
#  '상대',
#  '순환',
#  '무제',
#  '것',
#  '장단점',
#  '업무',
#  '경험',
#  '수',
#  '점',
#  '중소기업',
#  '산업',
#  '현장',
#  '대한',
#  '이해',
#  '수',
#  '점',
#  '중소기업',
#  '사장',
#  '고객',
#  '고객',
#  '상대',
#  '것',
#  '비교',
#  '젠틀',
#  '수',
#  '행정',
#  '인턴',
#  '단기',
#  '근무',
#  '점',
#  '여기',
#  '회사',
#  '자기',
#  '성찰',
#  '곳',
#  '곳',
#  '업무',
#  '복지',
#  '등',
#  '매우',
#  '급여',
#  '경력',
#  '급여',
#  '거의',
#  '기업',
#  '지도자',
#  '출퇴근',
#  '관련',
#  '매일',
#  '현장',
#  '출근',
#  '현장',
#  '퇴근',
#  '지도',
#  '일정',
#  '공공기관',
#  '장점',
#  '민원',
#  '응대',
#  '편임',
#  '전형',
#  '공무원',
#  '집단',
#  '생각',
#  '공공기관',
#  '도',
#  '개방',
#  '사고',
#  '분위기',
#  '보장',
#  '곳',
#  '시스템',
#  '예산',
#  '고질',
#  '문제',
#  '데스크',
#  '업무',
#  '현장',
#  '업무',
#  '두루',
#  '직원',
#  '일',
#  '분위기',
#  '공무원',
#  '정년',
#  '연금',
#  '보장',
#  '안정',
#  '육아휴직',
#  '등',
#  '제도',
#  '별',
#  '주기도',
#  '회사',
#  '필히',
#  '참고',
#  '자',
#  '이상',
#  '일',
#  '방식',
#  '소모',
#  '적임',
#  '사람',
#  '고생',
#  '구조',
#  '그냥',
#  '점',
#  '뭐',
#  '회사',
#  '사무',
#  '보조',
#  '무직',
#  '분장',
#  '상관',
#  '모든',
#  '일',
#  '업무',
#  '수',
#  '다만',
#  '서울시',
#  '비',
#  '복지',
#  '눈',
#  '복지',
#  '포인트',
#  '등',
#  '나이',
#  '연차',
#  '사람',
#  '일',
#  '사람',
#  '업무',
#  '과',
#  '함',
#  '종사',
#  '자기',
#  '커리어',
#  '활동',
#  '것',
#  '뭘',
#  '해도',
#  '공무원',
#  '집단',
#  '능력',
#  '교사',
#  '월급',
#  '대충',
#  '교사',
#  '혁신',
#  '근무',
#  '환경',
#  '월급',
#  '및',
#  '무조건',
#  '무난',
#  '크게',
#  '크게',
#  '도시',
#  '농촌',
#  '경찰서',
#  '관',
#  '이상',
#  '능력',
#  '차이',
#  '계약',
#  '직',
#  '정규직',
#  '차별',
#  '공공기관',
#  '프로세스',
#  '경험',
#  '수',
#  '무난',
#  '일',
#  '수',
#  '공단',
#  '부서',
#  '빨',
#  '꽤',
#  '거',
#  '연봉',
#  '승률',
#  '단점',
#  '근무',
#  '환경',
#  '대우',
#  '아르바이트',
#  '수',
#  '곳',
#  '사회',
#  '복지',
#  '분야',
#  '관심',
#  '경우',
#  '일',
#  '곳',
#  '다문화',
#  '가족',
#  '위',
#  '프로그램',
#  '운영',
#  '수',
#  '여의도',
#  '최저임금',
#  '진짜',
#  '여의도',
#  '내',
#  '임금',
#  '젤',
#  '산업',
#  '운영',
#  '알',
#  '수',
#  '곳',
#  '전시',
#  '기획',
#  '전문',
#  '곳',
#  '외국',
#  '보이',
#  '뼛',
#  '속',
#  '한국',
#  '기업',
#  '크게',
#  '발전',
#  '생각',
#  '첫',
#  '직장',
#  '경력',
#  '직',
#  '입사',
#  '뭐',
#  '하나',
#  '곳',
#  '야근',
#  '강요',
#  '휴학',
#  '후',
#  '사람',
#  '일',
#  '기억',
#  '가지',
#  '생각',
#  '회사',
#  '전국',
#  '문화재',
#  '보존',
#  '관리',
#  '업무',
#  '곳',
#  '청',
#  '단위',
#  '중',
#  '기획',
#  '정책',
#  '업무',
#  '과',
#  '청',
#  '대전',
#  '전국',
#  '소속',
#  '기관',
#  '외곽',
#  '단점',
#  '지방',
#  '근무',
#  '함',
#  '불구',
#  '본격',
#  '전문',
#  '문화재',
#  '업무',
#  '학예',
#  '직',
#  '추천',
#  '업무',
#  '난이도',
#  '시간',
#  '확보',
#  '수',
#  '보',
#  '이기',
#  '인재',
#  '채용',
#  '처우',
#  '개선',
#  '일자리',
#  '양성',
#  '실제',
#  '론',
#  '주먹구구',
#  '채용',
#  '이직',
#  '률',
#  '학교',
#  '밖',
#  '청소년',
#  '지원',
#  '특수성',
#  '직원',
#  '업무',
#  '환경',
#  '복지',
#  '한계',
#  '금전',
#  '부분',
#  '안정',
#  '일',
#  '수',
#  '곳',
#  '안정',
#  '직장',
#  '추천',
#  '워',
#  '밸',
#  '장담',
#  '민원',
#  '왜',
#  '의문',
#  '업무',
#  '지방조직',
#  '본부',
#  '세종',
#  '부서',
#  '고요한',
#  '느낌',
#  '인턴',
#  '권한',
#  '울산',
#  '광역시',
#  '군',
#  '구',
#  '내용',
#  '대한',
#  '연구',
#  '사업',
#  '수행',
#  '연구원',
#  '설계',
#  '감리',
#  '모두',
#  '진행',
#  '수',
#  '회사',
#  '구청',
#  '특성',
#  '과바',
#  '과',
#  '아주',
#  '저',
#  '신입',
#  '일',
#  '곳',
#  '경력',
#  '업무',
#  '책임',
#  '그',
#  '보상',
#  '대체로',
#  '업무',
#  '분위기',
#  '편',
#  '팀별',
#  '차이',
#  '스스로',
#  '해결',
#  '일',
#  '권한',
#  '외부',
#  '평가',
#  '기초',
#  '지자체',
#  '지방',
#  '공기업',
#  '워',
#  '밸',
#  '보장',
#  '복쩨도',
#  '인턴',
#  '일',
#  '곳',
#  '급여',
#  '직장',
#  '국내',
#  '창업',
#  '프로그램',
#  '리더',
#  '격',
#  '하나',
#  '중진',
#  '공',
#  '정규직',
#  '제외',
#  '코칭',
#  '전문',
#  '위원',
#  '행정',
#  '직원',
#  '계약',
#  '파견',
#  '직',
#  '근무',
#  '형태',
#  '재계약',
#  '문화',
#  '대부분',
#  '입교',
#  '강조',
#  '때문',
#  '화목',
#  '편입',
#  '니',
#  '복지',
#  '것',
#  '연차',
#  '휴가',
#  '중',
#  '야근',
#  '수당',
#  '출장',
#  '수당',
#  '주지',
#  '출장',
#  '거의',
#  '난',
#  '곳',
#  '남',
#  '워',
#  '밸',
#  '최고',
#  '직장',
#  '여자',
#  '직장',
#  '서로',
#  '존중',
#  '파트',
#  '강사',
#  '적응',
#  '수평',
#  '문화',
#  '지금',
#  '기관',
#  '서울',
#  '용인',
#  '짐',
#  '정체',
#  '고구마',
#  '개',
#  '기관',
#  '인사',
#  '평가',
#  '체계',
#  '엉망',
#  '기관',
#  '일',
#  '자하',
#  '사람',
#  '별로',
#  '인사',
#  '이동',
#  '때문',
#  '분야',
#  '제대로',
#  '전문',
#  '사람',
#  '몇몇',
#  '팀',
#  '결재',
#  '봇',
#  '극락',
#  '지옥',
#  '왓다갓다',
#  ...]

# %%
reviews_2 = sub(reviews2)
reviews_2
# Out:
# ['독립계로 소신있는 운용을 하고 있는점 높게 평가함 판교에 위치하고 있어서 주변 환경이 좋은편임',
#  '모든 문화예술공공기관이 그렇지만  사명감없이 버티기 힘든 곳',
#  '실제 업무하는 사람들만 일하는 체계  나머지는 업무관련하여 신경쓰지 않으려고 함  직원들을 보호해주는 회사의 역할이 부족함 ',
#  '서류작업이 많고 매우 보수적인 기업새로운 것을 시도하려하기보다 기존의 방식을 고수하는 것을 선호',
#  '사원보다 대리가 훨씬많은  인사부터 복장까지 지적하는 태강학교',
#  '야근 없고 휴가 자유롭게 쓰고 회식 없고 일하기 편함',
#  '그냥 평범한 회사인데 발전 가능성은 애매합니다',
#  '금융그룹계열사가 많이 섞여있어 관리가 미흡하다고 생각됩니다  야근이 잦고 인사평가또한 제대로 된다고 생각하지않습니다  굉장히 수직적입니다  학교보다 심한거같습니다 ',
#  '일단 이 회사뿐만 아니라 손해사정업계에는 애초에 발을 들이지 않는것을 추천자기가 한 만큼 돈을 버는 인센티브제라 밥먹는 시간 아끼고 화장실가는 시간 아껴서 기계처럼 일만 하게됨 돈 많이 벌어야하니 조기출근 야근은 거의 필수스펙 딸리는데 일은 해야한다 그럼 추천 무스펙으로 입사가능대신 경력개발 안됨자기일만 잘하면되니 사회성 부족한 사람에겐 추천',
#  '퇴근시간만 생각한다면 가도 좋은 회사  단  퇴근시간만',
#  '분위기가 보수적이고 남성적인 편이나 여성들 업무하기에도 좋은 환경임',
#  '근무환경이 쾌적하고 복지및 근무형태가 만족스러움',
#  '개인의 역량은 잘만 발휘하면 급여가 오르는 직장',
#  '장기근속 사원이 많은곳하지만 그런 직원들을 우습게 보는곳본인 업무외 타업무를 쉴새없이 시킴',
#  '준공기업 성격의 회사  정년이 보장되어 있다고 해도 과언이 아님  공무원 마인드로 다닐 수 있다 ',
#  '개인역량이 올랐을땐  그 어떤 회사와도 비교할 수 없는 인센구조  젊은 직원들이 지켜내고 있는 회사  이 부분은 정말 리스펙 ',
#  '직원 복지가 잘되있으나 회사의 비용관리 노력이 부족합니다  성장가능성이 낮은 회사입니다 ',
#  '취준 노력에 비해 직무 전문성이 많이 떨어짐  연봉 상승률도 낮음 ',
#  '공기업 이미지에 사회복지성 업무를 수행하고 있기 때문에 보람참',
#  '여러모로 좋은 회사이지만 변화하는 시장과 투자자들의 니즈에 시의적절하게 부응하지 못하여 어려움에 처함 ',
#  '커리어에는 도움될듯하다 다양한 감정을 느낄 수 있다',
#  '가뜩이나 일 많은데 텃세 무엇     ',
#  '외관보고 가면 근무환경에 놀람  시스템이 낙후 되어 있고 신규 시스템과 기술로 제안을 해도 도통 들을려고 하지않음',
#  '안좋은 평이 많은데 어느정도 알겠지만 스스로 돌아봐야할 사람이 일부러 안좋게 씀 그래도 나름 열심히 다녔던 팀원이었는데 안타까움',
#  '일은 빨리 늘지만 인원이 적고 일은 많아 사람이 갈려나갑니다  ',
#  '아무리 은행원이 되고 싶어도 쳐다도 보지 않았으면 하는 곳  이 곳은 은행이 아니라 모두가 대표 개인 비서인 곳임  직급과 관계없이 성희롱 폭언 왕따 욕설 비방이 난무한 전쟁터에서 눈치보기 바쁨  누구 하나 만족하는 직원을 못봤음 ',
#  '사람에 대한 기본적인 배려가 없는 회사 퇴사한지 오래되었는데도 아직까지 트라우마가 있다',
#  '직원을 소모품으로 아는 최악의 회사다  떳떳하지 못한 일을 하고있는 것 같다 ',
#  '겉보기엔 그럴듯 해보이지만 그에 맞는 실속이 없음빛좋은 개살구',
#  '소규모회사  주먹구구식회사  업무를 배우기 어려운 회사',
#  '정규직은 오래가고   계약직이면 인센티브율이 다른 증권사보다 높음',
#  '그룹문화가 상하 문화라기 보단 화기애애한 분위기로써 일 할 수 있는 회사이고 비교적 차별이나 업무 불이익등이 없습니다',
#  'It can be good if you re not comfortable with speaking English and you re okay with working in a very conservative and old fashioned company culture  I d like to give two and half stars out of five stars ',
#  '다니다보면 하루하루 성장해나가는 것을 느낄 수 있는 회사',
#  '야근문화는 없어졌고 급여도 나쁘지않아 만족하며다닐수있음',
#  '과거에는 최악이라고 부를만 했으나 조금씩 나아지는 중  하지만 아직 시간이 더 필요할 듯',
#  '무리한 비용절감과 영업 확장 추진으로 방향성을 잃은 회사',
#  '업무적으로 고객에게 받는 스트레스는 없지만  채권팀에서 받는 실적등의 업무 스트레스가 있음',
#  '과거와 미래의 패러다임 속에 있는 은행    안정적 보수적으로 운영하던 은행을 행장이 계속 바뀌면서 최고의 은행으로 만들려고함',
#  '역시 삼성 계약직 대우치고 돈은 짭짤하게 줌 그 돈 받다 다른 곳 못 가겠음',
#  '서울 붙박이로 정년까지 안정적이며 나쁘지않은 급여로 일할 수 있는 곳   그러나  ',
#  '실적압박없이 편하게 다닐수 있는 곳정규직과 비정규직 차이가 심함',
#  '대의가 있는 리더쉽 밑에서 일을 원없이 할 수 있는 곳  다만 번아웃 조심',
#  '계속해서 성장하는 회사  대우받으며 좋은 사람과 일할 수 있는 회사지만 주식에 지극히 편중된 수익구조는 반드시 극복해나가야 할 사안',
#  '사람들은 좋은데 다니고 오래 다니기엔 너무나 고민되는 기업',
#  '직장에 삶을 올인하지않고 취미생활을 할 수있고정년후 노후 연금까지 안정된 삶이 어느정도 보장된 곳',
#  '입사와 함께 보장된 다양한 복지와 안정적인 급여  금융공기업  국책은행이라는 프라이드는 덤  하지만 반대로   그만큼 본인을 버렸을때 버틸수 있는 조직   ',
#  '여러 증권과 비교했을때 상대적으로 안정적인 회사',
#  '글로벌 최고의 자산운용사에 근무하고 있다는 자부심을 느낄 수 있음 ',
#  '외국계 금융기업으로서 아주 훌륭하고 좋았습니다  아직도 전징작 동료들과 컨택하며 지냅니다 ',
#  '복지나 연봉 업계내에서는 괜찮은 편입니다',
#  '최근 기업문화가 회사다워지는 중  과거에 비하면 정말 좋아졌음  업무의 체계도 잡히고 직원 상호간 존중하는 문화를 만들기 위해 노력중임',
#  '영업현장의 업무 경험을 제대로 해볼 수 있는 곳',
#  '명절 선물 주긴 주는데 3만원은 처음 받아봐요 진짜로 ',
#  '기독교회사로 강제로 예배도 참석해야하는 고지식한 회사',
#  '전체적인 분위기는 화목하지만 출근은 빠르고 퇴근은 느린 회사',
#  '괜찮은 분위기에서 일하기 나쁘지 않으나 승진및 연봉동결',
#  '야망이 있다면 기회가 많은 곳  성장하는게 느껴짐  하지만 여전히 중책에 계신 분들 중에는 리더십 답답한 분들이 많이 있음 ',
#  '금융권이라 하기엔 애매하고 그냥 30인 내외 사업장 소기업이다 ',
#  '직원들간 합이 좋고 점점 나아지고 있음 군기 문화 없음',
#  '디자인에 대한 요구와 많은 야근이 있었지만 그래도 좋은 경험을 하였습니다 ',
#  '정말 효율적으로 일하는 조직이고 성과도 좋으나 업무강도는 과합니다 ',
#  '최근성장세가 좋은 우량한 서울 자산규모 1위신협입니다 ',
#  '큰 꿈없이 광주에 살고 싶다면 괜찮은 직장',
#  '근무환경은 적당한 수준임 일하기에 나쁘지 않으나 크게 좋은 것도 아님',
#  '그냥 시니어를 위한 회사임  주니어들은 디딤돌이라고 생각하고 1 2년안에 이직하는게 답임',
#  '만족스러운 근무 환경  일만 맞다면 꽤 만족스러운 회사 생활을 할 수 있는곳',
#  '다양한 사람들과 일해보고 싶으면 추천합니다  사람들은 너무 좋고 사장님과 만날 기회가 많습니다 ',
#  '밝은 분위기  수평적인 의사소통  자유로운 사내문화',
#  '가장 좋지도 그렇다고 가장 나쁘지도 않은 적당히 다니기 괜찮은 증권사',
#  '그나마 있던 복지같은 워라밸마저 사라지는중',
#  '영업자 자체 대우는 굉장히 좋으나 회의 및 여타 영업직과 다르게 퇴근시 회사 재 방문을 거의 해야 합니다 ',
#  '조용히 직장생활 할수 있는 곳으로 딱 저축은행 중간 포지션해당됩니다 ',
#  '친근하고 편한 기업문화  단 이게 회사가 맞나  싶을정도로 너무 막대하거나  주먹구구식으로 돌아갈때가 있음',
#  '욕심없이 무난하게 다닐 수 있는 회사',
#  '복지도 좋고 직원들끼리 연대감 좋은 편',
#  '업계 안에서 알아주는 편이고 성장속도도 의욕도 모두 좋음  그러나 자리잡히지 않은 업무체계와 당연시되는 야근과 주말출근 ',
#  '체계가 안잡힘 타사를 쫒아갈라는느낌이강함 자유로운 휴가사용가능',
#  '주먹구구식 기업운영 한달한달 바뀌는 보직이동은 제발 없애주셨으면 좋겠습니다 ',
#  '건설사 오너 탑다운 명령구조  사업구조상 확장 가능성 불확실',
#  '신입이 일 배우기 괜찮은 곳 다만 대리과장 진급이 늦어서 중간직급의 메리트는 별로인듯',
#  '일반 보험대리점이다  대신 더 큰 보험대리점은 많다   성장할 수 있는지 없는지를 꼭 확인해보길 권유한다 ',
#  '무조건 실적보다 인간관계가 중요한 회사     내성적이면 버티기 힘들다',
#  '문서정리 사무보조 일의 경우 신체적인 힘듦은 덜하나 업무에 스트레스가 약간 있습니다 ',
#  '회사가 성장하기위한 전략이 없다  경영진은 없는걸 포장해서 팔려는 장사꾼일 뿐이다 ',
#  '변화가 없는 기업 욕심은 많은데 롱런하긴 힘든 기업',
#  '스타트업이라는 기업특성을 쫓지만 자유로운 분위기는 아니고 좀 폐쇄적인 분위기  대부분이 지인들로 이루어진 임직원이 많아 형 동생 하는 사람이 많았음  수평적구조의 기업문화를 만들려하지만 내부문화는 수직적인 기업문화임  여의도에 위치해있고 사내카페가 있는것이 가장 장점이였음 ',
#  '대표님이 열정적이라서 좋아요  현실적인 조언을 많이 해주세요  사장님도 착하시고  ',
#  '외국계 기업으로써 국내 다양한 보험사들 보다 관리자로 나아갈수있는 기회 FC들에게 다양한 혜택과 기회가 많은 기업 ',
#  '공공기관이라는 한계로 동종업계에 비해 급여 및 복지는 많이 부족하나 일과 삶의 균형을 어느정도 가져갈 수 있음  업무만 맞다면 여성들이 일하기 좋은 회사임 ',
#  '부동산 대체투자 함  인턴은 잡무 많지만 기본 일 배울수있음',
#  '편하게 일하기 괜찮음  개인주의적 문화 발달  회사 위치 좋음  회사 건물 좋음  구성원 무난',
#  '수평적 조직문화  성격과 커리어 좋은 시니어들로 인해 인턴으로 근무하기에 최고의 회사 ',
#  '주식투자의 기본에 대해 많이 배울수 있는 곳',
#  '해외 스타트업 지원 및 컨설팅 회사  다양한 분야의 사업 내용들을 접할 수 있음 ',
#  '좋다 누구나 다니고 사람들과 함께하는 회사 이 회사를 추천합니다',
#  '외국계기업의 장점을 두루 갖춘 훌륭한 회사',
#  '투자자문사이지만 다양한 분야에 전문인력을 배치하여 매우 넓은 투자를 하는 기업  넓은 시야로 하는 투자를 경험하고자 한다면 좋은 경험이 될 것',
#  '하게 하는게 아닌  해보게끔 믿고 지원해 주는 회사충성을 강요하는게 아닌  충성심이 생길수 밖에 없는 회사',
#  '투자에 대한 업무를 배울수 있는 몇안되는 회사 중 하나',
#  '안정적이지만 시스템이 오래된 그래도 그 지역에서는 꽤나 괜찮은 직장',
#  '안정성 정년 보장 됨 하지만 조합원 자녀들 득실 과장은 꿈도 꿀수 없음 과장이 되야 돈좀 범 ',
#  '경력이 없는 계약직 및 인턴에게는 경력 쌓기 매우 좋은 곳  일이 많은 편',
#  '삼성화재의 자회사라는 타이틀을 벗지는 못하지만 그래도 삼성계열사의 복지와 문화를 갖추고 있는 곳  연봉도 동종업계중 상위권으로 경력직도 많이 들어옴  회사가 성장함에 따라 업무량도 많아지고 있으나 시간이 좀더 지나 안정적인 시기가 오면 균형을 맞춰갈 수도 ',
#  '업무가 크게 어렵지도 많이 쉽지도 않음  간간히 장애나 사고가 나면 수습까지 그렇게 오래 걸리지 않았음',
#  '경력 쌓기 좋고 자유로움 돈보고는 오지말기 ',
#  '급여와 워라벨 면에서 제주에서 다니기 나쁘지 않은 직장',
#  '회사가 주주가 바뀌면서 계속 변화한다  성장가능성 있는 곳 ',
#  '편하게 오래다닐수있는 회사그러나 많은것을 견뎌야하며 적응이 빠르고 액션등으로 자신을 어필 할수있어야함',
#  '최초 연락은 집코리아 같은 곳에서 이력서 올려놨더니 연락 왔어요 면접 보러갈 때 복장 어떻게 해야할지 물어보니 청바지에 흰티를 입고와도 된다길래   정말 청바지에 흰티 입고 갔었습니다   다른분은 정장 입고 왔습니다   그리고 면접에는 차장  대리 이렇게 면접관으로 들어왔었습니다  생각보다 저한테는 질문이 많이 없었고  다른분들한테 많았습니다    그리고 면접에 합격되고 들어가서 일하는데 큰 문제는 없었습니다  시설도 분위기도 그럭저럭 좋았습니다  ',
#  '업계 내 기업의 성장성과 그에 맞는 구성원들의 열정이 있음  다만 군대식문화 존재',
#  '성장하고 있는 그래서 성장통 겪는 스타트업',
#  '사람이 부속품인줄암 걍 밑사람은 회사의 일부 너무 치사하게굼',
#  '직원 복지를 위해 노력을 많이 하는편이며  급여 수준도 높은편',
#  '환경에 관심있는 분들에게는 추천  사회적 가치 지향',
#  '같이 근무하는 사람들이 다들 착함   중소기업치고는 직원들을 챙겨주려는 느낌이 들어서 다니기에 그리 나쁘지 않음',
#  '보험 심사직으로 야근이 많고 직원들 분위기는좋은편',
#  '적은돈 받으면서 합병되길 기다리면 최고의직장 아무도 일을 안하는데 굴러가는게 신기함',
#  '빡세지만 발전하고 있는회사경영진 바뀐후 능력위주 직원채용업무강도있고 스페셜 리스트 요함',
#  '글로벌한 기업 문화를 경험할 수 있는 곳 ',
#  '좋은 워라밸을 가지고 있으나  심히 공기업적인 마인드',
#  '계약직은 그냥 계약직으로 끝낼만한 곳 ',
#  '충남에 연고지가 있는 사람이고 금융 관련 업무를 하고 싶다면 나쁘지 않은 기업',
#  '무난한 편  회사 분위기가 각자 할 일만 하고 서로 터치를 안해서 조용한 편이고 좋다 ',
#  '항후 기업의 발전은 있어보이나 조직문화의 발전이 필요한 곳',
#  '체계가 있음에도 비체계적으로 돌아간다는 점',
#  '첫 회사로서 경험을 쌓는데 나쁘지 않은 기업입니다',
#  '수직적인 기업문화임 연차가 쌓일수록 편한 회사',
#  '일하기 너무 좋고 배려가 기본적으로 갖추어진 직장입니다 ',
#  '젊은 분위기는 좋으나 체계가 부족하고 직원에 대한 배려가 부족함',
#  '업력이 가장 오래된 신탁회사중 하나  자산 9조원의 군인공제회 자회사로 매우 안정적임  이름만 보면 공기업같지만 공기업은 아니고 그렇다고 사기업도 아닌 공기업과 사기업의 면모를 두루 갖춘 회사 ',
#  '워라밸과 높은 연봉 보장하는 공기업 성격이 강한 은행',
#  '외국계 증권사 중에 숨겨져 있는 꿀 직장 중 한곳  정규직으로 들어갈 수 있으면 최고 ',
#  '수직적구조 속에 잇는 수평적구조를 느낄수있다  동종업계 최고는아니지만 SK계열사로 자유로운 분위기속에서 좋은 경험을 쌓을수있다',
#  '최고의 글로벌 IB중 하나이며  Next career 계발에도 좋은 곳입니다 ',
#  '일한 만큼 대우 받는 곳  성과에 대한 보상이 확실한 곳',
#  'VC업계에서 빠르게 성장하고 있는 하우스  투자파트와 관리파트 모두 빠르게 성장중',
#  '스스로 조절이 불가능한 업무량  고객들과 직접적인 통화는 일상 ',
#  '본인 스스로나 회사나 앞으로 성장하기엔 글쎄요',
#  '부동산 자산운용업의 본질을 이해 못하는 회사 모회사 삼성생명의 정치 수단 그 이상 이하도 아님 단 운용업 진출  워라밸 측면에서는 괜찮다 ',
#  '많은 기회가 열려있는 곳이며 안좋은 사람들은 다 내보내졌다 생각됌',
#  '나름 괜찮고 타 보험사에 비하면괜찮음 대신 지사장을 잘만나야함  지사장 중에 박씨는 믿고 걸러야함 ',
#  '일반적인 손해사정법인과 일에서는 크게 다르지않으나 윗사람때문에 스트레스 받을 수 있음',
#  '계속 반복되는 업무  한사람에게만 쏟아지는 업무',
#  '근무부서에 따라 다르겠지만 잘만나면 좋은사람들과 일할수있음',
#  '업종이 다양해서 경력쌓기는 좋음   회사내 분위기는 다들 자유롭고  서로 서로 친해서 좋음  단점이 장점만큼 큰회사',
#  '그냥저냥 좋지도 그렇게 나쁘지도 않은 곳그렇지만 퇴사는 지능순',
#  '양천지사 지사장은 보험 설계사들 개개인에게 부당한 대우를 한다',
#  '직원들에게 많은걸 요구하는 기업임  엑셀을 잘해야함  엑셀도사가 존재',
#  '올라갈 욕심없으면 상관없으나 욕심있으면 포기',
#  '업권 대비 낮은 연봉  타이트한 인력 운용  부서에 따라 워라밸 천차만별',
#  '너무힘든곳 일은모두미루고책임은안지고 하는사람만계속일하는곳  ',
#  '간섭안받고 조용히 개인 일만 하고싶은분들에게 추천하는 곳',
#  '앤알에서 1년만 일하면 어느회사든지 살아남는다  가소롭다 ',
#  '제대로 일을 배울 수 있는곳  A부터 Z까지 알고 싶다면 추천',
#  '사람들이 왜 나가는지 이해 못함  잘못된 일이 있으면 무조건 직원들탓임 열정없고 끈기없다 생각함  사람들이 저정도로 계속 나가면 본인이 문제가 있다는 걸 인지할줄 알아야하는데 절대 절대 직원들 탓임',
#  '회사의 사내정치로 인해 실적이 떨어지는 팀은 괴롭다 ',
#  '신입들은 경력만 쌓고 일해도되는 회사입니다정말 경력만 쌓는회사',
#  '회사 분위기는 좋아보임 구내식당 밥 괜찮음',
#  '경영진 교체 이후 최근 변화를 긍정적으로 볼 수 있는 곳   카카오페이 금융자회사   최근에 금소법으로 인해 많이 거론됐던 그 회사 ',
#  '현대해상의 자회사  일은 힘들지만 그만큼 연봉이 높은곳',
#  '높은 초봉으로 이루워지는 안정적인 직장입니다  삼성동에 본사가 있으며  착한일을 하며 돈을 버는 좋은 회사입니다 ',
#  '부바부겠지만 사내 분위기는 대체로 좋은편  성과 지향적인 사람들에겐 좋은 곳',
#  '본사에 비하면 작은 사무소지만 세계적 기업이라는 자부심이 있다 ',
#  '중소기업으로 보면 좋은 회사  하지만 그 이상을 보고 바라 보면   글쎄',
#  '일이 너무 많음  프론트는 그게 커리어로 간다지만   백옵 사무직 은 말 그대로 빛 좋은 개살구',
#  '일할 때 담당자 분들이 좋아서 잘 다녔습니다 ',
#  '부서별로 분위기가 다르지만 업무강도가 높지않음',
#  '자산규모가 상당히 가파르게 상승하는 회사이지만  부실하지 않음  상당히 안정적 ',
#  '일 배우기 좋고 급여 높고 이상한 사람 없음',
#  '계속적 인수과정을 거치는 어려움이 있지만 전반적인 근무는 만족함',
#  '사람의 시간을 생각하지 않는 악덕기업  근무 시간이 상상을 초월함   아침 8시부터 저녁 8시 이상까지 근무 시간 부과  야근에 대한 appreciation   수당도 제대로 없다 ',
#  '계리사로서 경력을 쌓고 싶다면 좋은 직장임  전문성을 빠른 시간내에 키울 수 있고 몸값을 올릴 수 있는 최고의 직장임  이직도 잘되고 보험회사에서 스카웃 제의도 많음  단  상품개정시즌 등 업무집중기인 3 4개월 동안은 살인적인 업무량을 감수해야함  그렇다고 회계사처럼 업무비수기에 놀수있는건 아님  보험업계 관계자와의 커뮤니케이션도 중요한데 갑도 아니고 을도 아니기 때문에 업무하는데 어려움이 많음  그러나 좋은 연봉  상대적으로 교양있고 배운 동료직원들 속에서 대우받으며 직장생활 할 수 있는 곳 ',
#  '일한만큼 보상받을 수 있지만 일하기가 어려움',
#  '커리어를 쌓기에 너무나도 좋은 곳이며  실무를 제대로 배울 수 있는 곳이다',
#  '금융업도 아니고 판매업도 아니고 제조업도 아니고 시골에 조합 만들어서 설립한거랑 다를게 없다 기업은행 노조가 판을 침 노조땜에 뭐가 안됨',
#  '젊은기업의 장점을 가지고 있는 기업이다  좋았다',
#  '현직자들이 만족하는 금융계 최고의 직장가족같은 분위기와 좋은 기업 문화높은 연봉과 국내 최고의 복지를 갖춘 곳',
#  '임시공휴일 포함 빨간날쉬고 업계 최대연봉  보수적인분위기  기혼여성에게는 좋은 일터',
#  '안정적이지만 자기발전은 부족할수있다  기업문화가 보수적 이다 ',
#  '적은연봉 과도한업무  특정 부서에 업무과중되나  해결책마련해주지않음 ',
#  '진짜 오래된 회사 문화건 사람이건 회사자체건 싹다 오래됐다 ',
#  '은행 쉴 때 쉬므로 빨간날은 다 쉼  그런 점에서는 좋으나 업무강도는 확실히 높음  학력도 고졸이상이라면 지원가능  입사 절차도 쉽기 때문에 채용이 금방되나 그만큼 퇴사율도 높음  멘탈이 강한 사람이라면 다니는데 큰 문제 없음 ',
#  '바닥 중의 바닥인데 심지어  블랙리스트  인 기업',
#  '야근이 많다  업종이 다양하지 않아 여러 업종을 관리해보기 어렵다 ',
#  '액셀러레이팅  보육  투자 등 다양한 업무 경험 가능',
#  '그냥 그럼   보수적인 사람들 조직자체가 이상함 별로임',
#  '자유롭게 일할 수 있는 곳  다만 개인역량의 성장 가능성은 오로지 개인에게만 달려있음',
#  '영어 회화 가능자와 펀드 관련 지식을 기본적으로 가진 사람에게 추천',
#  '사람들은너무많고 옆에부서에서 떠드는소리 업무소리 다 들린다',
#  '빡센곳 일이많고 요구사항이많다 문화가 독특하다',
#  '신의직장은 옛말  가늘고 길게 다니고 싶다면 최적',
#  '지금은 모르겠고 예전에 우리금융지주 밑에 있던 시절은 노조원들의 천국',
#  '서면에 위치해있어 위치가 좋아 출퇴근하기 좋은 회사 업계특성상 힘들지만 초반에 배우기 좋은 회사',
#  '각 분야의 스페셜리스트들이 모여있는 곳  그리고 나가는 곳',
#  '초반에는 힘들었지만 지금은 자리 잡아 가는 AC 중에는 탑클래스',
#  '미국 Top 은행 중 한곳에서 일해보는 경험은 그 자체로 나의 가능성을 넓혀주는 기회를 주었습니다 ',
#  '인지도  커리어 면에서 최고의 회사  똑똑하고 능력있는 사람들과 함께 근무할 수 있는곳',
#  '우수한 인재  나이스한 근무환경  우수한 급여 및 뛰어난 재직 안정성이 한데 모인 작지만 강한 금융공기업',
#  '삼성그룹을 등에 업고 떵떵거리는  고인물들 수준은 중소기업인 회사',
#  '보여주기 행사를 위해 직원들을 희생시키는 회사',
#  '작은 조직의 한계가 뚜렷한 기업으로 큰 발전은 기대하기 어려우나 소소히 근무하기에는 괜찮을듯 마음은 비우고 ',
#  '금융업이라 어쩔 수 없는 보수적인 문화라지만 너무나 도가지나치게 보수적',
#  '업무분위기는 괜찮지만   직원들 연봉에 기준이없는 회사',
#  '보지도 가지도 말아야 할 곳  지인이 간다면 뜯어 말리겠다 ',
#  '연봉보다 편안한 직장에서 일하길 원하시는 분들이라면 추천  하지만 연봉이좀 많이 짭니다',
#  '체계가 없으며 위에서 하고 싶은대로 하는 회사 ',
#  '서로 심하게 터치하거나 간섭하는 분위기는 아니지만 그렇다고 편한 분위기도 아님  옛날 특유의 금융업 문화 있음  사라지는 산업도 아니지만 성장하는 산업도 아님  경영지원 팀은 잡일이 많음 ',
#  '목적의식이 생기지않고 발전이없는회사느낌복지가 좋은것도아니고 일이엄청힘든것도아니지만 좋은점이딱히 없음',
#  '알바인데도 일이 너무 많음  퇴근시간까지 꾸역꾸역 메일 넣어줌 알바조차 퇴사자가 넘쳐나서 그 몫까지 다 쳐내야함',
#  '국내 Private Equity 또는 Venture Capital 중 역사 및 펀드 규모 측면에서 상위 투자사',
#  '손해사정사 특성상 평가사가 아닌 사무직은 높은 보수를 기대하기 힘듦',
#  '인원대비 많은 업무량  타사대비 낮은 연봉인상률과 급여',
#  '나름 다닐만했던 회사  좋은 추억 만들고 갑니다',
#  '변화의 바람 모색  대표 나름의 카리스마가 있으나 감각도 있음  조용히 살면 국수처럼 살수있음 ',
#  '워라밸 좋음 연봉 적음 자유로운 출퇴근   합니다 ',
#  '전통적 금융 브로커 산업에서 전통적 방식으로 운영되는 기업   결코 좋은 의미의  전통적 이 아니라는 게 중요',
#  '너무 빡세다 일이 쉬는시간이 없음 눈치 보임 일이 너무 긴장됨',
#  '유럽의 최고 은행인 BNPParibas의 보험 회사로 한국의 신한은행과 합작해서 만든 보험회사임  프랑스 문화를 접하고 글로벌 회사에 근무를 원하 분이라면 도전해보시길',
#  '개인적분위기에 매우 조용함 일이 많진 않음',
#  '시스템 없고 관리가 안됨 커리어 개발 불가능한 회사라고 보면됨',
#  '분위기가 지점마다 다름 점바점 지점을 잘 만나야 함 중앙회가 일을 대충함',
#  '여가시간이 필요없고 욕 듣는 걸 좋아하며 돈에 구애받지 않는 직장을 원하신다면 적합한 직장입니다 ',
#  '평생 안정적으로 다니기 좋은 회사특히 여자들이 다니기좋은회사욕심있는분은 비추천',
#  '위로 올라갈수록 이상해지는 곳이지만 짧게 다니기엔 나쁘지 않다',
#  '위계질서 쩌는 곳  20대 초반 젊은 친구들이 몇달 먼저 들어왔다고 꼰대짓 하는게 문화인 회사',
#  '체계적이고 직원들간의 소통이 잘되고 분위기가 좋음',
#  '다양한 경험을 쌓을 수 있고 그에 맞는 권한이 주어짐',
#  '보수적 실적에 대한 압박  이런 것들이 있음 1금융권과 차이가 있음 각 지역별 금고 규모에 따라 업무강도 실적에 대한 차이가 있음',
#  '전반적으로 큰 이슈업이 운영중인 금융사',
#  '젊은 사람들이 재밌게 일하기를 원했는데 결론적으로 그렇지 못했던 곳',
#  '내가 아무 생각없이 정년까지 다니고 싶으면 다녀야하는 회사',
#  '고객센터 상담원 수가 턱없이 부족함   기존에 있는 상담원들은 점점 지쳐감',
#  '보람차게일할수있음  성과급으로 보상하는편여의도위치해서출퇴근용이',
#  '많이 알려져있어서 사람들이 잘 알고 있음',
#  'KB금융그룹의 계열사 중에서 업계순위가 낮은 편이지만 집중 투자하고 있으므로 성장가능성은 크다고 생각됨',
#  '근로환경이 매우 열악하며 근무 강도와 압박도 심하지만 급여는 그닥인  회사',
#  '직원을 개로 앎  첫출근해서 1달이 다되어서야 계약서 작성함   절대로 기업 사업하는 대표는 아님   예전 현대차 영업사원할 때 마인드를 그대로 갖고 있으면서 직원들을 무보수 영업사원으로 봄',
#  '경영진분들은 뭔가 해주려고 하는 것같은데 한두명이 분위기 흐림 ',
#  '워라벨 우수한 회사  단 계약직은 정규직 전환이 어렵고 장기근속자들이 많아 인사적체가 심함 ',
#  '체계가 없음직원이 자주 바뀜회식 좋아하는편젊은 꼰대가많음',
#  '은행원이라고 생각하지마세요  돈 많이 주지만  돈 많이 주는데는 이유있어요 ',
#  '전형적인 가족회사   신입인데도 거래처를 너무 많이 받아 힘든 회사',
#  '그냥 부모님 뭐하시는지 돈 많으신지 가장 궁금해 하던 거 같음',
#  '별점 최저가 하나인데  별 하나도 아까움  취준하시는분들 제발 취업어렵다고 여기 지원하지 말고 그냥 다른데가세요 ',
#  '기업 문화  사람들  사무실  복지 다 좋았었다  다만  대표의 횡령으로 하루아침에 사라진 회사',
#  '시설도 나쁘고 정말 나이든 분들의 갑질의 문화 최고죠',
#  '복지도 들었던 것이랑 다르고 근무시간에 비해 연봉이 낮은곳 ',
#  '전형적인 중소기업이다  코딱지만한 회사에서 무슨 정치질을 그렇게 하는지 모르겠다 ',
#  '칼퇴는 보장되는 금고  공제가 중요한 금고  지점을 계속 냄 돈이 많은가봄  직원한테 써주지 ',
#  '수평적인 커뮤니케이션 편하게 일할수 있는 기업  출퇴근이 자유롭슴',
#  '자유롭고 편안한 분위기로 본인의 역량에 따라 평가 받을수 있음',
#  '기계처럼 타자를 치고 있는 내 모습을 확인 할 수 있는 곳',
#  '다양한 벤처 스타트업 기업에 선한투자를 통해 창조경제에 이바지 하고 있는 투자기업',
#  '열심히 일한만큼 성과를 볼 수 있는곳 자유로운 분위기',
#  '기업리뷰를 쓰기위해 별하나줘야된다는게 아까울지경임',
#  '정말 군대식 분위기 조직생활에 질려 버리게 하는 회사 입니다 ',
#  '사람이 배운만큼 내뱉는다고 잘 배우신 분이셔서 직원들에게 좋은 말 해주고 좋은 말로 돌려받네요  ',
#  '다양하게 배울 수는 있지만 체계가 잘 안잡혀있다',
#  '진짜별로   금융권이나 직원에 대한 처우가 중소기업수준임   편하게 다니실분   ',
#  '회사 연봉도 타사 대비하위 전산노후 심함  사람도별로인집단',
#  '부서마다 분위기 대체적으로 좋으며 연봉  복지도 거의 최고 좋은 수준이었음',
#  '워라밸은 뛰어나나 차별이 난무하는곳  파견직이나 계약직으로는 입사하면 안되는곳',
#  '그냥 별로임  월급 너무 적음  인센제인데 인센 자체가 너무적음',
#  '한국 보수적인 회사가 글로벌 외국 회사처럼 문화를 바꾸려는 중간단계적 과도기를 경험할 수있었다 ',
#  '수평적 구조로 변해가고 있는 중이며  워라벨이 좋게 변함',
#  '비록 급여가 동종 타사에 비해 높진 않았으나 기업 문화와 수평적 의사 결정 구조 등 외국계 기업이 갖는 특징들을 가지고 있던 정말 괜찮은 회사였으나 현재 많이 변질되어 국내사처럼 되고 있음',
#  '이직이 잦은 금융계에서 신영증권은 모든 직원이 정규직일 정도로 안정적이다  하지만 어느 증권사와 마찬가지로 업무 시간이  많고 안정적인만큼 급여도 남들이 생각하는 것만큼 높지않다 ',
#  '지금은 합병됐지만 아주보람찬곳 사람들도 좋음 잘챙겨줌 사회생활 배움',
#  '생각했던 것보다 즐거웠고 재밌었지만 조금 많이 힘들었던 곳',
#  '업무능력은 전형적 외국계  미국계 회사 분위기는 완전 국내 꼰  집단',
#  '계약직이더라도 대우해주고 복지가 좋았고 다른 터치없이 좋았다',
#  '성장하는 면세사업에서 다양한 브랜드를 다루고 있는 브랜드 뒤의 브랜드 ',
#  '무난하게 다닐 수 있으나 일한 기간이 물경력이 될 가능성이 높음  추천하고 싶지는 않은 기업 ',
#  '업무는 힘들지만  보상이 따르는 편   그래도 사람들이 좋아 다닐만 함',
#  '아주아주 좋은듯하지만 오지게 그만두기 힘든회사  고소한다고 합니다  보통 그만둔다하면',
#  '직원에 대한 존중이 잘 이뤄진 회사 ',
#  '환경이 중요시 되면서 더욱 성장할 것으로 보입니다  아직은 조금 정체되어있는 느낌입니다',
#  '워라밸 좋아요  가족적인 분위기  편하게 다니기 좋음 ',
#  '말만 세무사 사무실이고 서울지점에있다가 인천지점으로 사무실이전 거래처 주 업무 재가장기요양센터',
#  '자신이 맡은 역활만 하면 된다   더 많은 것을 기대하지도 않고 하지 않아도 되었던것으로 기억',
#  '아직 사회적편견을 이겨내기 쉽지않은 회사  강한 업무강도로 고학력자 이 퇴직 잦은회사 ',
#  '배상책임의 모든면을 배우기에는 확실한 회사',
#  '자산운용이라는 가라앉는 시장에서 더욱 더 가라앉는 회사 ',
#  '금융쪽 치고 막 엄청나게 치열한 분위기는 아니었다  주변 인프라가 좋다 ',
#  '성장하는 수입차 시장과 해당 브랜드에 따라 급성장을 하고 있는 전망좋은 알짜 회사  하지만 글로벌 프로세스가 너무 많음 ',
#  '도태한 인생을 느낄 수 있는 곳  욕심 진급바램 없이 다닐 수 있는 곳',
#  '연봉이 그대로인 회사   워라밸은 좋은회사 장단점이 분명',
#  '본인이 보험 심사업무가 잘 맞는다면 괜찮음  경력주의직업인 것 같음 ',
#  '보수적인 기업문화로 고인물이 많아서 조금 숨막히는 느낌',
#  '분위기가 무겁고 교육이 그닥 귀에 안 들어왔어요 그래서 딱히',
#  '조선의 이름은 달고 있지만 독립회사로 조선과는 별개로 운영되는 회사임',
#  '사무실이 깔끔한 회사 구내식당이 있어서 좋았음 업무 만족도는 낮았지만 야근이 적어서 좋았음',
#  '핀테크 금융에 대한 다양한 테스트를 했던 팀  테스트의 결과까지 가는데는 어려움이 많았던 팀',
#  '역대 최악의 기업  내일 망해도 이상하지 않을 곳',
#  '도태되어있다는 느낌이 매우강함  규모만 늘리려는 경영진의 문제가 보임  조금 개선되거나 바뀔 필요가 있어보인다',
#  '별점 하나 주기에도 아까운 회사  인생허비하고 싶으면 입사하기를 추천 ',
#  '산업단지 분양대행 업체로 여러곳의 분양대행 사무실이 있어요',
#  '최악입니다 이런 회사를 다닌 시간이 아깝습니다   다시생각하세요',
#  '은행업종에 취업하고 싶으나 1금융권에 들어가기 너무 힘들다고 생각하면 추천합니다 ']

# %%
bank= append(reviews_2)
bank
# Out:
# [['독립', '소신', '운용', '점', '평가', '함', '판교', '위치', '주변', '환경', '편임'],
#  ['모든', '문화', '예술', '공공기관', '명감', '곳'],
#  ['실제',
#   '업무',
#   '사람',
#   '일',
#   '체계',
#   '나머지',
#   '업무',
#   '관련',
#   '신경',
#   '함',
#   '직원',
#   '보호',
#   '회사',
#   '역할',
#   '부족함'],
#  ['서류', '작업', '매우', '보수', '기업', '것', '시도', '기존', '방식', '고수', '것', '선호'],
#  ['사원', '대리', '인사', '복장', '지적', '태강', '학교'],
#  ['야근', '휴가', '회식', '일'],
#  ['그냥', '회사', '발전', '가능성'],
#  ['금융',
#   '그룹',
#   '열사',
#   '관리',
#   '생각',
#   '야근',
#   '인사',
#   '평가',
#   '또한',
#   '제대로',
#   '생각',
#   '수직',
#   '학교'],
#  ['일단',
#   '이',
#   '회사',
#   '손해',
#   '정업',
#   '애초',
#   '발',
#   '추천',
#   '자기',
#   '만큼',
#   '돈',
#   '버',
#   '인',
#   '센티',
#   '브',
#   '제라',
#   '밥',
#   '시간',
#   '화장실',
#   '시간',
#   '기계',
#   '일만',
#   '돈',
#   '조기',
#   '출근',
#   '야근',
#   '거의',
#   '필수',
#   '스펙',
#   '일',
#   '추천',
#   '무',
#   '스펙',
#   '입사',
#   '가능',
#   '대신',
#   '경력',
#   '개발',
#   '기일',
#   '사회',
#   '사람',
#   '추천'],
#  ['퇴근', '시간', '생각', '가도', '회사', '단', '퇴근', '시간'],
#  ['분위기', '보수', '남성', '편이', '여성', '업무', '환경', '임'],
#  ['근무', '환경', '복지', '및', '근무', '형태', '움'],
#  ['개인', '역량', '잘만', '발휘', '급여', '직장'],
#  ['장기', '근속', '사원', '곳', '직원', '곳', '본인', '업무', '외', '업무', '새', '시킴'],
#  ['준공', '기업', '성격', '회사', '정년', '보장', '해도', '과언', '공무원', '마인드', '수'],
#  ['개인',
#   '역량',
#   '땐',
#   '그',
#   '회사',
#   '비교',
#   '수',
#   '인',
#   '구조',
#   '직원',
#   '회사',
#   '이',
#   '부분',
#   '정말',
#   '리',
#   '스펙'],
#  ['직원', '복지', '회사', '비용', '관리', '노력', '성장', '가능성', '회사'],
#  ['취준', '노력', '직무', '전문성', '연봉', '상', '승률'],
#  ['공기업', '이미지', '사회', '복지', '업무', '수행', '때문', '보람'],
#  ['모로', '회사', '변화', '시장', '투자자', '니즈', '시', '부응', '어려움', '처함'],
#  ['커리어', '도움', '감정', '수'],
#  ['가뜩이나', '일', '텃세', '무엇'],
#  ['외관',
#   '보고',
#   '가면',
#   '근무',
#   '환경',
#   '놀람',
#   '시스템',
#   '낙후',
#   '신규',
#   '시스템',
#   '기술',
#   '제안',
#   '해도',
#   '도통'],
#  ['평이', '정도', '스스로', '사람', '일부러', '나름', '팀', '움'],
#  ['일', '늘', '인원', '일', '사람'],
#  ['은행원',
#   '보지',
#   '곳',
#   '이',
#   '곳',
#   '은행',
#   '모두',
#   '대표',
#   '개인',
#   '비서',
#   '곳임',
#   '직급',
#   '성희롱',
#   '폭언',
#   '왕따',
#   '욕설',
#   '비방',
#   '난무',
#   '전쟁',
#   '터',
#   '눈치',
#   '보기',
#   '누구',
#   '하나',
#   '직원'],
#  ['사람', '대한', '기본', '배려', '회사', '퇴사', '한지', '트라우마'],
#  ['직원', '소모품', '최악', '회사', '못', '일', '것'],
#  ['겉보기', '그', '실속', '빛', '개살구'],
#  ['소규모', '회사', '주먹구구', '회사', '업무', '회사'],
#  ['정규직', '계약', '직', '인센티브율', '다른', '증권사'],
#  ['그룹',
#   '문화',
#   '상하',
#   '문화',
#   '화기',
#   '애애',
#   '분위기',
#   '로써',
#   '일',
#   '수',
#   '회사',
#   '비교',
#   '차별',
#   '업무',
#   '불이익',
#   '등'],
#  [],
#  ['하루하루', '것', '수', '회사'],
#  ['야근', '문화', '급여'],
#  ['과거', '최악', '중', '시간', '더', '듯'],
#  ['비용', '절감', '영업', '확장', '추진', '방향성', '회사'],
#  ['업무', '고객', '스트레스', '채권', '팀', '실적', '등', '업무', '스트레스'],
#  ['과거',
#   '미래',
#   '패러다임',
#   '속',
#   '은행',
#   '안정',
#   '보수',
#   '운영',
#   '은행',
#   '행',
#   '계속',
#   '최고',
#   '은행',
#   '고함'],
#  ['역시', '삼성', '계약', '직', '대우', '돈', '줌', '그', '돈', '다른', '곳', '못'],
#  ['서울', '정년', '안정', '급여', '일', '수', '곳'],
#  ['실적', '압박', '곳', '정규직', '비정규직', '차이'],
#  ['대의', '리더쉽', '밑', '일', '원', '수', '곳', '다만', '번', '아웃', '조심'],
#  ['계속',
#   '회사',
#   '사람과',
#   '일',
#   '수',
#   '회사',
#   '주식',
#   '편중',
#   '수익',
#   '구조',
#   '반드시',
#   '극복',
#   '나가야',
#   '사안'],
#  ['사람', '기', '고민', '기업'],
#  ['직장',
#   '삶',
#   '올인',
#   '취미',
#   '생활',
#   '수',
#   '정년',
#   '후',
#   '노후',
#   '연금',
#   '안정',
#   '삶',
#   '정도',
#   '보장',
#   '곳'],
#  ['입사',
#   '보장',
#   '복지',
#   '안정',
#   '급여',
#   '금융',
#   '공기업',
#   '국책',
#   '은행',
#   '프라이드',
#   '덤',
#   '반대',
#   '본인',
#   '때',
#   '조직'],
#  ['여러', '증권', '비교', '때', '상대', '안정', '회사'],
#  ['글로벌', '최고', '자산운용', '사', '근무', '자부심', '수'],
#  ['외국', '금융', '기업', '아주', '징작', '동료', '컨택'],
#  ['복지', '연봉', '편입', '니'],
#  ['최근',
#   '기업',
#   '문화',
#   '회사',
#   '워',
#   '중',
#   '과거',
#   '비',
#   '정말',
#   '업무',
#   '체계',
#   '직원',
#   '상호',
#   '존중',
#   '문화',
#   '만들기',
#   '위해',
#   '노력',
#   '중임'],
#  ['영업', '현장', '업무', '경험', '제대로', '수', '곳'],
#  ['명절', '선물', '처음', '진짜'],
#  ['기독교', '회사', '강제', '예배', '참석', '회사'],
#  ['전체', '분위기', '화목', '출근', '퇴근', '회사'],
#  ['분위기', '일', '승진', '및', '연봉', '동결'],
#  ['야망', '기회', '곳', '중책', '중', '리더십', '분'],
#  ['금융', '그냥', '인', '내외', '사업', '기업'],
#  ['직원', '간', '합', '점점', '군기', '문화'],
#  ['디자인', '대한', '요구', '야근', '경험'],
#  ['정말', '효율', '일', '조직', '성과', '업무', '강도', '과'],
#  ['최근', '성장', '세', '우량', '서울', '자산', '규모', '위', '신협'],
#  ['꿈', '광주', '살', '직장'],
#  ['근무', '환경', '수준', '임', '일', '크게', '것'],
#  ['그냥', '시니어', '위', '회사', '임', '주니어', '디딤돌', '생각', '이직', '답임'],
#  ['근무', '환경', '일만', '꽤', '회사', '생활', '수', '곳'],
#  ['사람', '일', '추천', '사람', '사장', '만날', '기회'],
#  ['분위기', '수평', '의사소통', '사내', '문화'],
#  ['가장', '가장', '증권사'],
#  ['복지', '워', '밸', '중'],
#  ['영업', '자체', '대우', '회의', '및', '여타', '영업직', '퇴근', '시', '회사', '재', '방문', '거의'],
#  ['직장', '생활', '곳', '저축은행', '중간', '포지션'],
#  ['기업', '문화', '단', '이', '회사', '정도', '막대', '거나', '주먹구구', '때'],
#  ['욕심', '무난', '수', '회사'],
#  ['복지', '직원', '끼리', '대감', '편'],
#  ['업계',
#   '안',
#   '편이',
#   '성장',
#   '속도',
#   '의욕',
#   '모두',
#   '자리',
#   '업무',
#   '체계',
#   '시',
#   '야근',
#   '주말',
#   '출근'],
#  ['체계', '사', '갈라', '느낌', '휴가', '사용', '가능'],
#  ['주먹구구', '기업', '운영', '달', '달', '보직', '이동', '제발'],
#  ['건설', '사', '너', '탑', '다운', '명령', '구조', '사업', '구조', '확장', '가능성', '불확실'],
#  ['신입', '일', '곳', '다만', '대리', '과장', '진급', '중간', '직급', '메리트', '별로', '듯'],
#  ['일반', '보험', '대리점', '대신', '더', '보험', '대리점', '수', '꼭', '확인', '권유'],
#  ['무조건', '실적', '인간관계', '회사', '성적'],
#  ['문서', '정리', '사무', '보조', '일', '경우', '신체', '업무', '스트레스', '약간'],
#  ['회사', '위', '전략', '영진', '포장', '장사꾼', '일', '뿐'],
#  ['변화', '기업', '욕심', '롱런', '기업'],
#  ['스타트업',
#   '기업',
#   '특성',
#   '분위기',
#   '좀',
#   '폐쇄적',
#   '분위기',
#   '대부분',
#   '지인',
#   '임',
#   '직원',
#   '형',
#   '동생',
#   '사람',
#   '수평',
#   '구조',
#   '기업',
#   '문화',
#   '부문',
#   '수직',
#   '기업',
#   '문화',
#   '임',
#   '여의도',
#   '위치',
#   '카페',
#   '가장',
#   '장점'],
#  ['대표', '열정', '현실', '조언', '사장'],
#  ['외국', '기업', '국내', '보험사', '관리자', '기회', '혜택', '기회', '기업'],
#  ['공공기관',
#   '한계',
#   '종업',
#   '급여',
#   '및',
#   '복지',
#   '일과',
#   '삶',
#   '균형',
#   '정도',
#   '수',
#   '업무',
#   '여성',
#   '일',
#   '회사',
#   '임'],
#  ['부동산', '대체', '투자', '함', '인턴', '잡무', '기본', '일'],
#  ['일', '개인주의', '문화', '발달', '회사', '위치', '회사', '건물', '구성원', '무난'],
#  ['수평', '조직', '문화', '성격', '커리어', '시니어', '인턴', '근무', '최고', '회사'],
#  ['주식', '투자', '기본', '대해', '곳'],
#  ['해외', '스타트업', '지원', '및', '컨설팅', '회사', '분야', '사업', '내용', '접', '수'],
#  ['누구', '사람', '회사', '이', '회사', '추천'],
#  ['외국', '기업', '장점', '두루', '회사'],
#  ['투자자',
#   '사이',
#   '분야',
#   '인력',
#   '배치',
#   '매우',
#   '투자',
#   '기업',
#   '시야',
#   '투자',
#   '경험',
#   '경험',
#   '것'],
#  ['지원', '회사', '충성', '강요', '충성', '심', '회사'],
#  ['투자', '대한', '업무', '몇', '회사', '중', '하나'],
#  ['안정', '시스템', '그', '지역', '꽤', '직장'],
#  ['안정', '정년', '보장', '조합원', '자녀', '득실', '과장', '꿈', '과장', '돈좀', '범'],
#  ['경력', '계약', '직', '및', '인턴', '경력', '매우', '곳', '편'],
#  ['화재',
#   '자회사',
#   '타이틀',
#   '벗',
#   '삼성',
#   '계열',
#   '사의',
#   '복지',
#   '문화',
#   '곳',
#   '연봉',
#   '종업',
#   '중',
#   '상위',
#   '경력',
#   '직도',
#   '회사',
#   '업',
#   '무량',
#   '시간',
#   '좀더',
#   '지나',
#   '안정',
#   '시기',
#   '균형',
#   '수도'],
#  ['업무', '크게', '장애', '사고', '수습'],
#  ['경력', '자유', '로움', '돈', '보고', '오지', '말기'],
#  ['급여', '워', '라벨', '면', '제주', '직장'],
#  ['회사', '주주', '계속', '변화', '성장', '가능성', '곳'],
#  ['회사', '적응', '액션', '등', '자신', '어필', '함'],
#  ['최초',
#   '연락',
#   '집',
#   '코리아',
#   '곳',
#   '이력서',
#   '연락',
#   '면접',
#   '때',
#   '복장',
#   '청바지',
#   '티',
#   '정말',
#   '청바지',
#   '티',
#   '분',
#   '정장',
#   '면접',
#   '차장',
#   '대리',
#   '면접',
#   '관',
#   '생각',
#   '테',
#   '질문',
#   '다른',
#   '면접',
#   '합격',
#   '일',
#   '문제',
#   '시설',
#   '분위기'],
#  ['업계', '내', '기업', '성장', '성과', '그', '구성원', '열정', '다만', '군대', '문화', '존재'],
#  ['장통', '스타트업'],
#  ['사람', '부속품', '줄암', '밑', '사람', '회사', '일부', '굼'],
#  ['직원', '복지', '위해', '노력', '편이', '급여', '수준', '편'],
#  ['환경', '관심', '분', '추천', '사회', '가치', '지향'],
#  ['근무', '사람', '중소기업', '직원', '느낌'],
#  ['보험', '심사', '직', '야근', '직원', '분위기', '편'],
#  ['돈', '합병', '최고', '직장', '아무', '일'],
#  ['빡세',
#   '발전',
#   '회사',
#   '영진',
#   '후',
#   '능력',
#   '위주',
#   '직원',
#   '채용',
#   '업무',
#   '강도',
#   '스페셜',
#   '리스트',
#   '함'],
#  ['글로벌', '기업', '문화', '경험', '수', '곳'],
#  ['워', '밸', '가지', '공기업', '마인드'],
#  ['계약', '직', '그냥', '계약', '직', '곳'],
#  ['충남', '고지', '사람', '금융', '관련', '업무', '기업'],
#  ['무난', '편', '회사', '분위기', '각자', '일만', '서로', '터치', '안해', '편이'],
#  ['항후', '기업', '발전', '보이', '직문', '발전', '곳'],
#  ['체계', '비', '체계', '점'],
#  ['첫', '회사', '로서', '경험', '기업'],
#  ['수직', '기업', '문화', '임', '연차', '회사'],
#  ['일', '배려', '기본', '직장'],
#  ['분위기', '체계', '직원', '대한', '배려', '부족함'],
#  ['업력',
#   '가장',
#   '신탁',
#   '회사',
#   '하나',
#   '자산',
#   '군인공제회',
#   '자회사',
#   '매우',
#   '안정',
#   '적임',
#   '이름',
#   '공기업',
#   '공기업',
#   '기업',
#   '공기업',
#   '기업',
#   '면모',
#   '두루',
#   '회사'],
#  ['워', '밸', '연봉', '보장', '공기업', '성격', '은행'],
#  ['외국', '증권사', '중', '꿀', '직장', '중', '곳', '정규직', '수', '최고'],
#  ['수직', '구조', '속', '수평', '구조', '종업', '최고', '계', '열사', '분위기', '속', '경험'],
#  ['최고', '글로벌', '중', '하나', '계발', '곳'],
#  ['일', '만큼', '대우', '곳', '성과', '대한', '보상', '곳'],
#  ['업계', '하우스', '투자', '파트', '관리', '파트', '모두', '성장'],
#  ['스스로', '조절', '업', '무량', '고객', '직접', '통화', '일상'],
#  ['본인', '스스로', '회사', '앞', '글쎄요'],
#  ['부동산',
#   '자산운용',
#   '업',
#   '본질',
#   '이해',
#   '회사',
#   '모회사',
#   '생명',
#   '정치',
#   '수단',
#   '그',
#   '이상',
#   '이하',
#   '단',
#   '운용',
#   '업',
#   '진출',
#   '워',
#   '밸',
#   '측면'],
#  ['기회', '곳', '사람', '생각'],
#  ['나름', '타', '보험사', '비', '대신', '사장', '잘만', '사장', '중', '박씨'],
#  ['일반', '손해', '정법', '일', '크게', '윗사람', '때문', '스트레스', '수'],
#  ['계속', '반복', '업무', '사람', '업무'],
#  ['근무', '부서', '사람', '일'],
#  ['업종', '경력', '회사', '내', '분위기', '자유', '서로', '서로', '단점', '장점', '회사'],
#  ['저', '곳', '퇴사', '지능', '순'],
#  ['지사', '사장', '보험', '설계', '사', '개개인', '대우'],
#  ['직원', '요구', '기업', '임', '엑셀', '함', '엑셀', '도사', '존재'],
#  ['욕심', '욕심', '포기'],
#  ['업', '대비', '연봉', '타이트', '인력', '운용', '부서', '워', '밸', '천차만별'],
#  ['곳', '일', '모두', '책임', '안지', '사람', '만계', '곳'],
#  ['간섭', '개인', '일만', '은', '추천', '곳'],
#  ['앤알', '일', '회사'],
#  ['제대로', '일', '수', '곳', '부터', '알', '추천'],
#  ['사람',
#   '왜',
#   '이해',
#   '무조건',
#   '직원',
#   '탓임',
#   '열정',
#   '끈기',
#   '생각',
#   '함',
#   '사람',
#   '정도',
#   '계속',
#   '본인',
#   '문제',
#   '걸',
#   '인지',
#   '절대',
#   '절대',
#   '직원',
#   '탓임'],
#  ['회사', '사내정치', '실적', '팀'],
#  ['신입', '경력', '일', '회사', '정말', '경력', '회사'],
#  ['회사', '분위기', '보임', '구내식당', '밥'],
#  ['영진',
#   '교체',
#   '이후',
#   '최근',
#   '변화',
#   '긍정',
#   '볼',
#   '수',
#   '곳',
#   '카카오',
#   '페이',
#   '금융',
#   '자회사',
#   '최근',
#   '금',
#   '법',
#   '거론',
#   '그',
#   '회사'],
#  ['해상', '자회사', '일', '연봉', '곳'],
#  ['초봉', '이루', '워', '안정', '직장', '삼성동', '본사', '착', '한일', '돈', '버', '회사'],
#  ['부바', '사내', '분위기', '대체로', '편', '성과', '지향', '사람', '곳'],
#  ['본사', '비', '사무소', '세계', '기업', '자부심'],
#  ['중소기업', '회사', '그', '이상', '보고', '글쎄'],
#  ['프론트', '그게', '커리어', '간다', '옵', '사무직', '은', '말', '그대로', '빛', '개살구'],
#  ['일', '때', '담당자', '분'],
#  ['부서', '별로', '분위기', '업무', '강도'],
#  ['자산', '규모', '가파르', '상승', '회사', '안정'],
#  ['일', '급여', '사람'],
#  ['계속', '인수', '과정', '어려움', '전반', '근무'],
#  ['사람',
#   '시간',
#   '생각',
#   '악덕',
#   '기업',
#   '근무',
#   '시간',
#   '상상',
#   '초월',
#   '함',
#   '아침',
#   '저녁',
#   '이상',
#   '근무',
#   '시간',
#   '부과',
#   '야근',
#   '대한',
#   '수당',
#   '제대로'],
#  ['계',
#   '리사',
#   '로서',
#   '경력',
#   '직장',
#   '임',
#   '전문성',
#   '시간',
#   '내',
#   '수',
#   '몸값',
#   '수',
#   '최고',
#   '직장',
#   '임',
#   '이직',
#   '보험',
#   '회사',
#   '스카웃',
#   '제의',
#   '단',
#   '상품',
#   '개정',
#   '시즌',
#   '등',
#   '업무',
#   '집중',
#   '기인',
#   '개월',
#   '동안',
#   '살인',
#   '업',
#   '무량',
#   '감수',
#   '함',
#   '회계사',
#   '업무',
#   '놀수',
#   '보험',
#   '업계',
#   '관계자',
#   '커뮤니케이션',
#   '갑',
#   '을',
#   '때문',
#   '업무',
#   '어려움',
#   '연봉',
#   '상대',
#   '교양',
#   '동료',
#   '직원',
#   '속',
#   '직장',
#   '생활',
#   '수',
#   '곳'],
#  ['만큼', '보상', '수', '일', '어려움'],
#  ['커리어', '곳', '실무', '제대로', '수', '곳'],
#  ['금융업',
#   '판매업',
#   '제조업',
#   '시골',
#   '조합',
#   '설립',
#   '거',
#   '기업은행',
#   '노조',
#   '판',
#   '침',
#   '노조',
#   '땜',
#   '뭐'],
#  ['기업', '장점', '가지', '기업'],
#  ['현직',
#   '금융',
#   '최고',
#   '직장',
#   '가족',
#   '분위기',
#   '기업',
#   '문화',
#   '연봉',
#   '국내',
#   '최고',
#   '복지',
#   '곳'],
#  ['임시', '공휴일', '포함', '날쉬', '업계', '최대', '연봉', '보수', '분위기', '기혼', '여성', '일터'],
#  ['안정', '자기', '발전', '기업', '문화', '보수'],
#  ['연봉', '과도', '업무', '특정', '부서', '업무', '과중', '해결', '책', '마련'],
#  ['진짜', '회사', '문화', '건', '사람', '이건', '회사', '자체', '건', '싹'],
#  ['은행',
#   '때',
#   '날',
#   '점',
#   '업무',
#   '강도',
#   '학력',
#   '졸',
#   '상이',
#   '라면',
#   '지원',
#   '가능',
#   '입사',
#   '절차',
#   '때문',
#   '채용',
#   '금방',
#   '퇴사',
#   '율도',
#   '멘탈',
#   '사람',
#   '라면',
#   '문제'],
#  ['바닥', '중', '바닥', '심지어', '블랙리스트', '인', '기업'],
#  ['야근', '업종', '여러', '업종', '관리'],
#  ['액', '셀러', '레이', '팅', '보육', '투자', '등', '업무', '경험', '가능'],
#  ['그냥', '보수', '사람', '조직', '자체', '별로', '임'],
#  ['일', '수', '곳', '다만', '개인', '역량', '성장', '가능성', '개인'],
#  ['영어', '회화', '가능', '펀드', '관련', '지식', '기본', '사람', '추천'],
#  ['사람', '옆', '부서', '소리', '업무', '소리'],
#  ['빡센곳', '일이', '요구사항', '문화'],
#  ['신의', '직장', '옛말', '최적'],
#  ['지금', '예전', '우리금융', '지주', '밑', '시절', '노조', '원', '천국'],
#  ['서면', '위치', '위치', '출퇴근', '회사', '업계', '특성', '초반', '회사'],
#  ['각', '분야', '스페셜리스트', '곳', '곳'],
#  ['초반', '지금', '자리', '중', '탑', '클래스'],
#  ['미국', '은행', '중', '곳', '일', '경험', '그', '자체', '나', '가능성', '기회'],
#  ['인지도', '커리어', '면', '최고', '회사', '능력', '사람', '근무', '수', '곳'],
#  ['인재', '나이스', '근무', '환경', '급여', '및', '재직', '안정', '작', '금융', '공기업'],
#  ['그룹', '등', '떵떵거리', '인물', '수준', '중소기업', '회사'],
#  ['행사', '위해', '직원', '희생', '회사'],
#  ['조직', '한계', '기업', '발전', '근무', '마음'],
#  ['금융업', '수', '보수', '문화', '라지', '도', '보수'],
#  ['업무', '분위기', '직원', '연봉', '기준', '회사'],
#  ['보지', '가지', '곳', '지인', '간다'],
#  ['연봉', '직장', '일', '분', '추천', '연봉', '좀'],
#  ['체계', '위', '회사'],
#  ['서로',
#   '터치',
#   '거나',
#   '간섭',
#   '분위기',
#   '분위기',
#   '옛날',
#   '특유',
#   '금융업',
#   '문화',
#   '산업',
#   '산업',
#   '경영',
#   '지원',
#   '팀',
#   '잡',
#   '일이'],
#  ['목적의식', '생기지', '발전', '회사', '느낌', '복지', '것', '일이', '점'],
#  ['알바', '도', '퇴근', '시간', '메일', '줌', '알바', '퇴사', '그', '몫'],
#  ['국내', '중', '역사', '및', '펀드', '규모', '측면', '상위', '투자', '사'],
#  ['손해사정사', '특성', '평가', '사가', '사무직', '보수'],
#  ['인원', '대비', '업', '무량', '대비', '연봉', '상률', '급여'],
#  ['나름', '회사', '추억'],
#  ['변화', '바람', '모색', '대표', '나름', '카리스마', '감각', '살', '국수'],
#  ['워', '밸', '연봉', '출퇴근'],
#  ['전통',
#   '금융',
#   '브로커',
#   '산업',
#   '전통',
#   '방식',
#   '운영',
#   '기업',
#   '결코',
#   '의미',
#   '전통',
#   '이',
#   '게',
#   '중요'],
#  ['빡세', '쉬는시간', '눈치', '보임', '긴장'],
#  ['유럽',
#   '최고',
#   '은행',
#   '의',
#   '보험',
#   '회사',
#   '한국',
#   '신한은행',
#   '합작',
#   '보험',
#   '회사',
#   '임',
#   '프랑스',
#   '문화',
#   '접',
#   '글로벌',
#   '회사',
#   '근무',
#   '도전'],
#  ['개인', '분위기', '매우'],
#  ['시스템', '관리', '커리어', '개발', '회사'],
#  ['분위기', '지점', '점바점', '지점', '함', '중앙회', '일', '대충', '함'],
#  ['가시', '욕', '걸', '돈', '구애', '직장', '직장'],
#  ['평생', '안정', '회사', '여자', '회사', '욕심', '분', '비', '추천'],
#  ['위로', '곳', '기'],
#  ['위계', '질서', '쩌', '곳', '초반', '친구', '달', '먼저', '꼰대짓', '문화인', '회사'],
#  ['체계', '직원', '간의', '소통', '분위기'],
#  ['경험', '수', '그', '권한'],
#  ['보수',
#   '실적',
#   '대한',
#   '압박',
#   '것',
#   '금융',
#   '차이',
#   '각',
#   '지역별',
#   '금고',
#   '규모',
#   '업무',
#   '강도',
#   '실적',
#   '대한',
#   '차이'],
#  ['전반', '이슈', '업', '운영', '금융', '사'],
#  ['사람', '일', '결론', '곳'],
#  ['내', '아무', '생각', '정년', '회사'],
#  ['고객', '센터', '상담', '수가', '턱', '부족함', '기존', '상담', '원', '점점', '감'],
#  ['보람', '차', '게일', '성과급', '보상', '편', '여의도', '위치', '출퇴근', '용이'],
#  ['사람', '알'],
#  ['금융', '그룹', '계', '열사', '중', '업계', '순위', '편이', '집중', '투자', '성장', '가능성', '생각'],
#  ['근로', '환경', '매우', '근무', '강도', '압박', '급여', '그닥', '회사'],
#  ['직원',
#   '개',
#   '첫출근',
#   '달이',
#   '계약서',
#   '성함',
#   '절대로',
#   '기업',
#   '사업',
#   '대표',
#   '예전',
#   '현대차',
#   '영업',
#   '사원',
#   '때',
#   '마인드',
#   '그대로',
#   '직원',
#   '무보수',
#   '영업',
#   '사원',
#   '봄'],
#  ['영진', '뭔가', '것', '명', '분위기'],
#  ['워', '라벨', '회사', '단', '계약', '직', '정규직', '전환', '장기', '근속', '인사', '체'],
#  ['체계', '직원', '자주', '회식', '편', '꼰'],
#  ['은행원', '생각', '돈', '주지', '돈', '이유'],
#  ['전형', '가족', '회사', '신입', '도', '거래처', '회사'],
#  ['그냥', '부모님', '뭐', '돈', '신지', '가장', '거'],
#  ['점', '최저', '하나', '별', '하나', '움', '취준', '분', '제발', '취업', '여기', '지원', '그냥'],
#  ['기업', '문화', '사람', '사무실', '복지', '다만', '대표', '횡령', '하루아침', '회사'],
#  ['시설', '정말', '나이', '분', '갑', '질의', '문화', '최고'],
#  ['복지', '것', '근무시간', '연봉', '곳'],
#  ['전형', '중소기업', '코딱지', '회사', '무슨', '정치', '질'],
#  ['칼퇴', '보장', '금고', '공제', '금고', '지점', '계속', '돈', '직원'],
#  ['수평', '커뮤니케이션', '일', '기업', '출퇴근', '슴'],
#  ['자유', '분위기', '본인', '역량', '평가'],
#  ['기계', '타자', '내', '모습', '확인', '수', '곳'],
#  ['처', '스타트업', '기업', '투자', '통해', '창조경제', '이바지', '투자', '기업'],
#  ['만큼', '성과', '볼', '수', '곳', '분위기'],
#  ['기업', '리뷰', '쓰기', '위해', '별하나', '임'],
#  ['정말', '군대', '분위기', '조직', '생활', '회사'],
#  ['사람', '직원', '말', '말로'],
#  ['수', '체계'],
#  ['진짜', '별로', '금융', '직원', '대한', '처우', '중소기업', '수준', '임', '분'],
#  ['회사', '연봉', '대비', '하위', '전산', '노후', '사람', '별로', '집단'],
#  ['부서', '분위기', '체적', '연봉', '복지', '거의', '최고', '수준'],
#  ['워', '밸', '차별', '난무', '곳', '파견', '직', '계약', '직', '입사', '곳'],
#  ['그냥', '별로', '임', '월급', '인', '제', '인', '자체', '무적', '음'],
#  ['한국', '보수', '회사', '글로벌', '외국', '회사', '문화', '중간', '단계', '과도기', '경험', '수'],
#  ['수평', '구조', '중이', '워', '라벨'],
#  ['비록',
#   '급여',
#   '종',
#   '사',
#   '기업',
#   '문화',
#   '수평',
#   '의사',
#   '결정',
#   '구조',
#   '등',
#   '외국',
#   '기업',
#   '특징',
#   '가지',
#   '정말',
#   '회사',
#   '현재',
#   '변질',
#   '국내',
#   '처럼'],
#  ['이직',
#   '금융',
#   '증권',
#   '모든',
#   '직원',
#   '정규직',
#   '일',
#   '정도',
#   '안정',
#   '증권사',
#   '마찬가지',
#   '업무',
#   '시간',
#   '안정',
#   '급여',
#   '남',
#   '생각',
#   '것'],
#  ['지금', '합병', '아주', '보람', '찬곳', '사람', '줌', '사회생활', '배움'],
#  ['생각', '것', '조금', '곳'],
#  ['업무', '능력', '전형', '외국', '미국', '회사', '분위기', '완전', '국내', '꼰', '집단'],
#  ['계약', '직', '더라도', '대우', '복지', '다른', '터치'],
#  ['면세', '사업', '브랜드', '브랜드', '뒤', '브랜드'],
#  ['무난', '수', '일', '기간', '물', '경력', '가능성', '추천', '기업'],
#  ['업무', '보상', '편', '사람', '함'],
#  ['듯', '오지', '회사', '보통'],
#  ['직원', '대한', '존중', '회사'],
#  ['환경', '중요시', '더욱', '것', '은', '조금', '정체', '느낌'],
#  ['워', '밸', '가족', '분위기'],
#  ['말',
#   '세무사',
#   '사무실',
#   '지점',
#   '인천',
#   '지점',
#   '사무실',
#   '이전',
#   '거래처',
#   '주',
#   '업무',
#   '재',
#   '장기',
#   '요양',
#   '센터'],
#  ['자신', '역활', '더', '것', '기억'],
#  ['사회', '편견', '회사', '업무', '강도', '고학력자', '이', '퇴직', '회사'],
#  ['배상', '책임', '면', '회사'],
#  ['자산운용', '시장', '더욱', '더', '회사'],
#  ['금융', '쪽', '막', '분위기', '주변', '인프라'],
#  ['수입', '차', '시장', '해당', '브랜드', '급성', '전망', '알짜', '회사', '글로벌', '프로세스'],
#  ['도태', '인생', '수', '곳', '욕심', '진급', '바램', '수', '곳'],
#  ['연봉', '그대로', '회사', '워', '밸', '회사', '장단점', '분명'],
#  ['본인', '보험', '심사', '업무', '경력', '주의', '직업', '것'],
#  ['보수', '기업', '문화', '인물', '조금', '느낌'],
#  ['분위기', '교육', '그닥', '귀', '안'],
#  ['조선', '이름', '달', '독립', '회사', '조선', '별개', '운영', '회사', '임'],
#  ['사무실', '회사', '구내식당', '업무', '만족도', '야근'],
#  ['핀', '테크', '금융', '대한', '테스트', '팀', '테스트', '결과', '어려움', '팀'],
#  ['역대', '최악', '기업', '내일', '곳'],
#  ['도태', '느낌', '매우', '규모', '경영', '진의', '문제', '보임', '조금', '개선', '필요'],
#  ['점', '하나', '주기', '회사', '인생', '입사', '추천'],
#  ['산업', '단지', '분양', '대행', '업체', '곳', '분양', '대행', '사무실'],
#  ['최악', '회사', '시간', '다시', '생각'],
#  ['은행', '업종', '취업', '금융', '생각', '추천']]
