# %%
import requests
import time
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
# 참고 사이트 https://yeo0.github.io/data/2018/09/24/5.-%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9D%B4-%ED%95%84%EC%9A%94%ED%95%9C-%EC%82%AC%EC%9D%B4%ED%8A%B8%EC%97%90%EC%84%9C%EC%9D%98-%ED%81%AC%EB%A1%A4%EB%A7%81/
# 참고 사이트 2 https://hashcode.co.kr/questions/9084/%EC%9E%A1%ED%94%8C%EB%9E%98%EB%8B%9B-%EB%A1%9C%EA%B7%B8%EC%9D%B8-%ED%9B%84-%EC%8A%A4%ED%81%AC%EB%A0%88%EC%9D%B4%ED%95%91-%EB%AC%B8%EC%9D%98%EB%93%9C%EB%A6%BD%EB%8B%88%EB%8B%A4-%E3%85%9C%E3%85%9C

# 로그인 할 url
url = "https://www.jobplanet.co.kr/users/sign_in?_nav=gb"
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'
headers = {'Content-type': 'application/json', 'Accept': 'text/plain', 'User-Agent':user_agent}
login_data = {'user':{'email':'hsmy31@hanyang.ac.kr', 'password':'rhkwpgksmswnd!', 'remember_me':'true'}}
session = requests.session()

# 로그인 실행
login_response = session.post(url, json = login_data, headers = headers)

# %%
# 산업군별 코드 삽입
# 1.정부/공공기관/공기업(1001), 2.은행/금융업(900), 3.솔루션/SI/ERP/CRM(707), 4.네트워크/통신/모바일(704)
# 5.미디어/디자인(800), 6.세무/회계(1004), 7.전기/전자/제어(201), 8.서비스업(100)
def ind_reviews(code):
    url = "https://www.jobplanet.co.kr/reviews?&industry_id=" + str(code)
    response =  session.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    num = soup.find('span', class_='num') # 리뷰 개수 확인
    num = int(num.get_text().strip())
    import math, random
    pages = math.ceil(num / 10)
    page = random.sample(range(1, pages),30)
    reviews = {}
    for i in page: # 페이지를 랜덤으로 하여 300개의 리뷰 추출
        time.sleep(1)
        url = "https://www.jobplanet.co.kr/reviews?&industry_id=" + str(code) + "&page="+ str(i)
        response =  session.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        label = soup.find_all('h2', class_="us_label") # 한 줄 리뷰 추출
        # 추출한 리뷰에서 태그를 제외한 텍스트만 추출하여 labels 리스트에 저장
        labels = [label.get_text().strip() for label in label[:]]
        star = soup.find_all('div', class_="star_score") # 별점이 포함된 div 추출
        # 추출한 div에서 별점을 나타내는 width 속성의 숫자로 된 부분을 stars 리스트에 저장
        stars = re.findall('[0-9]+[.]+[0-9]', str(star))
        # reviews 딕셔너리에 '리뷰: 별점' 형식으로 추가
        for j in range(len(labels)):
            reviews[labels[j][5:-1]] = stars[j].replace('.0','')
    return reviews

# %%
# [미디어/디자인] 산업군의 기업 리뷰 스크래핑
reviews_5 = dict(ind_reviews(800))

# %%
reviews_5
# Out:
# {'소기업. 중소도 아닌 소기업. 가족회사. 방송국이라 하기엔 너무 작은 개인회사': '36',
#  '별점 1도 아까운데..잡플래닛이 사람 여럿살리는 역할하는듯. 이거 보시고 가지마세요 여기. 최악. 고용노동부에 신고 넣었는데 내 앞으로 신고자가 9명이라 그랬음': '36',
#  '즐겁고 쾌할한 회사 분위기에서 온라인마케팅 관련 전반에 대해 배울 수 있는 수 있는 회사': '36',
#  '광고 대행사라는 타이틀을 걸고 있지만, 실질적으로는 광고송출 대행사에 맞는 평가. AE 포지션에서 타 광고 대행사보다 할 수 있는 일이 거의 없다고 봐도 무방.': '36',
#  '개발자가 대우받으며 일할 수 없습니다요': '36',
#  '조직원의 역량을 높여주는 교육 기회를 제공해준다.': '36',
#  '디자인보다는 서류쓰기나 자료조사가 더 많은회사': '36',
#  '연봉이 오르지않는다. 별도의 수당이 없다': '36',
#  '면접때 알 수 없는 질문있었지만 기본적인 질문 했어요.': '36',
#  '빛좋은 개살구.. 되살아날 수 있을까 싶은 대표의 프라이드만 높은 회사': '36',
#  '가족같은 회사로 화목해 보일 수 있고 도가 넘어 보일 수 있다 그래도 디자인 일은 꾸준히 들어와서 신입은 디자인을 많이 해볼 수 있다 그리고 회사전체가 고인물이다': '54',
#  '일에만 집중하고 개인주의적인 성격이라면 좋은 직장\r인간관계 신경쓰는 사람이면  힘든 직장\r     .': '54',
#  '디자인 툴을 사용할 줄 안다면 어려움은 없는 회사.하지만 영업사원 및 클라이언트를 직접 상대해야해서 커뮤니케이션으로 인한 스트레스는 있을 수 있음': '54',
#  '다양한 종합 편성프로그램을 경험할 수 있어서 여러가지 노하우와 경험은 쌓을 수 있음': '54',
#  '실제 배우로서 일했던 썰 풀어드립니다.': '54',
#  '수직 문화, 짠 내 나는 사장님,포폴이 쓸데가 없다작은 회사의 특징. 멋모르는 어린 양들 데려다멀티로 돌리며 모든 예산을 줄이는 곳..?': '54',
#  '뭐하는 회사인지 정체성이 불분명한 회사 이것저것 많이 하긴하는데': '54',
#  '화장품계 벤더업체에서의 큰수준의 모기업을\r가지고있는 회사': '54',
#  '다양한 업무를 접할수 있으며 수직관계가 아닌 수평관계를 유지하기위한 노력을 꾸준히 한다': '54',
#  '정규직으로 들어가 배울게 없는 회사 인생 오점으로남을 회사': '54',
#  '업사이클링을 기반으로하여 폐자원을 활용한 고부가가치 제품을 양산해내는 성장가능성을 기대할 수 있는 기업': '46',
#  '클라이언트는 채용사이트에 올라온것처럼 좋지만, 회사는 그렇지 않다.': '46',
#  '두산인프라코어의 협력업체, 설계도 아니고 디자인도 아니고 업무자체가 애매함': '46',
#  '포스트 중에 복지는 좋은편 같습니다팀원들 분위기도 좋음': '46',
#  '수평적인 분위기에서 다양한 디자인을 배우고 도전해볼 수 있는 회사.': '46',
#  '하나부터 열까지 모든 것이 엉망이었던 회사': '46',
#  '대표님이 좋으시고 편하게 일하기 좋은 곳!': '46',
#  '자유롭고 젊은 느낌은 좋으나 여러가지 아쉬운 점도 많았습니다.': '46',
#  '자유로운 분위기에서 다양한 디자인 경험을 할 수 있는 곳.서로 존중하는 문화가 자리잡혀 있는 곳': '46',
#  '해리 포터 시리즈를 기반으로 여러 도서를 출간하는 탄탄한 출판사': '46',
#  '작은기업이지만 일을 배울수 있었고 미래가 있는거 같아 보였다': '46',
#  '인력에 최저 투자하고 최고치를 뽑고자 했던 곳. 체계가 심히 부족하고 중구난방식 프로젝트 진행.': '46',
#  '지각 안하는건 직원들간의 예의라 해서 절대 용납 못함. 대표가 자기 회사에 대한 애정 크고 프라이드 높음': '46',
#  '전시회사지만 행사용 무대시공이 더 잦은 편': '46',
#  '디자인쪽에서 엄청 힘들게 일해왔던 분들에게는 추천합니다.': '46',
#  '젊은 사람들이 그냥 회사같은 회사 맛보기 느낌으로 다니기엔 괜찮음': '44',
#  '전반적인 온라인 툴을 모두 다루어, 간접적으로 경험할 수 있는 부분이 많다. 사회 초년생이 다니기 좋은 회사': '44',
#  '전통이 있는 에이전시라 클라이언트 축이 좋고, 다양한 문화적 복지도 좋은편. 하지만 역동적이고 크리에이티브한 작업을 하기는 다소 힘든 전통적인 에이전시!': '44',
#  "이름의 환상에 넘어가지 마시라. '방송무대'가 가진 쓸데 없는 자존심만 남아있는 회사.": '44',
#  '야근의 연속, 사람들과의 유대감 제로,': '44',
#  '코로나 시국이 아니었다면 계속해서 성장했을 회사': '54',
#  '자유롭고 벽이없는 분위기 그리고 퇴근도 없다': '54',
#  '인지도 면에서는 장점. 하지만 편집디자인 판에서 인정 받아온 시간이 있는 것이지 현재 진행형이라고 말할 수 있을지 의문이다. 그래픽디자인 시장도 빠르게 변화하고 있지만 그에 대한 대안은 없는 듯하다.': '54',
#  '편집회사로 업무 시스템이 체계적인 편': '54',
#  '야망이 큰사람이라면 좁게 느껴지고\r조용하고 편안하게 다니는 사람에게는 적합한곳.\r포토샵과 파워포인트 그리고 일러스트레이터만 사용하며\r100퍼 디자인업무만 하니까 잡다한 스트레스는 없다.': '54',
#  '영화 <악마는 프라다를 입는다>의 패션 홍보직을 생각하고 지원했다면 다시 생각해보시길, 직무에 관해 모르고 오기에 퇴사자가 정말 많은 회사!': '54',
#  '작은 홍보대행사지만, 꼼꼼함과 다른 어느 회사를 가서도 인정받을 수 있는 기초를 다질 수 있다.': '54',
#  '사회초년생이 다니기엔배울게 많고, 경력있는 사람이 다니기엔 편한 회사': '54',
#  '아르바이트할 때 담당 직원이 있어서 잘 챙겨주고 칼퇴근 가능했음.': '54',
#  '일 많이할수있음 야근많음 워라밸 없음연봉 올리기도 매우 힘듬': '54',
#  '작은 회사임에도 교육이 잘 이뤄지고 신입사원에게도 원하면 기회를 주는 곳.': '44',
#  '사람들은 좋으나 경영진의 잘못된 운영으로 나락으로 떨어진 회사': '44',
#  '병원 기반의 마케팅 업체로 안정적이나, 정체되어 있는 회사 입니다. 사업 확장보다는 정해진 몇개의 병원업무가 전부 입니다.': '44',
#  '열심히 하면 해볼만한 회사, 다양한 프로젝트 수행가능한 곳': '44',
#  '문화재관련 전문종사자들과 이야기하기좋습니다+ 문화재청일도 가끔 수주받아서 합니다.': '44',
#  '직원들의 피땀으로 가파르게 성장하고 있는 회사. 온라인마케팅 부분 광고 대행사 중에 큰편이기에 다양한 브랜드를 경험해 볼 수 있음': '44',
#  '빠르게 경력을 쌓을 수 있는 직장, 서로 존중하는 문화': '44',
#  '좀 더 직원을 믿고 적극적으로 업무에 임할 수 있는 사내분위기 조성이 필요함.': '44',
#  '광고가 만들어지는 A to Z를 배우고 실행할 수 있는 곳에너지가 넘치는 회사': '44',
#  '기회기 있는 회사임은 증명합니다.힘들지만 노력하는이에게 기뢰는 준 회사임은 분명함': '44',
#  '나름 자유로운 분위기였던거 같고 위치가 이태원이라 좋았음 이거 말곤 딱히 모르겠음': '42',
#  '갠플하기 좋은회사 입니다 그냥 업무만 하면되는 그런 회사 여기저기 다녀봤는데 그건 편했음': '42',
#  '쉬는 날 일주일에 하루. 분위기 너무 무거움.. 눈치보임..': '42',
#  '컨텐츠 회사인데 컨텐츠에 대한 경영 지식을 가진 사람이 아무도 없는 곳. 컨텐츠 제작자들이 아무리 컨텐츠를 잘 만들더라도 경영이 제대로 이루어지지않아 경영이 얼마나 중요한 것인지 깨닫게 만들었던 곳.': '42',
#  '타지역 전보를 하루이틀 전에 발표하는 곳. 사람을 우습게 여긴다.': '42',
#  '아래 리뷰에서 추천하는 꼴 보고 어이 없어서 씁니다. 우리나라 최악의 방송사를 뽑으라면 두말할 필요 없이 여길 뽑겠습니다. 비정규직 처우 개선 해달라고 했는데 사람 자살로 몰고간 인간쓰레기집단체': '42',
#  '워라밸은 좋으나 발전가능성은 흠.. 회사가 항상 불안정하다': '42',
#  '오로지 사람이 아니라 부품이 필요한 회사 심지어 부품도 없어서 억지로 굴러가게만 만든 자동차': '42',
#  '다들 열심히 일하는 회사입니다. 특히 직원들이 가장 고생합니다.': '42',
#  '이 회사를 다니는 내 자신이 떳떳하지 못함과 동시에 탈출 하고싶은 곳': '42',
#  '잠시 거쳐가는 곳이면 모를까 자신의 성장과 연봉을 생각한다면 업무 보시면서 틈틈히 채용사이트 켜서 다른 곳 알아보시는 걸 진지하게 추천드릴 정도로 아쉬운 곳': '20',
#  '밑에 분들 말씀 너무 공감. 이제껏 다닌 회사 중에 최악임. 자존감을 아예 쓰레기통에 버려야 울면서 다닐 수 있음.': '20',
#  '이 연봉 받으면서 굳이 이런 혹독한 대우와 환경에서 일할필요가 있을까 싶네요': '20',
#  '혼자 일하기에는 너무 좋은 곳.혼자 일하는만큼 모든걸 혼자 해야함.': '20',
#  '다소 힘들었다. 밥벌이가 다 힘들지만 내 기억으로는 가장 힘들지 않았나 싶다.': '20',
#  '체계없고 답답한 회사. 일할 맛이 안나는 회사.': '20',
#  '제대로된 커리큘럼 없는 교육회사 정말이지 수준이하인 회사 다시는 이런 회사를 다니고 싶지 않습니다': '20',
#  '빠른 탈출이 답! 첫월급부터 밀리는 자본금도 없는 회사': '20',
#  '디자이너가 처음부터 배우며 일하기 적합하며,신입이 입사하여 배우기 좋은 기업': '20',
#  '가족회사 회장 아빠 사장 부사장 아들에 과장은 학연으로 들어오고. 연줄에 미친 사람들.. 부사장 딸 초등학생인데 방학숙제로 영상 편집 도와달라하질않나 명절에 보낼 카드 디자인하고 잘라서 봉투에 넣어 드리는 일까지.. 그냥 신입으로 들어오면 커피부터 타야한다고 생각하면 됨': '20',
#  '스타트업을 경험해보기에는 좋지만 체계가 없음': '20',
#  '퇴근없이 하루종일 일하기 좋아하는 사람에게 추천합니다.': '20',
#  '지하철역과 연결된 건물애 있다는 것이 가장 큰 장점인 2명의 대표가 운영하는 출판사': '20',
#  '이 글을 봤다면 도망가세요. 최저시급주고 새벽 6시에 출근하고 새벽3시에 퇴근합니다': '20',
#  '오지게 갑질회사 직원욕을 밥먹듯하며, 자식들까지 똑깉음 성질 제데로 사장덕에 맘고생 제데로 할수 있는곳': '20',
#  '젊안 아이들 데려다가 인생 낭비시키고 돈도 잘 안주는 질 나쁜 곳.': '20',
#  '돈은 필요없다. 후려침 당하며 배우고 싶은 사람들에게 추천합니다.': '20',
#  '그냥 동네에 있는 작은 개인회사. 관공소일을 한다고 하지만 그닥 큰건은 없음': '20',
#  '사실 피할수 있다면 피하는것을 추천합니다.': '20',
#  '1점도 아까움 장점을 쥐어짜내라면 강남에 있는 것 단 하나': '20',
#  '반복된 업무로 금방 적응가능 그러나 일감이 끊이지 않아 지루할 수 있음 사람마다 상이함': '76',
#  '내 직무가 아니여도 여러가지 일을 다 해야함': '76',
#  '체계적인 조직으로 만들 수 있으면 좋을것 같습니다.': '76',
#  '작은 무대에서 알찬 공연이 가능한 기업 근무지가 아름다움': '76',
#  '군대식 운영이고 선배 후배 개념이 좀 그랬음. 단순 외주계약직이 정규직 눈치 꽤나 많이봄 다만 그만큼 끈끈하고 회식 자주함': '76',
#  '일의 기본기를 닦기 좋은 디자인 에이전시, 경직된 조직 문화와 높은 업무 강도': '76',
#  '다양한 공연을 진행하며, 사내분위기가 크게 나쁘지 않음. 회사 내에서도 큰 분란이 없어 무난함': '76',
#  '홍보 업계 커리어를 쌓기에는 가장 좋은 기업': '76',
#  '주4일제는 너무도 파격적이며 워라벨은 아름답다\r업무강도는 센편이며 노력과 의지가 필수!\r장기근속을 원한다면 한번쯤 도전해보는것도 좋을듯~': '76',
#  '일한 만큼 인정을 받을 수 있지만 일이 적지는 않을 곳': '76',
#  '앞으로 발전 가능성이 보이는 회사\r부서마다 분위기는 다르지만, 전체적으로 수평적이고 즐거운 분위기': '56',
#  '어디에도 추천하지 않는 회사지인이 간다면 뜯어말릴 회사': '56',
#  '춘천시내와 거리가 멀어 장점이자 단점임': '56',
#  '중소기업중 상대적으로 거대한 그룹사로 인하여 매출이 매우 크고 규모가 큼': '56',
#  '탄탄한 모기업이 있어 안정적으로 다닐 수있는 회사': '56',
#  '편하게 다닐 순 있는데 여초회사라서 눈치보기 너무 힘듬': '56',
#  '복지가 좋은 곳입니다. 재택 근무도 많고 다니기 편하게 해 주는 편입니다. 위치도 괜찮습니다.': '56',
#  '연봉은 적으나 자유롭고 좋은 사람들이 많은 회사': '56',
#  '대기업을 간접적으로 느끼고 싶고, 평소 사람응대에 스트레스받지 않아하며 금융업을 하고 싶은 사람은 지원하면 좋아요': '56',
#  '정치권에 희생된 회사.........직원들만 볼쌍했고': '56',
#  '사진일을 처음 해보는 사람한테는 괜찮은 경험일듯 함': '34',
#  '퇴사한지 오래 되었지만 최악의 기억으로 남아있는 회사.디자인 업무뿐 아니라 온갖 심부름 잡일 기본이고 부당한 회식자리도 많았음 일보다는 술잘먹는 직원을 좋아하였고 연봉 또한 적었으며 야근도 많았음 디자이너라면 미래를 위해 추천하고싶지 않네요 여긴 굳이 디자인 전공 안하고 기술만 배운분이 가도 될듯': '34',
#  '가족기업은 답이 없다대표와 실장이 부부인 가족기업나머지들도 대표의 지인들로 그물망이 촘촘': '34',
#  '대체적으로 대우는 해줌. 대체적으로 이 회사가 박사님이라 호칭되는 회장님의 강의력이 뛰어나기 때문. 앞으로도 이러한 체제는 계속 될것이며, 사람들의 조합도 나쁘지 않지만, 시스템을 공유하는데 있어 좀 의사소통이 미흡함.': '34',
#  '작은 회사의 전형적인 케이스. 작은 회사로서 갖고 있는 장단점을 모두 갖고 있음': '34',
#  '그냥 여기 다른분들이 쓴 그대로 입니다. 가지마세요 시간낭비 하게됩니다ㅋ': '34',
#  '보수적인 문화, 조용히 자기일만 하기 좋음, 평균연령 40대 중반 이상, 중국회사 협력사라 중국인 많음, 현장 방진복착용.': '34',
#  '자리에 없는 대표, 아무것도 모르는 사회초년생들은 고객들 욕받이': '34',
#  '스타트업 기업이어서 체계가 없었고, 경영진들이 회사를 이끌어가기 위한 전문 지식이 없음': '34',
#  '개인 시간이 극히 적고 연봉도 적은, 20대를 갈기 위한 최적의 직장': '34',
#  '일과 삶의 중심을 맞출수 있는곳, 능력으로 인정 받을 수 있는곳': '34',
#  '직원들을 대우해주고 체계적이고 탄탄하다.': '34',
#  '올드한 사고방식과 변하지 않는 마인드 필요하면 뽑고 그렇지 않으면 관두게 하는 회사': '34',
#  '다양한 업무를 통해 여러 분야의 경험을 쌓을 수 있는 곳다만 체계가 없고 퇴사율 높음': '34',
#  '사회초년생/아줌마에겐 복지 좋은 회사': '34',
#  '보수적이지만 진보적인 오묘한 회사입니다.': '34',
#  '그냥저냥 다니기엔 아주 나쁘다고 보긴 힘들지만 추천하지 않습니다.': '34',
#  '고정적인 클라이언트와 대기업 출신 헤드들로 인해 큰 프로젝트가 많음\r자체적으로 자신들을 디자인 컨설팅 펌이라고 하나, 결국엔 수많은 웹 에이전시 중 하나에 불과': '34',
#  '일단 너무 돈이 작다.... 회사 위치도 그렇다...네 전 그렇습니다': '34',
#  '가족 회사의 전형적인 예. 좋다 싫다의 개념은 없음': '34',
#  '사회생활을 첫 걸음으로 시작하거나, 경력을 쌓기에 괜찮은 기업.': '52',
#  '전반적으로  관리자가 필요한곳입니다 잘 해줄것이라 믿습니다.': '52',
#  '예상보다 규모는 작지만, 대표님에 대한 존경이 있고 스스로 노력한다면 많은 것을 배우고 깨달을 수 있는 회사.': '52',
#  '지속가능경영보고서 SR 편집 및 디자인 회사': '52',
#  '엄청 프리합니다. 다들 일하기 싫어하기 때문에 일을 굳이 안 만들어요. 그래서 젊은 사람들이 프리랜서로 가기에는 발전이 없습니다. 그 프리함에 녹아들다가는 내 젊음이 아까울 수 있어요. 하지만 대구에서는 티비씨에서 일했다~ 라고 말하기는 좋은 듯...': '52',
#  '일본 전시회 회사 중에 가장 규모가 크고 부서가 잘 나뉘어 있어 업무가 비교적 체계적인 편': '52',
#  '좋은사람글과 편안한 분위기 빡센 업무강도': '52',
#  '사람들은 좋지만 굳이 해외 인턴을 이곳으로 가야 할 필요는 없는 곳': '52',
#  '글로벌 브랜드 철학이 숨쉬는 곳. 한국 마켓이 타국에 비하여 어떤 특장점/단점 있는지 알 수 있음': '52',
#  '사양산업 가운데 발버둥 치는 평범한 회사.': '52',
#  '브랜드 카달로그 편집을 주로 했던 회사. 어쩌다 VMD로 분야를 확장한 곳이라 VMD에 대한 기본적, 전문적 지식이 부족하고 때문에 체계적이지 못하다. 후에 업무 커리어에 영향을 줄 수 있는 회사.': '26',
#  '절대가지마세요. 자존감만 낮아집니다.': '26',
#  '최악의 광고대행사 이보다 더한곳을 찾을수 없다고 확신합니다': '26',
#  '편하게다니고싶으면좋다 하지만 너무 바빠서 정신이 없다': '26',
#  '꼰대들이 이미 주름잡고 있는 기업 야근 수당 받아본적 한번도 없고 10-7인데 나 다닐때는 독서회 가진다고 아침 8시까지 오랬다': '26',
#  '디자이너의 역량은 필요없는곳,\r추세를 따라가지 못하는 디자인\r워라벨은 없는 회사, 추천하고 싶지 않지만 스트레스를 받고싶은 직장인이라면 추천\r신입은 디자인에 대해서 배울 수 없고,\r경력직이라면 상사가 나보다 디자인 못 할 수 있음': '26',
#  '대표만 없어도 잘 굴러갈 수 있었으나...한때 잘 나갔지만 지금은 싸그리 망한 곳': '26',
#  '원수가 간다고 하면 추천할 회사\r대표의 히스테리에 정신이 피폐해져 나오는 곳': '26',
#  '일이 어렵진 않아서 편하게 일하기 좋지만 오래 일할 곳은 못되며\r연봉도 올릴 수 없음 체계적이지 않아서 디자인하는 사람은 굉장히 피곤함': '26',
#  '박봉과 모욕을 감수할 사람만 가면 될듯.': '26',
#  '정직원이라는 이름 아래 아르바이트 하는 곳. 발전 불가능.': '30',
#  '사람 소중한지 모르는,별 1개도 아까운 회사입니다.기억하기도 소름끼칩니다.': '30',
#  '원래 이회사는 아래 두개의 평이 나올정도는 아니었다. 허나 아래 두개의 평이 정통한건 사실이다.': '30',
#  '트렌드 정보를 다루고 컨설팅하는 회사': '30',
#  '쉽게 입사하고 쉽게 퇴사하는 직장.. 제작진 대다수가 외주 프리랜서로 구성되있다보니 피디/작가/조연출 상관없이 사람이 정말 자주 바뀐다.': '30',
#  '업무 외에도 잡다한 일을 많이시키는 회사.다들 몸고생 마음고생 다하는 회사': '30',
#  '주먹구구식 운영 아래서 고군분투하는 일당백 직원들': '30',
#  '아무런 전문성이라고는 없는 곳 여태 존재하는게 신기하다': '30',
#  '발전을 할수없고 배울수있는일이 없다': '30',
#  '직원들끼리 맘을 합하지 않으면 살아남을수 없는곳': '30',
#  '직원들끼리도 단합이 잘 안되고 재미없는 회사사장님의 기분이 왔다갔다함': '40',
#  '디자인 외적으로 여러가지를 배울 수 있는 기회가 많다.': '40',
#  '회사에서 여러가지 디자인 경험과 업무를 해볼 수 있어서 좋았다.': '40',
#  '직원들 사이 분위기 좋았음. 일을 확실히 힘들지만 버틸만한 수준 (원래 영상제작하는 일 강도 수준에서는 괜찮음)': '40',
#  '회사 모양만 갖췄지 뭘 해야할지 모르는 회사': '40',
#  '개고생하고 싶으면 들어가도 괜찮은 곳. 온갖 일을 다해볼 수 있다.': '40',
#  '3D프린팅으로 주로 피규어제작을 하는 곳. 이외의 상품 제작도 문의를 받아 제작한다. 3D프린터를 사용하고 모델러와 채색러가 있다. 야근은 본인이 하고싶으면 할 수 있으나 수당은 없음.': '40',
#  '정말 다양한 방송일을 할 수 있다. 하지만 정말 방송일 만 할 수도 있다.': '40',
#  '대기업에 인수된 미디어 업체이며 주로 흥미로운 방송을 다뤘었음.': '40',
#  '적어도 저 사람처럼 굴진 말아야지. 인격 수행하고 온 회사.': '40',
#  '스튜디오 특성상 반복업무와 애기를 좋아하는 분이라면 좋을듯 합니다^^': '40',
#  '이곳에서 처음으로 제안서 쓰는 일도 있다는걸 배웠어요.': '40',
#  '일도 많고 나름 겉으로 안정적인데 가족만 잘 사는 회사': '40',
#  '꼰대문화를 경험할수 있는곳, 사람 갈아서 회사 유지하는 곳': '40',
#  '일 외에 잡다한 것을 요구함. 커피타기, 분위기 띄우기 등 성격 좋고 활발한 사람이 신입으로 들어가야 함': '40',
#  '5~10인의 작은 회사인 만큼 체제가 없음. 즉 일반 기업처럼 부서가 딱히 나뉜게 없기 때문에 직무 관계 없이 이일 저일 아주 다양한 일을 해 볼 수 있음.': '40',
#  '대행사가 그렇듯 단기간에 많은 업무를 경험하기 좋음 직원마다 포트폴리오 차이 있을 수 있음': '40',
#  '공정한 시각으로 정보를 공유하려고 노력함. 새로운 시도를 위한 노력을 꾸준히 함.': '40',
#  '패션을 사랑하는 사람들이 한 번 쯤 경험해보고싶어하는 직업.': '40',
#  '비효율적인 업무형태로 사소한 회의가 자주있고, 업무 배분은 균등하지 못하며, 일을 하는 데에 있어서 성취감을 못느끼는 기업': '40',
#  '정해진 근무시간에 집중력 높히며 일하고 깔끔하게 퇴근할수 있는 곳. 업무 강도는 높지만 그만큼 많은것을 짧은 시간내에 배울수 있어 개인 성장가능성이 높다': '86',
#  '공예가들을 위한 플랫폼이라고 소개했미만 수수료가 비싼점이 단점인 것 같다.': '86',
#  '자유롭고 수평적인 분위기를 느껴보고 싶으시면 추천': '86',
#  '회사 구성원이 젊은 기업층으로 사무실 분위기가 수평적이다. 임신 후 육아휴직이나 개인적인 휴가들에 대해 아주 유연하게 처리해준다.': '86',
#  '다양한 커리어를 쌓고 자유로운 분위기로 디자이너의 역량을 펼칠 수 있는 곳': '86',
#  '신입이 커리어를 시작하기 좋은 회사. 친근한 분위기.': '86',
#  '작지만 알찬 회사. 큰 기업들의 작업들에서 필요로하는 디자인작업을 주로 하기 때문에 포트폴리오를 많이 쌓을 수 있음': '86',
#  '즐겁게 일하기 좋았습니다.\r출퇴근 눈치안보입니다.\r약간의 지각 허용됩니다': '86',
#  '아직도 있을려나? 워라벨 좋은 회사였음': '86',
#  '여기에서 마케팅 기초를 다 배웠습니다': '86',
#  '국가에서 운영하는곳이라 월급 밀릴일 없음근데 연봉은 최저로 수당도 없고고인물 많아서 신입에게 적대적임': '54',
#  '회사자체는 오래됐으나 작업하는방식/순서등 모든것이 신생회사인 느낌.무질서': '54',
#  '아이디어와 창의성이 확실히 필요한 곳이며 연봉과 복지가 이벤트 기획 회사중에서는 단연1위이다.': '54',
#  '젊은 사원들과 젊은 경영진들. 그러나 체계가 안잡혀있어 어수선함.': '54',
#  '급여적으로는 아쉬우나 업무외적인 부분에서 발생하는 스트레스는 거의 없는편 신입에게도 실무를 전담하게 하여 다른 곳에 비해 많이 성장할 수 있나 역으로 생각하면 부담감으로 다가올 수도 있는 회사': '54',
#  '정치는 조금 있지만 직원들끼리 사이가 나쁘지 않음 경영진이 딱히 관심이 없음': '54',
#  '프로젝트 보고 입사해서 커리어 쌓으면 좋은 회사에요 경영난을 겪어 있다고 함': '54',
#  '한국보다 글로벌에서 잘 나가는 광고 대행사.\r외국에서는 최고 수준의 광고회사고, 한국에서는 중견 광고대행사 수준.\r전성기 시절에는 한때 5-6위 수준의 광고 수주량을 자랑했었음.\r글로벌의 기준에 따라 경영하기 때문에 시스템은 어느 정도는 외국계의 시스템이 있음\r단, 로컬 대행사의 느낌이 전반적으로 강한 편': '54',
#  '온라인 바탕의 IMC를 진행하는 회사고 급성장중이라 일년마다 직원숫자가 두 배가 되는 회사임. 대기업에서 일 맡아달라고 줄을 서 있으나 Capa때문에 거절할 정도.': '54',
#  '개인주의 경향이 있으나 동료들이 좋았던 곳': '54',
#  '보여지는것에 치중하는 미래없는 회사 비추합니다. 시간이 아까워요': '34',
#  '실무자들이 알아서 일을 해야 하는 회사.': '34',
#  '실력은 빨리 늘 수 있지만, 건강이 나빠질 수 있음. \r에이전시지만 위계질서가 그 어디보다 확실한 곳.': '34',
#  '지하철 행선안내게시기 광고를 독점하고 있어 메리트가 있다.다양한 광고를 접할 수 있다.': '34',
#  '경력 쌓기에 적절하지 않음.. 서로 간 소통이 부족하고 업무 분담도 적절치 않음': '34',
#  '이걸 보고 있는 당신, 도망치세요!!!!!!': '34',
#  '공기업 위주로 거래를 해서 일은 꾸준히 들어옴\r영업직 위주로 디자인도 굴러가서 단순 반복 일 밖에 없네요.\r일 주는 사람 마음에 들면 꾸준히 일 할수 있을지도요. \r초보자만 뽑는걸로 알고 있습니다.': '34',
#  '팀원들이 좋아서 버틸수있었던곳, 방치된 회사, 자기포장하기 바쁜 사장님 ㅠ': '34',
#  '업무 스트레스가 크지 않고 업무량이 많지 않아 \r칼퇴근 할 수 있는것이 장점인 회사.\r교통편이 좋아서 출퇴근 스트레스가 적다.': '34',
#  '복지가 별로 없고 연봉이 낮고 디자인 작업은 교육쪽 컨텐츠가 대부분.': '34',
#  '앞서나가는 업체는 아니라고 생각합니다 잡지사이지만 교육원의 성격을 더 중시하는듯합니다': '46',
#  '디자인팀과 기획팀으로 분리되어진 평균의회사 그만큼 광고 회사의 평균 그이상도 그이하 아님출근 시간은 있지만 퇴근 시간은 알 수 없음 프로젝트 단위 효율성은 상사 역량': '46',
#  '일은 힘들지만 열심히 일을 잘하면 되는 곳입니다': '46',
#  '언론업계 바닥을 경험해보고 싶은 사람은 다닐만한 곳. 기자로 첫출발하면서 차근차근 경력을 쌓고 싶은 사람에게 추천': '46',
#  '1년이상 버티면 무슨 일이 든 할 수 있을 것': '46',
#  '돈 들어가는 투자는 아까워하고 디자이너 스스로의 발전을 바람.': '46',
#  '광주 지역 케이블방송국 설치는 동구,북구에 한정 되어있음': '46',
#  '그냥저냥 사회초년생이 가기에는 좋지도 나쁘지도 않은 회사.': '46',
#  '사람이 좋았던 회사 뭐 그냥 그랬어요.\r좋았던 기억이 안 좋았던 기억보다 더 많긴 하네요': '46',
#  '업무는 재밌고 나름 할만함 근데 감정적인 느낌으로 이야기하자면 업무적으로만의 까임이 아닌 사람 자존심마저 깎아내버림 그나마 나 다닐때 대리가 특히 심했음 사람 반발심 만들게 하는데 뭐 있는듯': '46',
#  '대표 1인기업하면 딱 맞을 회사. 직원에 대한 애정 전혀없고 작업의 퀄리티를 높이기는 힘들다.': '28',
#  '체계도 없고 일을 주는 사람은 아이디어 내기만 바쁘고 그걸 맞추느라 몇번이고 반복하여 일함.': '28',
#  '가족 및 지인으로 운영되는 회사로 엉성하고 불합리한 부분이 있는 곳입니다': '28',
#  '자유로운 분위기로 편하게 일할 수 있다': '28',
#  '지역 이기주의에 빠진 데다가 직원에 대한 예의가 없는 충북 기레기 집단': '28',
#  '내 인생에서 겪었던 최악 중에서도 최악의 회사. 전형적인 가족회사의 표본.': '28',
#  '한달만 다녀봐도 바로앎. 체계가 하나도없는 이런회사가 이태껏 버틴것도 신기한 회사란걸.....': '28',
#  '공연과 관련된 경력이 필요한 사람에게 맞춤임.': '28',
#  '체계성 없음. 문어발식 사업 확장. 직원들의 의견을 수렴하지 않는 임원진': '28',
#  '다양한 경험을 쌓고 클라이언트를 상대할 순 있으나 정해진 근무시간이 없음': '28',
#  '다양한 분야의 다양한 사람들을 만나며 즐겁게 일할 수 있는 곳, 하지만 체력이 갈린다...': '60',
#  '시간을 되돌릴 수 있다면 이력서를 절대 내고 싶지 않은 곳 사회의 쓴맛을 배울 수 있는 곳': '60',
#  '나름 괜찮았던 광고대행사.어디나 마찬가지겠지만 코로나이후 미래가 불투명해졌다': '60',
#  '삶과 일 모두 다 충족할 수 있는 워라밸이 확실히 보장된 회사를 원하시는 분들에게 강력추천': '60',
#  '온라인 광고를 알아가는데 있어 배울점이 많은 회사': '60',
#  '대우받지 못함. 멘탈은 강해지나 개인적, 업무적인 성장 불가': '60',
#  '웹툰 제작에 의욕이 많지만 의욕만큼 투자를 하지는 않는 곳': '60',
#  '스타트업을 표방한 자그마한 회사. 아직도 남아있다니...': '60',
#  '깔끔한 사무실과 분위기 좋은 회사 구조.': '60',
#  '작은만큼 장점단점 공존 BUT 단점이 월등하게 큰 회사같다': '60',
#  '이 분야에 관심이 있다면 일을 배우기 좋을 듯 합니다.': '28',
#  '그럭저럭 다닐만함 친구나 아는 사람이 간다고 하면 추천은 하지 않을듯': '28',
#  '상사들의 꼰대, 권위적, 보수적인 마인드 개선 필요': '28',
#  '이미 많은 분들이.... 그렇습니다..': '28',
#  '그냥 몇권 잘 팔리는 책 돌려가며 장사. 서점들 찾아가서 책정리도 대신 해주고 딱히 마케팅이랄게 없음 그냥 무조건 서점 엠디한테 잘보여서 한권이라도 더 넣어파는게 마케팅': '28',
#  '인격적 존중이 없는 회사. 기자 출신 어르신들이 요즘 세대와 전혀 어우러지지 못함': '28',
#  '부처라면 가세요 득도 할 수 잇음..\r하지만 내 커리어에는 도움이 될까 과연? 싶은곳': '26',
#  '지연 학연 혈연의 삼위일체. 문어발식 확장에 비해 임원진 수준이 따라오지 못함': '26',
#  '별 한개도 아까운 회사. 유튜브도 팔아넘겼는데 어떻게 명맥을 유지중인지 모르겠다': '26',
#  '나쁘지 않음 일은 적고 대신 매출에 대한 압박이 있음': '26',
#  '근무했던 회사 중, 제일 마무리가 별로였던 회사': '54',
#  '과거의 영광이 있는 곳. 최근에 많이 올라왔지만. 추가 광고주 영입이 없으면 힘들어질듯.': '54',
#  '재미있게 일하고 다양한 경험이 가능하며 임원과 직원사이에 소통이 편안합니다': '54',
#  '직원들과의 신뢰가 높은곳\r이전에는 어떤지 모르겠으나 힘든일을 겪어도 버틸수있는 사람들이 모여있는곳이지 않나 싶습니다\r코로나로 다같이 힘든이시기에 솔직히 다들 배려하면서 살아야하지 않나요': '54',
#  '플랜에이라는 독서실과 스터디카페 운영회사, 아지오디자인도 같은 회사임': '54',
#  '올라운더 회사 좋던싫던 모든지 배울수있음 송도에산다면추천': '54',
#  '다양한 업무를 경험해볼수있는것이 장점그러나 어느 중소도 마찬가지': '54',
#  '굳이 설명하라면 이름이 주간지라지만 일간 인터넷신문. 매일 발제하게함.  글이 본의 아니게 짧아진다.': '54',
#  '규모가 작고 일하는 사람은 따로 있음 체계 없음 발전가능성 없음': '54',
#  '사람들이 인격적으로 나쁘진 않았지만 루즈한 프로세스와 정체되어있는 업무': '54',
#  '일을 잘하면 일이 늘어나는 회사, 일은 아랫사람이 하고 수직적 컨펌을 거쳐 공로는 위에서 받는 구조': '48',
#  '조직문화가 없으며 CEO 생각과 판단에 모든 것이 결정되는 회사. 감각은 직원들이 훨씬 뛰어남에도 CEO가 요구하는 어처구니 없는 기획과 아이디어를 감당해내야 함.': '48',
#  '자유로운 외국계 분위기로 근무. 배울 게 많은 지는 의문.': '48',
#  '본인의 배움에 대한 열망과 마음 가짐에 따라 큰 성과를 얻을 수 있는 회사': '48',
#  '볼 품 없는 회사를 최저 대우에도 불구하고 일으켜 세울 영웅적인 인물이 되고 싶다면 여기 지원해보길 적극 권한다. 성과주의라고 매번 말하고 다니니 보상은 해줄 것이다.': '48',
#  '면접 분위기는 편안했습니다. 하지만 월급에 비해 포스트인 만큼 작업적인 면이나 대기로 인한 야근이 무척 많았고성수기 때는 주말 근무도 잦았습니다. 그리고 작업인원이 많지 않아신입이 작업하기에는 디자인적으로 가르쳐줄 사람이 없어매우 아쉽다고 생각합니다. 그리고 지금은 어떨지 모르겠지만연차가 존재하지 않아 쉬고 싶을 때 쉴 수 없고조금 한가해진다 싶으면 실장님 재량하에며칠 쉬게 해줘서 개인적인 시간에 대한 계획을 짜기가 어렵습니다.': '48',
#  '팀에따라 야근은 필수인 곳 주말에도 일 할수 있음... 그러나 주중에 한번 쉬게 할 수 도 있음.... 혼자크기 좋은 곳': '48',
#  '내가 여기서 뭘 하고 있나 현타 오는 곳.. 급여도 매우 적음..': '48',
#  '인원이 적으나 자유로운 분위기 직원 연령이 젊은 층이라 분위기가 좋음': '48',
#  '회사 사람들도 너무 좋고 경력도 쌓고 좋았어요. 일이 많은 성수기엔 어느 정도 야근 해야 하고 바쁘지만 야근 수당이 있어서 나쁘지 않았어요.': '48',
#  '스낵바가 있고 요청하면 가득 채워지는게 좋아요': '62',
#  '이것저것 하기에 좋다 본인이 성장하고 싶다는 의지만 있다면': '62',
#  '하고싶은 일이 많다면 두루두루 경험해보고싶다면 나쁘지 않다.': '62',
#  '다양한 상세페이지를 만들 수 있는 곳빠르게 일을 쳐내야해서 손이 빨라진다는 장점이있다': '62',
#  '언제까지 갈까 언젠가 망하겠다 라는 생각으로 다님': '62',
#  '디지털 종합광고대행사로 다양한 광고업무를 하지만 최근 매우 좋지않은 회사 상황이 아쉬움.': '62',
#  '공공디자인 보고서 작업, 가이드라인, 가끔 시설물 등 전반적으로 다룸, 디자인 외 기획 업무도 진행하고 싶으면 추천': '62',
#  '옥외광고를 시작으로 온라인 광고로 영역을 확장하고 있는 회사.\r원하는 포지션에 지원해 일하기는 좋을지도..': '62',
#  '학원 원장님이 자신만의 고집으로 아이들을 몰아붙이는 곳. 일하는 사람이 자주 바뀌는 곳.': '62',
#  '퀄리티있고 결과물을 만들어내는, 어워드수상이 많은 그래픽디자인회사': '62',
#  '미디어 광고 회사, 광고 영업에 의해 운영되는 회사로 영업, 영상제작, 관리운영 팀으로 나뉘어짐': '32',
#  '4년제 대졸애들 1800으로 부리던 회사박봉에, 꼰대같은 대표, 그나마 착하고 순한사람들덕분에 괜찮았음\r그러나 연차못씀 눈치오지게 주면서 연차쓰려할때마다 노려보니까 ㅋㅋ\r퇴사도 내 맘대로 못했음 사표내니까 화내네?^^': '32',
#  '그 누구에게도 추천하고싶지 않은 회사입니다.지인이면 말리고싶네요.': '32',
#  '경력은 별로 안되지만 쉽게 짤릴 걱정이 없는 회사입니다': '32',
#  '이것저것 시도해 보고자 하는 사업들이 많아서 잘하면 배울 수 있는 좋은 기회가 될 수도 있읍니다': '32',
#  '연령대가 낮은 직원들 하지만 그중 오래근무한 어린 꼰대들이 있고 직원들 사이에 자기편만들기 잘하고 대표와 꼰대 들 에게 이쁨 받으려면 술잘마셔야함 연령층이 어리다보니 고딩 일진 놀이 하는 분들이 몇몇 있음': '32',
#  '직무의 전문성이 아닌 모든 업무를 해야하는 다재다능한사람이 필요한듯': '32',
#  '사원에게는 기회가 없는 회사. 모든걸 경영진이 결정함.\r임파워먼트라는 개념을 좀 알았으면함.': '32',
#  '최악의 기업 오지마세요.\r처음에 면접 보러 갔을때 주차비도 자비로 내야하는 열악한 환경입니다.\r탈출하세요.': '32',
#  '작가 한 명과 그 주변 인맥에 거의 모든것을 의지하고있어서 미래에 대한 기대를 할 수 없는곳': '32',
#  '공공피알을 해볼수있는 기회였고 낮은 연차에도 다양한 경험 가능': '64',
#  '서로 ~님이라고 부르며  존중하는 분위기가 인상적이었어요.': '64',
#  '회사 내 사원들의 연령이 거의 또래로 구성되어 단합이 잘되고, 분위기가 좋다.': '64',
#  '커리어적인 면에서는 다양한 기회가 있지만, 워라밸을 지키기에는 구조적인 어려움이 있는 곳': '64',
#  '클라이언트가 탄탄하고 규모는 작아도 오래다닐수 있는 회사': '64',
#  '인천에 이런 대우 해주는 회사 없어요너무 편하게 회사 다니시려는 분께는 어디든 힘들겠지만일을 배우 꿈을 펼칠 분들께는 추천합니다': '64',
#  '사내 분위기가 나쁘지 않다 평타는 치는 느낌?법에 민감해서 위법은 절대 안할 기업': '64',
#  '홍보에이전시지만 칼퇴가능하고 연차 사용이 자유로운 편\r그치만 소기업이라서 불편한 점도 많음': '64',
#  '자유로운 연차사용, 개인의 생각이나 원하는 것을 자유롭게 도전해볼 수 있는 곳': '64',
#  '바쁠때만 바쁘고 안바쁠때는 한가해서 다른 업무를 볼 수 있었음': '64'}

# %%
len(reviews_5)
# Out:
# 300

# %%
df = pd.DataFrame(reviews_5, index = [1])
df = df.transpose()
df.columns = ['score']
df['review'] = df.index
df.insert(0, 'industry', 'media_design')
df.reset_index(drop=True)
# Out:
#          industry score                                             review
# 0    media_design    36        소기업. 중소도 아닌 소기업. 가족회사. 방송국이라 하기엔 너무 작은 개인회사
# 1    media_design    36  별점 1도 아까운데..잡플래닛이 사람 여럿살리는 역할하는듯. 이거 보시고 가지마세요...
# 2    media_design    36  즐겁고 쾌할한 회사 분위기에서 온라인마케팅 관련 전반에 대해 배울 수 있는 수 있는 회사
# 3    media_design    36  광고 대행사라는 타이틀을 걸고 있지만, 실질적으로는 광고송출 대행사에 맞는 평가. ...
# 4    media_design    36                              개발자가 대우받으며 일할 수 없습니다요
# ..            ...   ...                                                ...
# 295  media_design    64  인천에 이런 대우 해주는 회사 없어요너무 편하게 회사 다니시려는 분께는 어디든 힘들...
# 296  media_design    64      사내 분위기가 나쁘지 않다 평타는 치는 느낌?법에 민감해서 위법은 절대 안할 기업
# 297  media_design    64  홍보에이전시지만 칼퇴가능하고 연차 사용이 자유로운 편\r그치만 소기업이라서 불편한 ...
# 298  media_design    64        자유로운 연차사용, 개인의 생각이나 원하는 것을 자유롭게 도전해볼 수 있는 곳
# 299  media_design    64                 바쁠때만 바쁘고 안바쁠때는 한가해서 다른 업무를 볼 수 있었음
#
# [300 rows x 3 columns]

# %%
# [세무/회계] 산업군의 기업 리뷰 스크래핑
reviews_6 = dict(ind_reviews(1004))

# %%
reviews_6
# Out:
# {'인수인계 없고 업무체계 없고 정치색 강요와 성적인 요소로 불쾌감 조성 및 각종 비하를 해주는 특별한 곳!': '36',
#  '개인주의자 성향이 강한 회사여서 저하고 잘 맞았습니다.': '36',
#  '신입직원이 일하기 좋은 사무실이라고 생각합니다': '36',
#  '근로자 시간을 갈아서 유지하는 회사자신의 인생을 살고자 하는 사람들에게는 최악의 회사': '36',
#  '내가 하는일에 아무도 터치하지 않아서 편히 일하기 좋다.': '36',
#  '크게 기대할 것도 실망할 것도 없는 정도임\r적당히 경력 쌓을 정도임.': '36',
#  '편하게 일하는 곳 시키는 일만 하면 되는 곳': '36',
#  '배우고자 한다면 많은 것을 배울수 있으나, 그런 의지가 없다면 시간만 흘려보낼 것 같음. 난이도가 살짝 있는 업무를 하기위해서는 개인적인 공부가 필수. 그래야 물어봤을때 알려주시는걸 빨리 흡수할 수 있음.': '36',
#  '조직문화가 심각한 곳 야근이 잦은 곳 사장님이 큰 소리를 내도 직원들이 아무말도 못하는 곳': '36',
#  '적은 월급에 비해 많은 노동력 가성비가 딸림다양한 거래처로 배울점은 많으나 체계적이지 못한 교육방식': '36',
#  '다양한 일을 배울 수 있고 자유로운 분위기인 편임.': '94',
#  '기장팀이라 팀마다 다르겠지만 개인주의라면 자유롭고 편합니다': '90',
#  '다양한 경험을 할 수 있고 문화 또하 좋았습니다.': '86',
#  '작은곳이지만 마음만은 편한 회사였다 \r퇴사했어도 가끔 연락하고 좋았다': '86',
#  '사람들이 너무 좋았고 좋은 상사를 만나서 많이 배울 수 있었음': '86',
#  '결산, 조정 등 업무 배우기에 좋은 환경임': '86',
#  '다양한 업무를 모두 경험할 수 있음 여의도에 위치해있어 출퇴근이 용이하고 식사나 커피 모두 다양하게 선택 가능함': '80',
#  '지점이 여러개인데 지점끼리 서로 교류가 없음 지점마다 다르지만 일단 일이 많고 야근이 많음': '80',
#  '전문지식을 배우며 업무를 빠르고 체계적으로 배울 수 있는 곳': '80',
#  '내 할일만 잘 하면 되는 회사 걱정할건 없음': '80',
#  '세무사무실 특성상 적은 연봉, 야근필수': '26',
#  '조용한 분위기 좋아하고, 숙달만 되면 정시퇴근 할 수 있습니다. 그대신 책임은 스스로 해결해야 할 수 있어야 합니다.': '26',
#  '5인이하 형태의 기업. 다른 여타 사무실과 비슷////': '26',
#  '첫직장이라 아무것도 모를때 입사했던 곳...면접부터 이상했습니다.': '26',
#  '신입에게 업계 평균치를 웃도는 업체수를 맡기나 별도의 교육은 없다': '26',
#  '일도 많고 직원도 많고 입퇴사자가 많음입퇴사자가 많아 거래처 조정도 꽤 있음회사는 깨끗하함 직원이 많아 좁긴하지만': '24',
#  '별로 추천하고싶지않음 경력 쌓으러 한번경험 해보고 싶으면ㄱㄱ': '24',
#  '별 하나도 아까운 절대 가지 말아야 하는 곳. 본인의 자존감이 너무 높다고 생각하는 사람에게 추천드립니다.': '22',
#  '신입이 일 배우기 힘든 환경. 사람이 자주 바뀌는 것에는 이유가 있음.': '22',
#  '그냥 직원에 대한 배려 존중 하나도 없음 개인 비서인거같음. 회계사없는곳 ,사무장이라는사람은 그냥 일만시키고 아무것도 안함 .욕하고 비하함': '22',
#  '잡일이 좀 많고 일의 순환률이 그저그렇다 우편보내는 일이 많다': '74',
#  '법인사업자 기장을 배우고 싶다면 추천. 법인 기장하면서 회계처리도 많이 배울 수 있었음. 업종이 다양함.': '74',
#  '윗사람이 꼰대스럽긴 하나 전체적으로 분위기는 좋은 편이다': '74',
#  '여회계사님을 만나면 좋아요. 인간적으로 대우와 제대로 일 배울 수 있습니다.\r직원들과 사이가 좋았어요. 이부분은 케바케죠.': '74',
#  '공재불사. 그만두지 않음에 있다는 뜻으로 꾸준히 노력하며 발전하는 회사.': '74',
#  '큰 나무에 여러가지가 있는 세무그룹 / 각 지점별 별다른 교류가 있는지는 미지수': '72',
#  '적당한 복지시스템과 세무사님의 강의등 좋은점이 있습니다.': '72',
#  '다양한 업종의 거래처가 없다는것이 아쉽지만 신입이라면 배우면서 일하기에 좋은 조건으 가지고 있음': '70',
#  '외국계 이름을 쓴 현지화 완료된 중소기업입니다. 생각보다 좀 달랐네요.': '70',
#  '업무 배우기에는 좋은 회사에요. 세무 업무적인 특성상 야근이 많아 하다보면 지치는 부분이 있습니다.': '70',
#  '모두가 친절하고 일에대한 적극성이 뛰어나 발전가능성 엄청좋음': '52',
#  '대우 받으며 보람차게 일할 수 있는 곳. 다양한 업무와 직장 생활에 필요한 경험을 쌓을 수 있는 곳.': '52',
#  '업무량에 비해 연봉이 매우 적고 같이 일하는 직원들이 꼰대였음': '52',
#  '회계사무실 일을 스파르타로 배울 수 있는 곳이었음': '52',
#  '중소기업의 특징을 다 가지고 있지만. 세무회계 사무실 중에선 일하기 괜찮은 편.': '52',
#  '회계지식을 많이 배울 수있음 경력 쌓으려 한다면 추천함': '52',
#  '퇴사자가 너무 많았었다... 업무 인수인계가 잘 되어지지 않는다.': '50',
#  '회계 업무를 신입치고 다양하게 배울 수 있음 많은 것을 실무로 경험하고 배우고 싶은 사람에게 추천함': '50',
#  '연봉 및 복지 생각하지 않고 오직 회계업무를 배우고 싶다면 추천': '50',
#  '로컬 회계법인의 특성상 커리어에 크게 도움이 되지는 않으나 워크앤라이프를 고려하는 회계사라면 갈만한 곳': '50',
#  '실장이 퇴근 안하면 새벽 한시까지 퇴근 못하는 회사. 점심시간 지켜주면 감사할 지경.': '36',
#  '원수가 이 기업 회사 들어간다고 하면 한번쯤은 말릴 회사': '34',
#  '텃세가 너무 심하며 사소한 것에 대해서도 터치가 심함하지만 체계가 잘잡혀있어 신입이 가서 일배우기에 좋음': '34',
#  '아주 잠깐이었지만 별로였던 곳으로 기억됨..........': '34',
#  '사람인에 구인 공고가 자주 뜨는 곳..': '34',
#  '자유롭게 일을 하지만 무언가 잘 이루어지지 않는 그런 사무실 같은 느낌이다.': '34',
#  '면접볼때와 근무할때 고용형태가 달라지는 금요일제외 칼퇴가 없는 회사': '34',
#  '별 한개도 아까움.... 연봉도 적고 하는일 많음.': '34',
#  '발전없고 그냥 시간떼우기 좋음. 전문적으로 배우고싶으면 다른데 가세요': '34',
#  '법인 지점이 많이 나눠져있으나 전부 개별로 운영....': '34',
#  '오성 여의도점 1점조차 아까움. 직원들 이직이 잦은 이유는 다 이유가 있음': '48',
#  '고위직 공무원들이 자리 잡은 곳...': '48',
#  '다양한 개발을 할 수 있으면 보람찬 곳': '48',
#  '개인플레이하는곳 두번다시 가고싶지않은곳': '48',
#  '생각보다 성과급 챙겨주긴함거의 위에서 하라는대로 하는일만 할 수 있음': '48',
#  '세무사쪽 처음 접하기엔 좋은회사 나름 괜찮았던회사 ….': '48',
#  '적당히 일하고 적당히 경력 쌓을 수 있는 회사. 별로 특별한 것은 없음': '48',
#  '탄력제로 하반기엔 매우 널널한편 세무사사무실 특성상 상반기엔 바쁜게 당연한일': '48',
#  '직원들 먹고 싶은 음식이나 필요한 소모품에 대해 아낌없이 지원해줌. 하지만 직원한테 들어가는 모든 비용까지 세전연봉에 포함하여 지급하고 있다는 세무사 및 회계사의 마인드때문에 일을 많이 시켜서 뽕을 뽑겠다는 의지가 굳세게 느껴지고 본 업무 외에 시키는 일들이 매우 많음.': '48',
#  '한 사람의 평가로 인해 그 외 사람들의 인성이 정해지는 이상한 곳. 일을 어떻게하든 상관없음 그 사람과 잘지내면 장땡~': '48',
#  '별점으로 충분히 설명이될꺼라고 생각합니다~ 이정도면 충분합니다': '48',
#  '층 별로 분위기가 많이 다름. 대체적으로 야근이 많음\r층 별로 나이대도 다양함': '48',
#  '사람들도 좋았고 업무강도도 높지 않았음.': '48',
#  '본사가 망친 회사. 업계1위에서 꼴지로 추락.': '48',
#  '어딜가나 일하는건 비슷해서…다만 강남역에위치해서 교통편이 괜찮을거같아요': '46',
#  '기술사업화 전반에 대한 전문성을 가지고 있는 기관으로, 비즈니스모델 설계에 우수한 역량을 가진 인력들이 다수 있음.': '46',
#  '나쁘지도 그렇다고 엄청 좋지도 않습니다.\r전 직장보다 세무사님이 덜 갈궜다는 점?': '46',
#  '회계사님이 의지가 강하시고, 직원이 성장하길 바라심': '46',
#  '세무사사무실 전반적인 업무를 배울수 있는곳': '46',
#  '홀수 달에는 바쁘고 짝수 달에는 한가합니다..회계업종 고민하다가 세무사사무실 들어갔는데 추천하지 않아요': '46',
#  '9호선과 분당선 선정릉역 역세권(도보 3분이내)이다. 건물에 스타벅스가 입점되어 있어서 아침에 커피 사기 편리하다': '54',
#  '자유로운 분위기지만 수직관계가 너무 확실함 개인역량 늘려도 승진 거의 불가 그냥 윗사람 자리가 비어야 그자리에 갈 수 있음': '54',
#  '회계법인 중 규모가 나름 있는 편, 회계사님들이 좋고 팀이 나누어져있음.': '54',
#  '단합이 좋고 일을 체계적으로 배울수 있다. 되돌아보니 괜찮은회사': '54',
#  '봉급 딱히 상관없으면 괜찮게 일 할 만한 곳. 저는 큰 불만 없이 다니고 있습니다.': '54',
#  '신입 때 입사하면 정말 배우기 좋은 회사. 결재시스템이 잘 갖추어져있음 (물론 사무실마다 다름) 다른 곳 가서 인일회계 다녔다고 하면 나에 대한 신뢰가 높아짐...': '54',
#  '그냥 세무법인 그자체 뭐 특별한 것도 없다': '54',
#  '수평적 분위기라 업무를 진행하는데 있어 만족스러웠으나 다소 우유부단한 느낌이 있어 의사결정에 어려움을 느낀적이 있음': '54',
#  '낮은 복지, 세무사의 꼰대마인드는 회사를 다니고 싶지않게 만듬': '54',
#  '여러가지 업종의 회사들이 기장을 하기 때문에 세무회계 전반적인 업무를 배우기에 좋음': '54',
#  '일하기에는 사람도 좋고 텃세도 없고 좋은 법인': '60',
#  '직원에게 최대한 좋은 복지를 제공해주려고 노력하는 회사라 생각되나 실질적으로 잘 운영되진 않고있음': '60',
#  '세무일을 많이 배울수있다. 하지만 야근많음...': '60',
#  '다양한 업종을 경험하고 관리 가능 업무효율 좋습니다.': '60',
#  '자유롭고 발전성있는 회계펌입니다. 하지만 회계사 자격증이 있어야 입사할 수 있어요': '60',
#  '다양한 업체소유로 신고 시 여러직무 습득가능하고, 각 직무를 위한 기업에서 교육지원': '60',
#  '여러방면으로 성장 할 수 있음 임원 제외 사람들은 좋음': '60',
#  '다른직원들과 관계가 타회사에 비해 다소 원만함. 바쁘게 일할수있어 좋음.': '60',
#  '일이 많은편은 아니고 가족같은 분위기라 다니기 편함. 세무사님이 좋으심': '60',
#  '세무회계 갓 입사하는 신입이 입사하기 좋은 회사': '60',
#  '나이많아도편히다닐수있는곳으로나잇대가좀많은편임': '70',
#  '그냥 그럭저럭 그래요\r매일 점심은 맛있는거로 먹어서 그거 하나는 좋아요\r수직적인 문화가 있어요\r막내가 다 하는 느낌적인 느낌?': '70',
#  '인턴급 이상의 일을 경험할 수 있고 전체적으로 실력 향상이 눈에 보일 정도로 컸음': '70',
#  '전문적인 업무를 친절하게 설명 받을 수 있어서 좋음': '68',
#  '체계가 잘 잡혀있고 사람들이 너무 좋아서 첫직장으로 좋습니다': '68',
#  '근속연수가 오래된 직원은 서로 으샤으샤해서 지속적으로 근무해 나가지만, 그의 반해 신규 입사자는 회사에 적응하기 어렵다. 그리고 현 담당자가 퇴사할 경우 새로이 입사하는 직원은 인수인계가 제대로 이루어지지 못하는 경우가 잦다.': '68',
#  '인간대우해주는 정상적인 회사, 그만두고싶지않은 회사': '68',
#  '업무강도 괜찮고 복지 좋았습니다.\r바쁠때 바쁘고 여유있을때 여유가 있습니다.': '68',
#  '맡는 거래처는 복불복\r회사 분위기 좋음': '66',
#  '일 하기에는 편하지만 배울 수 있을지는 의문. 세세하게 배우기위해 갔다면 비추': '66',
#  'ㄷ세무대리인으로서 야근과 최저연봉 받으며 일할수 있는 근무환경을가짐': '26',
#  '한번경험해볼만한 가족회사입니다 아무생각없이 다녀야 오래다닐수있음': '26',
#  '배울점이 없었던 회사. 일을 배운건지 편법만 배우다가 그만둔 회사 일한직원에 노고는 알아주지 않는 회사': '26',
#  '노동력 착취가 심함  하지만 다양한 경험은 가능했음 하지만 기초를 닦는데에는 부족': '26',
#  '아무것도 모르는 사회초년생 환영, 경력자가 오기엔 너무 열악한 환경': '26',
#  '대표자가 거래처에 관심이 없고 박리다매,': '26',
#  '최악최악 최최악....실장의 단독으로 뭐든 다 처리하는회사': '26',
#  '사무장 기분에 따라 분위기 좌지우지되는 곳.': '26',
#  '정석대로 일 배우고 싶다면 이곳으로 입사하는 걸 매우 추천': '26',
#  '다른 세무사사무실과 비교했을때 오래 다녀도 경력으로 인정받기 힘들것같은 곳': '26',
#  '옛날 사무실 분위기로 젊은 사람들이 다니기에 부적절하다고 생각이 든다.': '34',
#  '과장이란 사람이 너무 사람을 괴롭힘 들들 볶는게 짜증남': '34',
#  '임원의 기분에 따라 그날의 사무실 분위기가 좌지우지되는 회사': '34',
#  '빨리 나와야하는곳.(지점에따라 다르긴하겠지만)': '34',
#  '기장팀은 상사가 어려울수있다, 이외 회계사 소속 팀은 각 회계사별로 급여나 복지가 달라질수있다': '34',
#  '자유로운 분위기로 분위기 좋으나 직원텃세가 약간 있음': '34',
#  '자기들은 꼰대아닌척하지만 꼰대인게 티가 나는곳. 시키는대로 고분고분 해야하는곳. 밑에 직원들은 잡일 다 해야하고 그게 당연한곳.': '34',
#  '모든회계사무실이 그렇듯이 야근업무나 비슷합니다.': '34',
#  '적막한 분위기에서 일만 할 수 있는 곳.\r세무사사무실이 보통 그런 분위기여서 나쁘지 않음.': '34',
#  '좋은 회사는 아니에요.처음에는 잘 모르겠지만 갈수록 힘든 요소들이 나올거에요.상반기에 사람들의 태도를 보고 판단하세요.': '32',
#  '도소매 업종 비율이 높아 물경력이 될 가능성이 높고 나이대가 어리고 명수가 좀 많다보니\r불필요한 말이 돌고돈다': '44',
#  '텃세 없고 일하시는 분들이 너무 좋아요': '44',
#  '가족기업 신입만 뽑으면서 기대치는 높음 신입이지만 A to Z까지 책임져야함': '44',
#  '과한 업무로 인한 워라밸 붕괴로 인한 잦은 구성원 변경': '44',
#  '사무실 크기는 평범했고 야근을 하긴 하는데 별로 안한다 평범한 사무실': '42',
#  '여의도 지점에 근무 했었는데 복지도 좋고 직원분들 다 좋으시고 특히 먹는거 잘 챙겨줍니다!!': '42',
#  '근무환경이 좋거나 복지가 좋으면 괜찮을거같은데 할일만 많으니 좀 그런거같습니다.\r개선이 되면 괜찮은 기업으로 변신시킬수 있을거 같습니다.': '42',
#  '인천 작전점 또는 (이형근 회계사무소)\r예고없는 갑작스런 야근, 주3일이상 술, 직원 뒷담화, 직원들 앞에 대놓고 야단, 직원에 대한 배려와 존중이 없는 회사 , 직원들이 자주 바뀌어요-> 이 말뜻은 무슨 말인지 아시겠죠?': '42',
#  '회계사별로 팀이 나뉘어지다 보니 팀마다 복지며 급여 차이가 있음': '42',
#  '회계사 입맛 맞추기임 그냥 모든게 힘들고 일을 할수록 늘어나고 복지가 아무것도 없음': '42',
#  '팀바팀이라 팀을 잘 만나야 합니다. 보수적인 집단..': '52',
#  '급여인상율이 작고 회장 마음대로 회사운영되는 경우가 많아 직원들간의 화합이 좋음': '52',
#  '나쁜 사람 1명이 회사를 흐려놈. 으쌰으쌰하려다가도 기운빠짐': '52',
#  '일하는사람만 일함 나서려고 하는사람이 별로 없음 수동적': '52',
#  '세무업무에 대해 배우고자 한다면 경력 쌓기 나쁘지 않음': '52',
#  '눈에 보이는 복리는 좋다 눈에 보이지 않는 복리는... 말하지 않겠다.': '52',
#  '세무 관련 전문성을 키울 수 있으나  일이 많고 급여가 적습니다.': '52',
#  '회계법인이지만 개인세무사사무실에 가까운곳임..개인업체가 상대적으로 많음': '52',
#  '일을 잘알려준다하는데 메뉴얼만 고집하는 직장인거 같음': '52',
#  '각 팀마다 다른 소속감을 느낄 수 있다.': '52',
#  '최저시급, 그에 걸맞지 않은 업무강도. 이런 곳에 들어갈 바에야 차라리 좀 더 무직자로.': '30',
#  '1점도 아까워요 / 글자 수 채우기도 아깝네요,,,,,,,,,,,,,,,,,,,,': '30',
#  '4대보험 안내줌 회사 위치가 역과 거리가있음 (도보 15분) 차 막힘(버스 힘듦)': '30',
#  '보험취득안해주고 꼼수부리기 바쁘심..': '30',
#  '워라벨 그런건없음 출근첫날부터 야근에 주말출근\r안하면 눈치주고 신입한테 그냥 개인거래처 줌': '30',
#  '무조건 옆사람에게 물어봐야하는데 옆사람도 경력이 없어서 물어볼사람이 없음': '30',
#  '세무회계 일배우로 들어가서 잘배우고 다녔습니다': '28',
#  '윗사람들 터치가 적고, 바쁜시기 지나면 연차도 마음대로 쓰고, 일하기 편함. \r신고기간때는 수당도 많이 주고, 하반기에는 근무시간 1시간 빼줌': '28',
#  '별 하나도 아까운 회사ㅋㅋㅋ 급여 안주고싶어서 난리 ㅋㅋ 속보입니다': '28',
#  '복지 무난무난하고 재택근무도함. 업무강도는 높다. 여초회사의 악질적인 특징은 다 갖고 있음.': '26',
#  '관리자들의 구식 운영과 소통 부재, 수평구조인 "척"하는 굉장히 수직적인 회사.': '40',
#  '많은 업무량에 다양한 실무경험을 쌓을 수 있음.': '40',
#  '아르바이트생으로 근무하였으며, 여자분들이 많은 회사였습니다.\r분위기는.. 여자분들이 많은 곳의 특유 분위기를 가진 것 같습니다.': '40',
#  '큰 세무 법인내에 여러 개의 작은 세무사 사무실': '40',
#  '여러의미로 동물의 왕국 처음에만 좋아보이는 회사': '40',
#  '신입이 본인의 역량을 파악하기엔 좋음 하지만 그외엔 잘 모르겠음': '40',
#  '편하게 다녔엇음현재는 모르겠으나 수원역고ㅏ 가까워서 인프라는 좋음': '40',
#  '자유도가 높고 자신이 할일만 하면 됨': '40',
#  '특정개인에게 업무 과중으로 인해 1달만에 퇴사함 9TO9으로 일하게 되는 경우가 종종 있음. 일 배우다가 책임을 신입에게 뒤집어 씌우기도 함.': '40',
#  '일단 팀바팀이 심하고(옆팀은 상사가 너무 좋음), 가족같은회사가 아니라 가족회사임. 여기 입사한 후로 왜 가족회사는 가면안되는지 알게되었음. 회사규모는 작지않은데 급여수준은 최악입니다. 계약서 근무시간이 10시~5시로 되어있는 이유가 급여를 조금 주기위해서 입니다. 일반기업 최저시급에 한참 못미치는 급여수준. 상반기 야근기간에 매일야근 9시까지하고 야근수당이없어서 급여200도못받음.': '40',
#  '1년이상 근무하는 사람이  거의 없음.  문제가 항상 있는 사무실': '50',
#  '영등포지사 ) 급여가 짜긴 했지만, 많은걸 배울 수 있음': '50',
#  '근무환경은 좋아요.회계사님이 직원들 복지 많이 챙겨주세요.': '50',
#  '처음 업계에 들어온 사람이라면 일을 배우기엔 좋은 환경이나 기본적인 복지나 급여가 많이 적은 편': '50',
#  '전형적인 세무사 사무실 법인 업체입니다.': '50',
#  '고령화 회사입니다 충격적으로 조용하고 웃을일도 없고 적막하고 매순간 퇴사욕구 뿜뿜 이에요': '50',
#  '단점을 적을 공간이 현저히 부족한 회사.\r전문성이 필요하지 않은 업무를 하고 싶은 사람, 상명하복 구조에 익숙해지고 싶은 사람,  인격적인 대우를 받지 못해도 견딜 수 있는 사람, 밤 늦게 퇴근하며 현 시대의 직장인 코스프레 하고 싶은 사람에게 추천합니다.': '50',
#  '자기 능력에 따라 성과를 올릴수 있는 법인. 파트너 아닌 직원은 대우가 천차만별': '50',
#  '별도의 전산시스템이 갖추고있지만, 전산부분에 회계지식이 부족한 인력이 많아 신고하는데 어려움을 격음.': '48',
#  '결재시스템은 있으나 업무적으로 전문성이 부족한 윗사람이 검토하여 문제발생확률 높음': '48',
#  '회계일을 배우기에는 좋지만.. 야근이 너무 많은 회사': '50',
#  '크지않은 회사라 커리어를 처음 시작하는 사람에게 추천': '50',
#  '열심히 노력하는 모습 기분좋았음.\r항상 성장하는 회사입니다.': '50',
#  '팀바이팀입니다 좋은 팀에 걸리면 오래 다닐 수 있지만 그게 아닐 시 금방 퇴사 하시게 될겁니다': '50',
#  '각자 하는 일만 열심히 하고 책임감 있게 잘 할 수 있는 사람이면 추천': '50',
#  '다양한 세무업무를 경험하고 인사,노무 관련 지원사업을 하기 위한 사람이라면 추천': '50',
#  '좋은 곳 입니다^^ 세무사님도 너그럽고 사모님도 인자하신 곳입니다점심식대 대주시고 직원간 일 편하게 할수있게 많이 노력해 주십니다': '50',
#  '부서마다 다름내가있던 부서는 상대적으로 자유로운 분위기였음': '50',
#  '세무사님이 정이 많으시고 좋으신 분이라 복지도 좋고 근무환경이 좋았습니다.': '50',
#  '좋지도 나쁘지도 않은 중간정도는 하는 사무실이에요': '50',
#  '아주 편해요! 터치하시는 것도 없고 자유로운 분위기! 분위기는 좋은 편인 거 같아요': '66',
#  '노무에 관하여 다양한 업무를 경험해볼수 있었고 사람들이 좋아서 사내분위기가 너무 좋았다': '66',
#  '대표세무사 및 직원으로 구성되어있으며 직원들 근속연수가 매우 오래되었음. 향후 퇴사 의사도 없을 것으로 예상됨.': '66',
#  '남다른 회사 남다른 경영진이였다.\r나와는 맞지 않는 그곳': '66',
#  'Work Life Balance 측면에서는 컨설팅 회사 치고는 좋은 편이며, 회계 법인 산하 컨설팅인 점을 감안하더라도 군대식 문화는 아님. 사람들은 굉장히 나이스하고, 컨설팅치고 경쟁적인 분위기보다는 가족같은 분위기.': '66',
#  '다른 회계사무실들과 비슷하며 강도도 비슷한 편으로 무난함': '66',
#  '조직문화가 정말 좋다. 권위적인 분위기도(몇몇 악명높은 사람들은 물론 있다) 없고 팀원들 간의 커뮤니케이션도 활발하다.': '66',
#  '직원들이 대체적으로 별로며, 여자세무사는 인성이 별로임': '66',
#  '회계사라면 한번쯤은 일해보기 괜찮은 곳': '66',
#  '나이많은 회계사 및 직원들이 많아서 마인드도 굉장히 옛날사람들인거같음. 거기에서 오는 장단점이 다 있음.': '66',
#  '각 사무실에 따라 분위기와 직무환경이 다르다.': '60',
#  '굳이 갈 만한 곳은 아닌듯 사람 자주 바뀜 지금은 잘 모르겠으나 비슷할것임 복지가 없음 하반기 빠른퇴근 없음': '60',
#  '회계법인 마다 분위기나 환경이 다르지만 옛날방식으로 급여 상여를 책정하고 신고때 회계사님 업무로 시간을 많이 빼앗긴다': '60',
#  '가족같은 분위기로 일 할 수 있어요! 사무실 분위기 좋아요': '60',
#  '팀바팀인데, 너무 나뉨.. 여기 특성상 일 몰아서 오는 거는 맞긴한데 회계사가 회계사냐 회개사냐에 따라 달라짐...': '60',
#  '최하도 최고도 아니고 중하위건 정도의 복지와 연봉입니다': '60',
#  '다양한 환경에서 일을 배울수있음 나름 괜찮았음': '60',
#  '배울 것이 많은 회사 = 일이 많은 회사': '60',
#  '세무법인답게 딱 그정도입니다.\r가족같은분위기는 아니라 회사분위기입니다.': '60',
#  '신입이 입사하면 확실히 배울 수 있는 곳.': '60',
#  '전체적으로 무난하게 다닐 수 있습니다.': '60',
#  '회사는 크고 복지 정말 좋습니다다만 큰 만큼 직원이 많아요': '60',
#  '과한 업무강도, 깎이는 자존감. 업무지식만 잘 배우면 무슨 소용인가.': '60',
#  '직원들이 밝고 사이가 좋음 . 교육시간이 별도로 있음.': '58',
#  '자유로운 업무환경이 형성되어 있으나 대표님 말이 곧 법인 전형적임 수직구조의 기업': '58',
#  '여러곳에서 업무 의뢰가 많이 들어와서 일을 다양하게 배울 수있다.': '58',
#  '팀별간 분리된 분위기. 회사 내 칸막이로 부서 구분이 되어있습니다.': '58',
#  '비교적 자유로운 분위기로 일할수 있지만업무량이 많은데 비해 급여는 평균정도': '58',
#  '열정페이로 모든 면을 다 감당하며 근무 할 자에게 추천합니다': '58',
#  '전문직의 특수성과 세무라는 분야에 대해 엄청난 업무량도 감당 가능한 \r애정을 가지신 경력 단절녀에게 추천함.': '56',
#  '가족 회사. \r세무사 눈치보느라 살이 쪽쪽빠지는 곳.': '32',
#  '경력직들이 있어서 그런지 알아서 돌아가는 시스템': '32',
#  '회계법인의 다양한 업무를 접할 수 있어 일반 회사와 개인회계사무실 보다는 업무 성장의 도움이 많이 됨': '32',
#  '퇴사가 후회되지 않음. 할말은 많지만 더 쓰진 않겠습니다': '30',
#  '개인사무소 치고 거래처가 굉장히 많고 직원은 적어서 한 직원이 100개씩 기장하는 회사': '30',
#  '배울것도 많고 전반적으로 좋았지만 다시 다니라면 못 다닐것같아요': '30',
#  '사무실 전체적인 분위기는 좋으나 직원들이 자주 바뀌고 적응하기 어려움': '30',
#  '처음 일배우는 사람은 비추, 평생 이곳에서만 일하실 분은 추천.': '30',
#  '사람이 머무르지 않는곳.. 계속적으로 입사, 퇴사가 일어난다. 연령대가 낮다.': '30',
#  '자유로운 분위기이나 직원 복지가 적고 위치는 좋으나 건물자체가 낙후되어있음': '30',
#  '학교같은 회사 꼰대같은 관리직, 관리직이 책임저야할 것을 직원들에게 넘김. 누구하나 책임져 주는 사람 없는 서비스직이다.': '42',
#  '아무것도 모르는 고등학생 데리고 돈장사하는 회사 1위': '42',
#  '고립된 사고 방식을 가진 회사매사에 부정적인 시선 앞뒤가 다른 경영진': '42',
#  '관리자의 입맛대로 굴러가는 회사 적은 연봉받고 미친듯이 일하면서 스트레스 받고 싶으면 입사 추천': '42',
#  '많은 사무실 다녀봤지만 그래도 직원을 챙겨줍니다\r퇴사할때 100만원 넘는 공기청정기 선물함': '40',
#  '기술에 대한 관심이 있고, 고객들을 만나는 일이 즐거운 사람에게 추천': '40',
#  '대표때문에 문닫은 회사\r영업실적도 괜찮고, 좋은 직원도 많았으나,대표의 기행이 너무컸다': '40',
#  '윗상사분들께서 친절하게 잘 가르쳐주시며 첫 직장으로 참 좋습니다.': '40',
#  '정말 최고의 직장 동료와 함께 일 할 수 있다는 장점과 동시에\r최악의 대표와 함께 일할 수 있다는 단점을 가진 회사': '40',
#  '여긴 그냥 완전 노답.. 상사가 너무 많음.. 업무 못하고 실수하면 설명은 10분정도 잔소리는 기본 30분이상 두시간 가까이씩함..  그것도 했던 말 몇번씩 함 그 긴시간동안 서서 들어야함.. 그거 듣고있음 설명 들은것도 다 까먹을 정도임.. 그 긴시간동안말 듣는거 무서워서 출근 못할정도임': '40',
#  '겉과속이 다른 여자들로 인하여 인식이 바뀌어버린회사': '46',
#  '사업은 이렇게 해야 사장과 사장 가족은 부자가 되는 기업': '46',
#  '1점도 아깝다 직원이 자주 바뀌는건 이유가 있다': '46',
#  '연봉은 나쁘지 않으나 법인 기본 40개 해야함 수직구조를 강조함': '46',
#  '세무사 사무실 치고는 복지가 꽤 좋은 편인 것 같다..': '46',
#  '담당 거래처 수는 적으나 일은 많은 곳, 꼼꼼히 일해야한다': '46',
#  '세무회계사무소에서 하는일 업무 모든것이 보통임 직원분들이 나잇대가 있음': '46',
#  '일은 잘 배울 수 있고 분위기가 많이 무겁지도 가볍지도 않은 사무실. 회식도 별로 안 함.': '46',
#  '1년이 아니라 짧은시간이였지만 1년아래에는 없어서 1년으로 적네요\r다들 친절하시고 좋은 회사에요': '46',
#  '신입으로 들어온다면 많이 배울 순 있지만 그만큼 힘들다. 경력직이라면 체크리스트 작성 등이 많아서 기존에 업무하던 스타일과 안맞을 수 있다.': '46',
#  '기장배우고싶다면 추천하지만 그외 다양한 업무를 배울기회는 적음': '64',
#  '회계사님마다 케바케는 분명있겠지만 내가 다닌곳은 3층이였고회계사님 딱 두분.. 짠돌이 중에 상짠돌이 같이일하는 직원이랑 대놓고 차별식대를 15만원인가 10만원인가 본인카드에 돈넣고 그걸 쓰라고함…. 거래처나 세무서랑 통화하는걸 지극히 싫어함 1년동안 세무서 조사관과 통화를 안해줘서 다른직원이 난처해했음': '64',
#  '부서마다 다르겠지만 대부분 일이 많은 부서들이 많은것같음': '64',
#  '인턴으로 근무 하여 처음 사회생활을 시작하는데 기본적 스킬을 배울 수 있음. 예를 들면 출력, 제본, 전화받기, 기본 엑셀 & 파워포인트, 등등 매우 베이직 한 인턴이 하는 단순 업무를 하며 기본 업무부터 시작하게됨.': '62',
#  '현직에 있으면서도 업무관련 교육이나 개정내용을 잘 챙겨야 오래 일을 할 수 있는 직종': '62',
#  '일은 많지만 대우는 최고급으로 해줬던 곳': '62',
#  '여자가  편하고 길게 다니기에는 적합하다': '62',
#  '다양한 거래처를 경험할 수 있어서 좋았습니다.': '62',
#  '꽤 규모가 큰 법인사업체라 안정적이고 다양한 업무를 경험해볼수있었음.': '62',
#  '인지도는 있지만 업무강도가 강하고 합리적이지 않은 보상.': '62',
#  '문정역송파지점회계사가 감정적이며 배울게없는곳.거래처가 몇개없어서 타 사무실에 비하면 좋다.다만 그 좋은점을 다 깍아먹는 회계사와 잡무들이있다.': '20',
#  '배울점이 하나도 없는곳 신입이 들어가기엔 매우 고통스러울수도 있는 구조 형태임': '20',
#  '일당백이 무슨 말인지 알게 하는 회사.\r왜 사람들이 자주 바뀌는 지 알았으면 좋겠다.': '20',
#  '부부싸움. 분노조절장애. 자존감 깎아 먹고 싶은 사람 들어가세요. 직원은 심심풀이 화풀이 대상임.': '20',
#  '서열 체계만 잘 잡혀있고 경력자가 일하기 괜찮은 곳': '20',
#  '실장 밖에 있지 않으며 신입에게 업무를 잘 알려주지 않음': '20',
#  '같이일하는사람들은 좋았음.........': '20',
#  '서비스직 마인드가 있으면 더 잘 맞을거 같아요': '20',
#  '인생을 살면서 이런 지옥 같은 경험을 할 수 있을까 생각되는 곳.\r삶이 불행해지고 싶다면 입사하세요…': '20',
#  '진짜 부모님의 원수가 간다고해도 한번쯤 말리고 싶은 회사': '20',
#  '재직 당시 원펌 형태의 회계법인이었으며 일은 많지만 신입이 배우기엔 좋은 회사입니다.': '56',
#  '업무가 많은편이고 급여가 적은편입니다.ㅎㅎㅎㅎㅎㅎㅎㅎㅎ': '56',
#  '회식없는 자유로운 분위기, 개인플레이 철저': '56',
#  '직원과의 분위기가좋음 워라밸가능함 연차17개 자유로운 연차사용': '56',
#  '그냥 그런 다른 회계법인과 다를 바 없는 평범한 회사한마디로 그런 회사': '56',
#  '꼰대의 천국, 개인이기주의 팽배, 정말 오래 다니기는 힘든 회사': '56',
#  '무난함 팀을 잘 만난다면 아주 괜찮은 회사생활 가능할것으로 보임': '56',
#  '나만 잘 하면 별도의 압박은 크게 없는 회사.': '56',
#  '적게 받고 야근 많이 하고 싶으면 추천합니다 사람 스트레스 장난 아님': '56',
#  '드림세무법인 연수지점 경력쌓기 좋았고,직장동료들이 사람들이 모난사람 없이 다 좋았습니다.': '54',
#  '내 일만 잘하면 딱히 트집잡힐일이 없음': '40',
#  '업무하고싶은남자 오세요 1년동안 열심히 업무하며 관리하고싶은 남성분은 하셔도될듯 사람안믿는 남과장의 험한말과 스트레스 잘참는사람은 괜찮음': '38',
#  '신입이라면 입사를 다시 생각해보기 바람. 경력직은 다니기 괜찮을 수도?': '38',
#  '전체적으로 배울 수 있고 일을 할 수 있는 환경입니다.': '38',
#  '입사하기엔 너무 쉬워요  직원분들 다 친절하세요': '38',
#  '사내 텃새가 너무 심하여 신입은 다니기 힘듦. 회사체계는 나름 잡혀 있어서 신입이 업무 배우기는 괜찮음': '36',
#  '자유로운분위기로 자유롭게 연차사용가능 그거빼곤좋은거없음': '36',
#  '술 못먹는 사람은 비추합니다. 술 진짜 자주 먹음 회식문화 별로임': '36',
#  '여러기업의 회계처리를 해보고 경험할수 있고, 부가세,원천세,소득세,법인세 등 세무업무와 관련되어 많은 기업들의 세무신고를 할수 있다.': '36',
#  '회사가 아니라 학교 느낌이다. 퇴사하는 사람이 많아 신입 와도 말 잘 안 걸음.': '36',
#  '소규모이지만 업체를 다양하게 가지고 있어 여러 업종을 접할 수 있으며 수평적인 회사': '80',
#  '업종이 세무대리쪽이여서 일하면서 여러가지 경력을 쌓을 수 있다는 최고의 장점이 있습니다. 이 업종은 어디서든 똑같은거 같지만, 회계사님들께서 회계학쪽으로 많이 도움 주십니다.': '80',
#  '회계법인 중에서 최고의 대우를 받으며 일할 수 있는 곳.': '80',
#  '사업부마다 다르겠지만, 제가 근무하고 있는 곳은 업무량도 많고 업무강도도 다소 높은 편입니다. 그에 비해 복지를 챙겨주려고 하는것 같긴 한데 업무량에 비하면 모자른것 같습니다.': '78',
#  '신입으로 일배우기좋은곳이었어요 급여인상이나성취감에 집착하지않으면 좋은곳': '78',
#  'A부터Z까지 모든걸 담당자가 직접 결산함 \r개인의 역량 강화를 위해서 자기개발이 필요함': '76',
#  '첫직장으론 나쁘지않은곳.막내가 다니기엔 좋은회사지만,연차가 높아질수록 위에 사람이 나가지 않는이상 계속해서 막내생활을 함': '76',
#  '좋은 분위기에서 일할수 있는곳, 발전하는 곳': '76',
#  '신입의 위치로 다니기 힘든곳많은 지식과 경험을 바탕으로 성장할 수 있음신입으로써 발전하기 어려운환경': '76',
#  '대학생이 세무경험을 쌓기 좋은곳. 아르바이트를 하면서 용돈벌이와 근로경험 가능': '76'}
